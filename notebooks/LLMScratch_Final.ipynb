# %% [markdown]
# # BUILD A LARGE LANGUAGE MODEL FROM SCRATCH

# %% [markdown]
# ### STEP 1: LOADING THE DATASET

# %%
import os

file_path = "data.txt"

# Check if the file exists in the current directory (i.e., Colab session)
if os.path.exists(file_path):
    with open(file_path, "r", encoding="utf-8") as file:
        text_data = file.read()
    print(f"File '{file_path}' loaded with {len(text_data)} characters.")
else:
    print(f"File '{file_path}' not found. Please upload it to the Colab environment first.")
# Out:
# File 'data.txt' loaded with 1935114 characters.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### STEP 2: IMPLEMENTING THE TOKENIZER

# %%
# !pip3 install tiktoken > /dev/null 2>&1

# %%
import importlib
import tiktoken

print("tiktoken version:", importlib.metadata.version("tiktoken"))
# Out:
# tiktoken version: 0.9.0

# %%
tokenizer = tiktoken.get_encoding("gpt2")

# %%
text = (
    "Hello, do you like tea? <|endoftext|> In the sunlit terraces"
     "of someunknownPlace."
)

integers = tokenizer.encode(text, allowed_special={"<|endoftext|>"})

print(integers)
# Out:
# [15496, 11, 466, 345, 588, 8887, 30, 220, 50256, 554, 262, 4252, 18250, 8812, 2114, 1659, 617, 34680, 27271, 13]

# %%
integers = tokenizer.encode("Akwirw ier")
print(integers)

strings = tokenizer.decode(integers)
print(strings)
# Out:
# [33901, 86, 343, 86, 220, 959]
# Akwirw ier

# %%
total_characters = len(text_data)
total_tokens = len(tokenizer.encode(text_data))

print("Characters:", total_characters)
print("Tokens:", total_tokens)
# Out:
# Characters: 1935114
# Tokens: 522304

# %% [markdown]
# ### STEP 3: CREATING INPUT-TARGET PAIRS

# %%
with open("data.txt", "r", encoding="utf-8") as f:
    raw_text = f.read()

enc_text = tokenizer.encode(raw_text)
print(len(enc_text))
# Out:
# 522304

# %%
from torch.utils.data import Dataset, DataLoader


class GPTDatasetV1(Dataset):
    def __init__(self, txt, tokenizer, max_length, stride):
        self.input_ids = []
        self.target_ids = []

        # Tokenize the entire text
        token_ids = tokenizer.encode(txt, allowed_special={"<|endoftext|>"})

        # Use a sliding window to chunk the book into overlapping sequences of max_length
        for i in range(0, len(token_ids) - max_length, stride):
            input_chunk = token_ids[i:i + max_length]
            target_chunk = token_ids[i + 1: i + max_length + 1]
            self.input_ids.append(torch.tensor(input_chunk))
            self.target_ids.append(torch.tensor(target_chunk))

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return self.input_ids[idx], self.target_ids[idx]

# %%
def create_dataloader_v1(txt, batch_size=4, max_length=256,
                         stride=128, shuffle=True, drop_last=True,
                         num_workers=0):

    # Initialize the tokenizer
    tokenizer = tiktoken.get_encoding("gpt2")

    # Create dataset
    dataset = GPTDatasetV1(txt, tokenizer, max_length, stride)

    # Create dataloader
    dataloader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=shuffle,
        drop_last=drop_last,
        num_workers=num_workers
    )

    return dataloader

# %%
import torch
print("PyTorch version:", torch.__version__)
dataloader = create_dataloader_v1(
    raw_text, batch_size=1, max_length=4, stride=1, shuffle=False
)

data_iter = iter(dataloader)
first_batch = next(data_iter)
print(first_batch)
# Out:
# PyTorch version: 2.6.0+cu124
# [tensor([[   62,    54,  2501, 47958]]), tensor([[   54,  2501, 47958,   468]])]

# %% [markdown]
# ### STEP 4: CREATING TOKEN EMBEDDINGS

# %%
vocab_size = 50257
output_dim = 256

token_embedding_layer = torch.nn.Embedding(vocab_size, output_dim)

# %%
max_length = 4
dataloader = create_dataloader_v1(
    raw_text, batch_size=8, max_length=max_length,
    stride=max_length, shuffle=False
)
data_iter = iter(dataloader)
inputs, targets = next(data_iter)

# %%
print("Token IDs:\n", inputs)
print("\nInputs shape:\n", inputs.shape)
# Out:
# Token IDs:
#  tensor([[   62,    54,  2501, 47958],
#         [  468,  7382,   257,  3734],
#         [  290,   655, 12941,  1022],
#         [  564,   250, 33983,   198],
#         [ 1525, 24930,   447,   251],
#         [  290,   564,   250, 33983],
#         [  351,  2614,  1842,    13],
#         [  447,   251,   770, 12941]])
#
# Inputs shape:
#  torch.Size([8, 4])

# %%
token_embeddings = token_embedding_layer(inputs)
print(token_embeddings.shape)
# Out:
# torch.Size([8, 4, 256])

# %% [markdown]
# ### STEP 5: CREATING POSITIONAL EMBEDDINGS

# %%
context_length = max_length
pos_embedding_layer = torch.nn.Embedding(context_length, output_dim)

# %%
pos_embeddings = pos_embedding_layer(torch.arange(max_length))
print(pos_embeddings.shape)
# Out:
# torch.Size([4, 256])

# %% [markdown]
# ### STEP 6: CREATING INPUT EMBEDDINGS

# %%
input_embeddings = token_embeddings + pos_embeddings
print(input_embeddings.shape)
# Out:
# torch.Size([8, 4, 256])

# %% [markdown]
# ### STEP 7: IMPLEMENTING MULTI-HEAD ATTENTION

# %%
import torch.nn as nn

class MultiHeadAttention(nn.Module):
    def __init__(self, d_in, d_out, context_length, dropout, num_heads, qkv_bias=False):
        super().__init__()
        assert (d_out % num_heads == 0), \
            "d_out must be divisible by num_heads"
        self.d_out = d_out
        self.num_heads = num_heads
        self.head_dim = d_out // num_heads # Reduce the projection dim to match desired output dim

        self.W_query = nn.Linear(d_in, d_out, bias=qkv_bias)
        self.W_key = nn.Linear(d_in, d_out, bias=qkv_bias)
        self.W_value = nn.Linear(d_in, d_out, bias=qkv_bias)
        self.out_proj = nn.Linear(d_out, d_out)  # Linear layer to combine head outputs
        self.dropout = nn.Dropout(dropout)
        self.register_buffer(
            "mask",
            torch.triu(torch.ones(context_length, context_length),
                       diagonal=1)
        )

    def forward(self, x):
        b, num_tokens, d_in = x.shape

        keys = self.W_key(x) # Shape: (b, num_tokens, d_out)
        queries = self.W_query(x)
        values = self.W_value(x)

        # We implicitly split the matrix by adding a `num_heads` dimension
        # Unroll last dim: (b, num_tokens, d_out) -> (b, num_tokens, num_heads, head_dim)
        keys = keys.view(b, num_tokens, self.num_heads, self.head_dim)
        values = values.view(b, num_tokens, self.num_heads, self.head_dim)
        queries = queries.view(b, num_tokens, self.num_heads, self.head_dim)

        # Transpose: (b, num_tokens, num_heads, head_dim) -> (b, num_heads, num_tokens, head_dim)
        keys = keys.transpose(1, 2)
        queries = queries.transpose(1, 2)
        values = values.transpose(1, 2)

        # Compute scaled dot-product attention (aka self-attention) with a causal mask
        attn_scores = queries @ keys.transpose(2, 3)  # Dot product for each head

        # Original mask truncated to the number of tokens and converted to boolean
        mask_bool = self.mask.bool()[:num_tokens, :num_tokens]

        # Use the mask to fill attention scores
        attn_scores.masked_fill_(mask_bool, -torch.inf)

        attn_weights = torch.softmax(attn_scores / keys.shape[-1]**0.5, dim=-1)
        attn_weights = self.dropout(attn_weights)

        # Shape: (b, num_tokens, num_heads, head_dim)
        context_vec = (attn_weights @ values).transpose(1, 2)

        # Combine heads, where self.d_out = self.num_heads * self.head_dim
        context_vec = context_vec.contiguous().view(b, num_tokens, self.d_out)
        context_vec = self.out_proj(context_vec) # optional projection

        return context_vec

# %%
torch.manual_seed(123)

# Define the tensor with 3 rows and 6 columns
inputs = torch.tensor(
    [[0.43, 0.15, 0.89, 0.55, 0.87, 0.66],  # Row 1
     [0.57, 0.85, 0.64, 0.22, 0.58, 0.33],  # Row 2
     [0.77, 0.25, 0.10, 0.05, 0.80, 0.55]]  # Row 3
)

batch = torch.stack((inputs, inputs), dim=0)
print(batch.shape)

batch_size, context_length, d_in = batch.shape
d_out = 6
mha = MultiHeadAttention(d_in, d_out, context_length, 0.0, num_heads=2)
context_vecs = mha(batch)
print(context_vecs)
print("context_vecs.shape:", context_vecs.shape)
# Out:
# torch.Size([2, 3, 6])
# tensor([[[ 0.1569, -0.0873,  0.0210,  0.0215, -0.3243, -0.2518],
#          [ 0.1117, -0.0547,  0.0406, -0.0213, -0.3251, -0.2993],
#          [ 0.1196, -0.0491,  0.0318, -0.0635, -0.2788, -0.2578]],
#
#         [[ 0.1569, -0.0873,  0.0210,  0.0215, -0.3243, -0.2518],
#          [ 0.1117, -0.0547,  0.0406, -0.0213, -0.3251, -0.2993],
#          [ 0.1196, -0.0491,  0.0318, -0.0635, -0.2788, -0.2578]]],
#        grad_fn=<ViewBackward0>)
# context_vecs.shape: torch.Size([2, 3, 6])

# %% [markdown]
# ### STEP 8: IMPLEMENTING A GPT MODEL FROM SCRATCH TO GENERATE TEXT

# %%
GPT_CONFIG_124M = {
    "vocab_size": 50257,    # Vocabulary size
    "context_length": 256, # Context length
    "emb_dim": 768,         # Embedding dimension
    "n_heads": 12,          # Number of attention heads
    "n_layers": 12,         # Number of layers
    "drop_rate": 0.1,       # Dropout rate
    "qkv_bias": False       # Query-Key-Value bias
}

# %% [markdown]
# ### STEP 9: THE BUILDING BLOCKS-LAYER NORMALIZATION, GELU AND FEED-FORWARD NEURAL NETWORK

# %%
class LayerNorm(nn.Module):
    def __init__(self, emb_dim):
        super().__init__()
        self.eps = 1e-5
        self.scale = nn.Parameter(torch.ones(emb_dim))
        self.shift = nn.Parameter(torch.zeros(emb_dim))

    def forward(self, x):
        mean = x.mean(dim=-1, keepdim=True)
        var = x.var(dim=-1, keepdim=True, unbiased=False)
        norm_x = (x - mean) / torch.sqrt(var + self.eps)
        return self.scale * norm_x + self.shift

class GELU(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, x):
        return 0.5 * x * (1 + torch.tanh(
            torch.sqrt(torch.tensor(2.0 / torch.pi)) *
            (x + 0.044715 * torch.pow(x, 3))
        ))


class FeedForward(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(cfg["emb_dim"], 4 * cfg["emb_dim"]), ## Expansion
            GELU(), ## Activation
            nn.Linear(4 * cfg["emb_dim"], cfg["emb_dim"]), ## Contraction
        )

    def forward(self, x):
        return self.layers(x)

# %%
class TransformerBlock(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.att = MultiHeadAttention(
            d_in=cfg["emb_dim"],
            d_out=cfg["emb_dim"],
            context_length=cfg["context_length"],
            num_heads=cfg["n_heads"],
            dropout=cfg["drop_rate"],
            qkv_bias=cfg["qkv_bias"])
        self.ff = FeedForward(cfg)
        self.norm1 = LayerNorm(cfg["emb_dim"])
        self.norm2 = LayerNorm(cfg["emb_dim"])
        self.drop_shortcut = nn.Dropout(cfg["drop_rate"])

    def forward(self, x):
        # Shortcut connection for attention block
        shortcut = x
        x = self.norm1(x)
        x = self.att(x)  # Shape [batch_size, num_tokens, emb_size]
        x = self.drop_shortcut(x)
        x = x + shortcut  # Add the original input back

        # Shortcut connection for feed forward block
        shortcut = x
        x = self.norm2(x)
        x = self.ff(x)
        # 2*4*768
        x = self.drop_shortcut(x)
        x = x + shortcut  # Add the original input back

        return x
        # 2*4*768

# %% [markdown]
# ### STEP 10: ENTIRE GPT MODEL ARCHITECTURE IMPLEMENTATION

# %%
class GPTModel(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.tok_emb = nn.Embedding(cfg["vocab_size"], cfg["emb_dim"])
        self.pos_emb = nn.Embedding(cfg["context_length"], cfg["emb_dim"])
        self.drop_emb = nn.Dropout(cfg["drop_rate"])

        self.trf_blocks = nn.Sequential(
            *[TransformerBlock(cfg) for _ in range(cfg["n_layers"])])

        # self.final_norm = LayerNorm(cfg["emb_dim"])
        self.out_head = nn.Linear(
            cfg["emb_dim"], cfg["vocab_size"], bias=False
        )

    def forward(self, in_idx):
        batch_size, seq_len = in_idx.shape
        tok_embeds = self.tok_emb(in_idx)
        pos_embeds = self.pos_emb(torch.arange(seq_len, device=in_idx.device))
        x = tok_embeds + pos_embeds  # Shape [batch_size, num_tokens, emb_size]
        x = self.drop_emb(x)
        x = self.trf_blocks(x)
        # x = self.final_norm(x)
        logits = self.out_head(x)
        return logits

# %%
torch.manual_seed(123)

batch = []
txt1 = "Every effort moves you"
txt2 = "Every day holds a"
batch.append(torch.tensor(tokenizer.encode(txt1)))
batch.append(torch.tensor(tokenizer.encode(txt2)))
batch = torch.stack(batch, dim=0)

model = GPTModel(GPT_CONFIG_124M)
out = model(batch)
print("Input batch:\n", batch)
print("\nOutput shape:", out.shape)
print(out)
# Out:
# Input batch:
#  tensor([[6109, 3626, 6100,  345],
#         [6109, 1110, 6622,  257]])
#
# Output shape: torch.Size([2, 4, 50257])
# tensor([[[ 7.2379,  9.2021,  2.4880,  ..., -3.4341,  7.5146,  5.0383],
#          [ 9.4426,  7.6091,  1.4124,  ..., -5.6357, 14.3246,  1.9549],
#          [ 6.0989,  1.7785, -2.2105,  ...,  0.3368,  9.4367,  8.8507],
#          [ 6.9916, -0.0620,  1.1862,  ..., -8.6474,  7.7368,  0.7080]],
#
#         [[ 3.7606,  6.8197, -5.9052,  ..., -1.9480,  2.5729, -0.9700],
#          [ 4.3701, -2.1784, -6.2221,  ..., -0.4014,  6.8416, -2.7395],
#          [-1.4246, -1.5830, -9.5747,  ...,  6.9486,  4.5621, -2.0802],
#          [ 0.4507, -6.3370, -4.0991,  ..., -0.6288,  1.2506, -7.9354]]],
#        grad_fn=<UnsafeViewBackward0>)

# %%
total_params = sum(p.numel() for p in model.parameters())
print(f"Total number of parameters: {total_params:,}")
# Out:
# Total number of parameters: 219,041,280

# %%
print("Token embedding layer shape:", model.tok_emb.weight.shape)
print("Output layer shape:", model.out_head.weight.shape)
# Out:
# Token embedding layer shape: torch.Size([50257, 768])
# Output layer shape: torch.Size([50257, 768])

# %%
total_size_bytes = total_params * 4 #A
total_size_mb = total_size_bytes / (1024 * 1024) #B
print(f"Total size of the model: {total_size_mb:.2f} MB")
# Out:
# Total size of the model: 835.58 MB

# %% [markdown]
# ### STEP 11: GENERATING TEXT FROM OUTPUT TOKENS

# %%
def generate_text_simple(model, idx, max_new_tokens, context_size):
    # idx is (batch, n_tokens) array of indices in the current context

    ###Input batch:
 ###tensor([[6109, 3626, 6100,  345],
        ##[6109, 1110, 6622,  257]])

    for _ in range(max_new_tokens):

        # Crop current context if it exceeds the supported context size
        # E.g., if LLM supports only 5 tokens, and the context size is 10
        # then only the last 5 tokens are used as context
        idx_cond = idx[:, -context_size:]

        # Get the predictions
        with torch.no_grad():
            logits = model(idx_cond) ### batch, n_tokens, vocab_size

        # Focus only on the last time step
        # (batch, n_tokens, vocab_size) becomes (batch, vocab_size)
        logits = logits[:, -1, :]

        # Apply softmax to get probabilities
        probas = torch.softmax(logits, dim=-1)  # (batch, vocab_size)

        # Get the idx of the vocab entry with the highest probability value
        idx_next = torch.argmax(probas, dim=-1, keepdim=True)  # (batch, 1)

        # Append sampled index to the running sequence
        idx = torch.cat((idx, idx_next), dim=1)  # (batch, n_tokens+1)

    return idx

# %%
import tiktoken

def text_to_token_ids(text, tokenizer):
    encoded = tokenizer.encode(text, allowed_special={'<|endoftext|>'})
    encoded_tensor = torch.tensor(encoded).unsqueeze(0) # add batch dimension
    return encoded_tensor

def token_ids_to_text(token_ids, tokenizer):
    flat = token_ids.squeeze(0) # remove batch dimension
    return tokenizer.decode(flat.tolist())

start_context = "The Room was"



token_ids = generate_text_simple(
    model=model,
    idx=text_to_token_ids(start_context, tokenizer),
    max_new_tokens=10,
    context_size=GPT_CONFIG_124M["context_length"]
)

print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# Output text:
#  The Room wasington NWuddle bod�suffarius HeckRunner�

# %% [markdown]
# ### STEP 12: CREATING TRAINING, TESTING AND VALIDATION DATA

# %%
# Train/validation ratio
train_ratio = 0.90
split_idx = int(train_ratio * len(text_data))
train_data = text_data[:split_idx]
val_data = text_data[split_idx:]


torch.manual_seed(123)

train_loader = create_dataloader_v1(
    train_data,
    batch_size=2,
    max_length=GPT_CONFIG_124M["context_length"],
    stride=GPT_CONFIG_124M["context_length"],
    drop_last=True,
    shuffle=True,
    num_workers=0
)

val_loader = create_dataloader_v1(
    val_data,
    batch_size=2,
    max_length=GPT_CONFIG_124M["context_length"],
    stride=GPT_CONFIG_124M["context_length"],
    drop_last=False,
    shuffle=False,
    num_workers=0
)

# %% [markdown]
# ### STEP 13: DEFINING THE CROSS ENTROPY LOSS FUNCTION

# %%
def calc_loss_batch(input_batch, target_batch, model, device):
    input_batch, target_batch = input_batch.to(device), target_batch.to(device)
    logits = model(input_batch)
    loss = torch.nn.functional.cross_entropy(logits.flatten(0, 1), target_batch.flatten())
    return loss


def calc_loss_loader(data_loader, model, device, num_batches=None):
    total_loss = 0.
    if len(data_loader) == 0:
        return float("nan")
    elif num_batches is None:
        num_batches = len(data_loader)
    else:
        # Reduce the number of batches to match the total number of batches in the data loader
        # if num_batches exceeds the number of batches in the data loader
        num_batches = min(num_batches, len(data_loader))
    for i, (input_batch, target_batch) in enumerate(data_loader):
        if i < num_batches:
            loss = calc_loss_batch(input_batch, target_batch, model, device)
            total_loss += loss.item()
        else:
            break
    return total_loss / num_batches

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Note:
# Uncommenting the following lines will allow the code to run on Apple Silicon chips, if applicable,
# which is approximately 2x faster than on an Apple CPU (as measured on an M3 MacBook Air).
# However, the resulting loss values may be slightly different.

#if torch.cuda.is_available():
#    device = torch.device("cuda")
#elif torch.backends.mps.is_available():
#    device = torch.device("mps")
#else:
#    device = torch.device("cpu")
#
# print(f"Using {device} device.")


model.to(device) # no assignment model = model.to(device) necessary for nn.Module classes


torch.manual_seed(123) # For reproducibility due to the shuffling in the data loader

with torch.no_grad(): # Disable gradient tracking for efficiency because we are not training, yet
    train_loss = calc_loss_loader(train_loader, model, device)
    val_loss = calc_loss_loader(val_loader, model, device)

print("Training loss:", train_loss)
print("Validation loss:", val_loss)
# Out:
# Training loss: 14.919835876263186
# Validation loss: 15.044375660183194

# %%
print(device)
# Out:
# cuda

# %% [markdown]
# ### STEP 14: TRAINING LOOP FOR THE LLM

# %%
def train_model_simple(model, train_loader, val_loader, optimizer, device, num_epochs,
                       eval_freq, eval_iter, start_context, tokenizer):
    # Initialize lists to track losses and tokens seen
    train_losses, val_losses, track_tokens_seen = [], [], []
    tokens_seen, global_step = 0, -1

    # Main training loop
    for epoch in range(num_epochs):
        model.train()  # Set model to training mode

        for input_batch, target_batch in train_loader:
            optimizer.zero_grad() # Reset loss gradients from previous batch iteration
            loss = calc_loss_batch(input_batch, target_batch, model, device)
            loss.backward() # Calculate loss gradients
            optimizer.step() # Update model weights using loss gradients
            tokens_seen += input_batch.numel() # Returns the total number of elements (or tokens) in the input_batch.
            global_step += 1

            # Optional evaluation step
            if global_step % eval_freq == 0:
                train_loss, val_loss = evaluate_model(
                    model, train_loader, val_loader, device, eval_iter)
                train_losses.append(train_loss)
                val_losses.append(val_loss)
                track_tokens_seen.append(tokens_seen)
                print(f"Ep {epoch+1} (Step {global_step:06d}): "
                      f"Train loss {train_loss:.3f}, Val loss {val_loss:.3f}")

        # Print a sample text after each epoch
        generate_and_print_sample(
            model, tokenizer, device, start_context
        )

    return train_losses, val_losses, track_tokens_seen

# %%
def evaluate_model(model, train_loader, val_loader, device, eval_iter):
    model.eval()
    with torch.no_grad():
        train_loss = calc_loss_loader(train_loader, model, device, num_batches=eval_iter)
        val_loss = calc_loss_loader(val_loader, model, device, num_batches=eval_iter)
    model.train()
    return train_loss, val_loss

# %%
def generate_and_print_sample(model, tokenizer, device, start_context):
    model.eval()
    context_size = model.pos_emb.weight.shape[0]
    encoded = text_to_token_ids(start_context, tokenizer).to(device)
    with torch.no_grad():
        token_ids = generate_text_simple(
            model=model, idx=encoded,
            max_new_tokens=50, context_size=context_size
        )
    decoded_text = token_ids_to_text(token_ids, tokenizer)
    print(decoded_text.replace("\n", " "))  # Compact print format
    model.train()

# %%
# !pip uninstall sympy -y
# !pip install sympy==1.12
# Out:
# Found existing installation: sympy 1.13.1
# Uninstalling sympy-1.13.1:
#   Successfully uninstalled sympy-1.13.1
# Collecting sympy==1.12
#   Downloading sympy-1.12-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.11/dist-packages (from sympy==1.12) (1.3.0)
# Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 58.2 MB/s eta 0:00:00
# Installing collected packages: sympy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires sympy==1.13.1; python_version >= "3.9", but you have sympy 1.12 which is incompatible.
# Successfully installed sympy-1.12

# %% [markdown]
# As we can see, based on the results printed during the training, the training loss improve drastically, starting with a value of 9.558 and converging to 0.762.
#
# The language skills of
# the model have improved quite a lot. In the beginning, the model is only able to append
# commas to the start context ("Every effort moves you,,,,,,,,,,,,") or repeat the
# word "and". At the end of the training, it can generate grammatically correct text.
#
#
# Similar to the training set loss, we can see that the validation loss starts high (9.856)
# and decreases during the training. However, it never becomes as small as the training set
# loss and remains at 6.372 after the 10th epoch.

# %% [markdown]
# ### STEP 15: PLOTTING THE LOSSES

# %%
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

# Create a results directory in your Drive
RESULT_DIR = "/content/drive/MyDrive/grid_search_results"
os.makedirs(RESULT_DIR, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import torch
import time
import seaborn as sns
import numpy as np

# Dark background settings
plt.style.use('dark_background')
sns.set_style("darkgrid")

# ---- Smoothing Function ----
def smooth(values, window_size=20):
    if len(values) < window_size:
        return values
    return np.convolve(values, np.ones(window_size)/window_size, mode='valid')

# ---- Dark Themed Plotting Function ----
def plot_losses(epochs_seen, tokens_seen, train_losses, val_losses, lr_label, epoch_count, smooth_window=20):
    smoothed_train = smooth(train_losses, smooth_window)
    smoothed_val = smooth(val_losses, smooth_window)

    offset = (len(train_losses) - len(smoothed_train)) // 2
    epochs_smoothed = epochs_seen[offset : offset + len(smoothed_train)]
    tokens_smoothed = tokens_seen[offset : offset + len(smoothed_train)]

    fig, ax1 = plt.subplots(figsize=(7, 4))
    fig.patch.set_facecolor('black')
    ax1.set_facecolor('black')

    ax1.plot(epochs_smoothed, smoothed_train, label="Training Loss", color="cyan", linewidth=2)
    ax1.plot(epochs_smoothed, smoothed_val, label="Validation Loss", color="yellow", linewidth=2, linestyle="--")

    ax1.set_xlabel("Epochs", fontsize=12, color='white')
    ax1.set_ylabel("Loss", fontsize=12, color='white')
    ax1.tick_params(colors='white')
    ax1.grid(True, linestyle="--", alpha=0.3)
    ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

    ax2 = ax1.twiny()
    ax2.plot(tokens_smoothed, smoothed_train, alpha=0)
    ax2.set_xlabel("Tokens Seen", fontsize=12, color='white')
    ax2.tick_params(colors='white')

    fig.suptitle(f"Loss Curve (LR={lr_label}, Epochs={epoch_count})", fontsize=14, color='white', weight='bold')
    legend = ax1.legend(loc="upper right", fontsize=10)
    for text in legend.get_texts():
        text.set_color("white")

    fig.tight_layout(rect=[0, 0, 1, 0.95])
    plot_filename = os.path.join(RESULT_DIR, f"no_normalization_layers.pdf")
    plt.savefig(plot_filename, dpi=300)
    plt.close()

# ---- Training Wrapper Function ----
def run_training_for_epochs(lr, epoch_count):
    print(f"\nTraining with learning rate: {lr} for {epoch_count} epochs")
    torch.manual_seed(123)

    model = GPTModel(GPT_CONFIG_124M)
    model.to(device)
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=0.1)

    train_losses, val_losses, tokens_seen = train_model_simple(
        model, train_loader, val_loader, optimizer, device,
        num_epochs=epoch_count, eval_freq=5, eval_iter=1,
        start_context="He said we came here", tokenizer=tokenizer
    )

    epochs_tensor = torch.linspace(0, epoch_count, len(train_losses))
    lr_label = str(lr).replace(".", "_")
    plot_losses(epochs_tensor, tokens_seen, train_losses, val_losses, lr_label, epoch_count)

    token_ids = text_to_token_ids("The tree was", tokenizer).to(device)
    token_ids = generate_text_simple(
        model=model,
        idx=token_ids,
        max_new_tokens=25,
        context_size=GPT_CONFIG_124M["context_length"]
    )
    output_text = token_ids_to_text(token_ids, tokenizer)

    output_file = os.path.join(RESULT_DIR, f"output_text_no_normalization_layers.txt")
    with open(output_file, "w") as f:
        f.write(output_text)

    print("Sample output:\n", output_text)

    loss_file = os.path.join(RESULT_DIR, f"final_losses_no_normalization_layers.txt")
    with open(loss_file, "w") as f:
        f.write(f"Final Training Loss: {train_losses[-1]:.4f}\n")
        f.write(f"Final Validation Loss: {val_losses[-1]:.4f}\n")

# ---- Run Training ----
learning_rate = 0.0001
epoch_variations = [10]
start_time = time.time()

for epoch_count in epoch_variations:
    run_training_for_epochs(learning_rate, epoch_count)

end_time = time.time()
print(f"\nAll training runs completed in {(end_time - start_time)/60:.2f} minutes.")
# Out:
# Training with learning rate: 0.0001 for 10 epochs
# Ep 1 (Step 000000): Train loss 12.751, Val loss 13.068
# Ep 1 (Step 000005): Train loss 11.659, Val loss 11.259
# Ep 1 (Step 000010): Train loss 11.035, Val loss 11.774
# Ep 1 (Step 000015): Train loss 10.680, Val loss 10.065
# Ep 1 (Step 000020): Train loss 10.403, Val loss 9.959
# Ep 1 (Step 000025): Train loss 9.265, Val loss 9.174
# Ep 1 (Step 000030): Train loss 8.331, Val loss 8.959
# Ep 1 (Step 000035): Train loss 8.488, Val loss 8.476
# Ep 1 (Step 000040): Train loss 8.714, Val loss 8.133
# Ep 1 (Step 000045): Train loss 7.849, Val loss 7.965
# Ep 1 (Step 000050): Train loss 7.807, Val loss 7.779
# Ep 1 (Step 000055): Train loss 8.016, Val loss 7.797
# Ep 1 (Step 000060): Train loss 7.852, Val loss 7.566
# Ep 1 (Step 000065): Train loss 7.638, Val loss 7.364
# Ep 1 (Step 000070): Train loss 7.667, Val loss 7.403
# Ep 1 (Step 000075): Train loss 6.857, Val loss 7.091
# Ep 1 (Step 000080): Train loss 7.516, Val loss 6.985
# Ep 1 (Step 000085): Train loss 7.063, Val loss 6.987
# Ep 1 (Step 000090): Train loss 7.076, Val loss 6.975
# Ep 1 (Step 000095): Train loss 6.854, Val loss 6.895
# Ep 1 (Step 000100): Train loss 6.643, Val loss 6.788
# Ep 1 (Step 000105): Train loss 6.608, Val loss 6.831
# Ep 1 (Step 000110): Train loss 7.440, Val loss 6.784
# Ep 1 (Step 000115): Train loss 6.562, Val loss 6.810
# Ep 1 (Step 000120): Train loss 6.594, Val loss 6.680
# Ep 1 (Step 000125): Train loss 6.851, Val loss 6.905
# Ep 1 (Step 000130): Train loss 7.180, Val loss 6.633
# Ep 1 (Step 000135): Train loss 6.377, Val loss 6.669
# Ep 1 (Step 000140): Train loss 6.366, Val loss 6.586
# Ep 1 (Step 000145): Train loss 5.988, Val loss 6.613
# Ep 1 (Step 000150): Train loss 6.925, Val loss 6.597
# Ep 1 (Step 000155): Train loss 6.891, Val loss 6.565
# Ep 1 (Step 000160): Train loss 6.875, Val loss 6.614
# Ep 1 (Step 000165): Train loss 5.920, Val loss 6.497
# Ep 1 (Step 000170): Train loss 6.260, Val loss 6.435
# Ep 1 (Step 000175): Train loss 6.687, Val loss 6.535
# Ep 1 (Step 000180): Train loss 6.529, Val loss 6.413
# Ep 1 (Step 000185): Train loss 6.497, Val loss 6.484
# Ep 1 (Step 000190): Train loss 6.242, Val loss 6.421
# Ep 1 (Step 000195): Train loss 6.016, Val loss 6.427
# Ep 1 (Step 000200): Train loss 6.292, Val loss 6.365
# Ep 1 (Step 000205): Train loss 6.693, Val loss 6.352
# Ep 1 (Step 000210): Train loss 6.157, Val loss 6.334
# Ep 1 (Step 000215): Train loss 6.286, Val loss 6.357
# Ep 1 (Step 000220): Train loss 6.320, Val loss 6.335
# Ep 1 (Step 000225): Train loss 6.527, Val loss 6.302
# Ep 1 (Step 000230): Train loss 6.195, Val loss 6.405
# Ep 1 (Step 000235): Train loss 5.902, Val loss 6.290
# Ep 1 (Step 000240): Train loss 5.947, Val loss 6.281
# Ep 1 (Step 000245): Train loss 5.643, Val loss 6.208
# Ep 1 (Step 000250): Train loss 5.643, Val loss 6.183
# Ep 1 (Step 000255): Train loss 5.949, Val loss 6.195
# Ep 1 (Step 000260): Train loss 6.035, Val loss 6.224
# Ep 1 (Step 000265): Train loss 5.635, Val loss 6.161
# Ep 1 (Step 000270): Train loss 6.138, Val loss 6.187
# Ep 1 (Step 000275): Train loss 5.866, Val loss 6.232
# Ep 1 (Step 000280): Train loss 6.477, Val loss 6.135
# Ep 1 (Step 000285): Train loss 6.065, Val loss 6.215
# Ep 1 (Step 000290): Train loss 6.152, Val loss 6.065
# Ep 1 (Step 000295): Train loss 5.470, Val loss 6.090
# Ep 1 (Step 000300): Train loss 5.628, Val loss 6.186
# Ep 1 (Step 000305): Train loss 5.789, Val loss 6.070
# Ep 1 (Step 000310): Train loss 5.551, Val loss 6.138
# Ep 1 (Step 000315): Train loss 5.316, Val loss 6.076
# Ep 1 (Step 000320): Train loss 6.098, Val loss 6.107
# Ep 1 (Step 000325): Train loss 5.554, Val loss 6.045
# Ep 1 (Step 000330): Train loss 5.766, Val loss 6.087
# Ep 1 (Step 000335): Train loss 5.732, Val loss 6.099
# Ep 1 (Step 000340): Train loss 6.324, Val loss 6.089
# Ep 1 (Step 000345): Train loss 5.718, Val loss 6.079
# Ep 1 (Step 000350): Train loss 6.108, Val loss 6.206
# Ep 1 (Step 000355): Train loss 5.776, Val loss 5.995
# Ep 1 (Step 000360): Train loss 6.126, Val loss 6.044
# Ep 1 (Step 000365): Train loss 5.838, Val loss 5.985
# Ep 1 (Step 000370): Train loss 5.512, Val loss 5.952
# Ep 1 (Step 000375): Train loss 5.569, Val loss 5.946
# Ep 1 (Step 000380): Train loss 5.860, Val loss 6.033
# Ep 1 (Step 000385): Train loss 5.817, Val loss 6.092
# Ep 1 (Step 000390): Train loss 5.500, Val loss 5.991
# Ep 1 (Step 000395): Train loss 5.440, Val loss 5.931
# Ep 1 (Step 000400): Train loss 5.914, Val loss 5.969
# Ep 1 (Step 000405): Train loss 5.258, Val loss 5.896
# Ep 1 (Step 000410): Train loss 5.838, Val loss 5.987
# Ep 1 (Step 000415): Train loss 5.635, Val loss 5.917
# Ep 1 (Step 000420): Train loss 6.042, Val loss 5.920
# Ep 1 (Step 000425): Train loss 5.873, Val loss 5.918
# Ep 1 (Step 000430): Train loss 5.438, Val loss 5.936
# Ep 1 (Step 000435): Train loss 4.826, Val loss 5.970
# Ep 1 (Step 000440): Train loss 5.116, Val loss 5.927
# Ep 1 (Step 000445): Train loss 5.631, Val loss 5.865
# Ep 1 (Step 000450): Train loss 5.476, Val loss 5.806
# Ep 1 (Step 000455): Train loss 5.638, Val loss 5.780
# Ep 1 (Step 000460): Train loss 5.594, Val loss 5.881
# Ep 1 (Step 000465): Train loss 5.209, Val loss 5.855
# Ep 1 (Step 000470): Train loss 5.044, Val loss 5.759
# Ep 1 (Step 000475): Train loss 5.600, Val loss 5.859
# Ep 1 (Step 000480): Train loss 5.614, Val loss 5.775
# Ep 1 (Step 000485): Train loss 4.962, Val loss 5.802
# Ep 1 (Step 000490): Train loss 5.580, Val loss 5.793
# Ep 1 (Step 000495): Train loss 5.503, Val loss 5.740
# Ep 1 (Step 000500): Train loss 5.459, Val loss 5.809
# Ep 1 (Step 000505): Train loss 5.183, Val loss 5.789
# Ep 1 (Step 000510): Train loss 5.472, Val loss 5.766
# Ep 1 (Step 000515): Train loss 5.490, Val loss 5.756
# Ep 1 (Step 000520): Train loss 5.859, Val loss 5.790
# Ep 1 (Step 000525): Train loss 5.167, Val loss 5.741
# Ep 1 (Step 000530): Train loss 5.360, Val loss 5.791
# Ep 1 (Step 000535): Train loss 6.042, Val loss 5.688
# Ep 1 (Step 000540): Train loss 4.487, Val loss 5.814
# Ep 1 (Step 000545): Train loss 5.533, Val loss 5.717
# Ep 1 (Step 000550): Train loss 5.535, Val loss 5.698
# Ep 1 (Step 000555): Train loss 5.044, Val loss 5.799
# Ep 1 (Step 000560): Train loss 5.358, Val loss 5.740
# Ep 1 (Step 000565): Train loss 5.765, Val loss 5.640
# Ep 1 (Step 000570): Train loss 5.425, Val loss 5.698
# Ep 1 (Step 000575): Train loss 5.319, Val loss 5.742
# Ep 1 (Step 000580): Train loss 4.527, Val loss 5.732
# Ep 1 (Step 000585): Train loss 5.554, Val loss 5.755
# Ep 1 (Step 000590): Train loss 5.666, Val loss 5.691
# Ep 1 (Step 000595): Train loss 5.299, Val loss 5.640
# Ep 1 (Step 000600): Train loss 5.198, Val loss 5.633
# Ep 1 (Step 000605): Train loss 5.473, Val loss 5.686
# Ep 1 (Step 000610): Train loss 5.447, Val loss 5.639
# Ep 1 (Step 000615): Train loss 5.688, Val loss 5.685
# Ep 1 (Step 000620): Train loss 5.322, Val loss 5.712
# Ep 1 (Step 000625): Train loss 5.568, Val loss 5.623
# Ep 1 (Step 000630): Train loss 5.332, Val loss 5.722
# Ep 1 (Step 000635): Train loss 5.149, Val loss 5.596
# Ep 1 (Step 000640): Train loss 5.666, Val loss 5.643
# Ep 1 (Step 000645): Train loss 5.398, Val loss 5.674
# Ep 1 (Step 000650): Train loss 5.539, Val loss 5.652
# Ep 1 (Step 000655): Train loss 4.931, Val loss 5.657
# Ep 1 (Step 000660): Train loss 6.270, Val loss 5.632
# Ep 1 (Step 000665): Train loss 5.061, Val loss 5.591
# Ep 1 (Step 000670): Train loss 5.457, Val loss 5.629
# Ep 1 (Step 000675): Train loss 5.161, Val loss 5.751
# Ep 1 (Step 000680): Train loss 5.709, Val loss 5.624
# Ep 1 (Step 000685): Train loss 5.251, Val loss 5.616
# Ep 1 (Step 000690): Train loss 5.316, Val loss 5.658
# Ep 1 (Step 000695): Train loss 5.842, Val loss 5.570
# Ep 1 (Step 000700): Train loss 5.379, Val loss 5.572
# Ep 1 (Step 000705): Train loss 4.907, Val loss 5.576
# Ep 1 (Step 000710): Train loss 5.306, Val loss 5.513
# Ep 1 (Step 000715): Train loss 5.263, Val loss 5.582
# Ep 1 (Step 000720): Train loss 5.005, Val loss 5.556
# Ep 1 (Step 000725): Train loss 5.421, Val loss 5.544
# Ep 1 (Step 000730): Train loss 5.960, Val loss 5.536
# Ep 1 (Step 000735): Train loss 5.122, Val loss 5.599
# Ep 1 (Step 000740): Train loss 5.093, Val loss 5.560
# Ep 1 (Step 000745): Train loss 5.095, Val loss 5.579
# Ep 1 (Step 000750): Train loss 4.695, Val loss 5.657
# Ep 1 (Step 000755): Train loss 5.622, Val loss 5.620
# Ep 1 (Step 000760): Train loss 5.168, Val loss 5.555
# Ep 1 (Step 000765): Train loss 5.223, Val loss 5.567
# Ep 1 (Step 000770): Train loss 5.216, Val loss 5.562
# Ep 1 (Step 000775): Train loss 5.322, Val loss 5.541
# Ep 1 (Step 000780): Train loss 5.008, Val loss 5.509
# Ep 1 (Step 000785): Train loss 5.202, Val loss 5.536
# Ep 1 (Step 000790): Train loss 4.751, Val loss 5.503
# Ep 1 (Step 000795): Train loss 5.422, Val loss 5.527
# Ep 1 (Step 000800): Train loss 5.270, Val loss 5.532
# Ep 1 (Step 000805): Train loss 5.637, Val loss 5.525
# Ep 1 (Step 000810): Train loss 4.612, Val loss 5.550
# Ep 1 (Step 000815): Train loss 4.847, Val loss 5.521
# Ep 1 (Step 000820): Train loss 4.856, Val loss 5.535
# Ep 1 (Step 000825): Train loss 4.415, Val loss 5.613
# Ep 1 (Step 000830): Train loss 5.019, Val loss 5.504
# Ep 1 (Step 000835): Train loss 5.722, Val loss 5.576
# Ep 1 (Step 000840): Train loss 5.546, Val loss 5.536
# Ep 1 (Step 000845): Train loss 5.070, Val loss 5.587
# Ep 1 (Step 000850): Train loss 4.674, Val loss 5.505
# Ep 1 (Step 000855): Train loss 4.902, Val loss 5.535
# Ep 1 (Step 000860): Train loss 5.147, Val loss 5.520
# Ep 1 (Step 000865): Train loss 5.022, Val loss 5.472
# Ep 1 (Step 000870): Train loss 5.030, Val loss 5.546
# Ep 1 (Step 000875): Train loss 4.829, Val loss 5.508
# Ep 1 (Step 000880): Train loss 5.523, Val loss 5.504
# Ep 1 (Step 000885): Train loss 4.814, Val loss 5.464
# Ep 1 (Step 000890): Train loss 4.581, Val loss 5.496
# Ep 1 (Step 000895): Train loss 5.068, Val loss 5.551
# Ep 1 (Step 000900): Train loss 4.875, Val loss 5.460
# Ep 1 (Step 000905): Train loss 4.305, Val loss 5.461
# He said we came here, but I am afraid, and I am afraid I am afraid, and I am afraid, and I am afraid I am afraid, and I am afraid, and I am afraid, and I am afraid I am afraid, and I am afraid I
# Ep 2 (Step 000910): Train loss 5.369, Val loss 5.485
# Ep 2 (Step 000915): Train loss 4.931, Val loss 5.456
# Ep 2 (Step 000920): Train loss 5.137, Val loss 5.459
# Ep 2 (Step 000925): Train loss 5.241, Val loss 5.379
# Ep 2 (Step 000930): Train loss 5.109, Val loss 5.418
# Ep 2 (Step 000935): Train loss 5.205, Val loss 5.474
# Ep 2 (Step 000940): Train loss 4.647, Val loss 5.388
# Ep 2 (Step 000945): Train loss 4.967, Val loss 5.445
# Ep 2 (Step 000950): Train loss 5.185, Val loss 5.447
# Ep 2 (Step 000955): Train loss 4.563, Val loss 5.444
# Ep 2 (Step 000960): Train loss 4.828, Val loss 5.503
# Ep 2 (Step 000965): Train loss 4.880, Val loss 5.463
# Ep 2 (Step 000970): Train loss 4.818, Val loss 5.451
# Ep 2 (Step 000975): Train loss 5.291, Val loss 5.503
# Ep 2 (Step 000980): Train loss 4.584, Val loss 5.462
# Ep 2 (Step 000985): Train loss 5.048, Val loss 5.503
# Ep 2 (Step 000990): Train loss 4.918, Val loss 5.414
# Ep 2 (Step 000995): Train loss 5.072, Val loss 5.465
# Ep 2 (Step 001000): Train loss 5.174, Val loss 5.431
# Ep 2 (Step 001005): Train loss 4.834, Val loss 5.468
# Ep 2 (Step 001010): Train loss 4.384, Val loss 5.422
# Ep 2 (Step 001015): Train loss 5.115, Val loss 5.422
# Ep 2 (Step 001020): Train loss 5.473, Val loss 5.464
# Ep 2 (Step 001025): Train loss 5.051, Val loss 5.420
# Ep 2 (Step 001030): Train loss 4.460, Val loss 5.459
# Ep 2 (Step 001035): Train loss 5.274, Val loss 5.446
# Ep 2 (Step 001040): Train loss 4.829, Val loss 5.418
# Ep 2 (Step 001045): Train loss 4.673, Val loss 5.466
# Ep 2 (Step 001050): Train loss 5.076, Val loss 5.386
# Ep 2 (Step 001055): Train loss 4.881, Val loss 5.408
# Ep 2 (Step 001060): Train loss 5.271, Val loss 5.354
# Ep 2 (Step 001065): Train loss 5.460, Val loss 5.424
# Ep 2 (Step 001070): Train loss 4.760, Val loss 5.408
# Ep 2 (Step 001075): Train loss 4.826, Val loss 5.342
# Ep 2 (Step 001080): Train loss 4.893, Val loss 5.388
# Ep 2 (Step 001085): Train loss 5.412, Val loss 5.351
# Ep 2 (Step 001090): Train loss 5.244, Val loss 5.341
# Ep 2 (Step 001095): Train loss 4.632, Val loss 5.400
# Ep 2 (Step 001100): Train loss 4.974, Val loss 5.368
# Ep 2 (Step 001105): Train loss 4.881, Val loss 5.379
# Ep 2 (Step 001110): Train loss 4.366, Val loss 5.359
# Ep 2 (Step 001115): Train loss 5.187, Val loss 5.383
# Ep 2 (Step 001120): Train loss 5.321, Val loss 5.373
# Ep 2 (Step 001125): Train loss 4.716, Val loss 5.389
# Ep 2 (Step 001130): Train loss 5.117, Val loss 5.336
# Ep 2 (Step 001135): Train loss 4.990, Val loss 5.317
# Ep 2 (Step 001140): Train loss 4.958, Val loss 5.340
# Ep 2 (Step 001145): Train loss 4.486, Val loss 5.332
# Ep 2 (Step 001150): Train loss 4.916, Val loss 5.331
# Ep 2 (Step 001155): Train loss 4.650, Val loss 5.294
# Ep 2 (Step 001160): Train loss 4.948, Val loss 5.286
# Ep 2 (Step 001165): Train loss 4.503, Val loss 5.394
# Ep 2 (Step 001170): Train loss 4.364, Val loss 5.406
# Ep 2 (Step 001175): Train loss 5.005, Val loss 5.365
# Ep 2 (Step 001180): Train loss 4.542, Val loss 5.379
# Ep 2 (Step 001185): Train loss 4.782, Val loss 5.394
# Ep 2 (Step 001190): Train loss 4.599, Val loss 5.370
# Ep 2 (Step 001195): Train loss 5.503, Val loss 5.399
# Ep 2 (Step 001200): Train loss 4.901, Val loss 5.393
# Ep 2 (Step 001205): Train loss 4.738, Val loss 5.373
# Ep 2 (Step 001210): Train loss 5.141, Val loss 5.366
# Ep 2 (Step 001215): Train loss 4.354, Val loss 5.403
# Ep 2 (Step 001220): Train loss 4.763, Val loss 5.381
# Ep 2 (Step 001225): Train loss 5.327, Val loss 5.406
# Ep 2 (Step 001230): Train loss 4.401, Val loss 5.361
# Ep 2 (Step 001235): Train loss 5.340, Val loss 5.353
# Ep 2 (Step 001240): Train loss 4.313, Val loss 5.424
# Ep 2 (Step 001245): Train loss 5.006, Val loss 5.329
# Ep 2 (Step 001250): Train loss 4.969, Val loss 5.348
# Ep 2 (Step 001255): Train loss 4.749, Val loss 5.323
# Ep 2 (Step 001260): Train loss 4.714, Val loss 5.326
# Ep 2 (Step 001265): Train loss 4.262, Val loss 5.319
# Ep 2 (Step 001270): Train loss 4.612, Val loss 5.372
# Ep 2 (Step 001275): Train loss 4.586, Val loss 5.342
# Ep 2 (Step 001280): Train loss 4.857, Val loss 5.330
# Ep 2 (Step 001285): Train loss 4.628, Val loss 5.337
# Ep 2 (Step 001290): Train loss 5.650, Val loss 5.355
# Ep 2 (Step 001295): Train loss 4.151, Val loss 5.367
# Ep 2 (Step 001300): Train loss 4.977, Val loss 5.387
# Ep 2 (Step 001305): Train loss 5.229, Val loss 5.376
# Ep 2 (Step 001310): Train loss 4.216, Val loss 5.298
# Ep 2 (Step 001315): Train loss 4.598, Val loss 5.360
# Ep 2 (Step 001320): Train loss 5.326, Val loss 5.354
# Ep 2 (Step 001325): Train loss 4.408, Val loss 5.408
# Ep 2 (Step 001330): Train loss 4.413, Val loss 5.379
# Ep 2 (Step 001335): Train loss 4.310, Val loss 5.354
# Ep 2 (Step 001340): Train loss 4.790, Val loss 5.381
# Ep 2 (Step 001345): Train loss 4.530, Val loss 5.394
# Ep 2 (Step 001350): Train loss 4.930, Val loss 5.283
# Ep 2 (Step 001355): Train loss 5.253, Val loss 5.286
# Ep 2 (Step 001360): Train loss 4.351, Val loss 5.295
# Ep 2 (Step 001365): Train loss 4.357, Val loss 5.298
# Ep 2 (Step 001370): Train loss 5.026, Val loss 5.262
# Ep 2 (Step 001375): Train loss 5.032, Val loss 5.236
# Ep 2 (Step 001380): Train loss 4.627, Val loss 5.299
# Ep 2 (Step 001385): Train loss 5.619, Val loss 5.250
# Ep 2 (Step 001390): Train loss 4.405, Val loss 5.276
# Ep 2 (Step 001395): Train loss 4.862, Val loss 5.250
# Ep 2 (Step 001400): Train loss 5.229, Val loss 5.305
# Ep 2 (Step 001405): Train loss 4.980, Val loss 5.320
# Ep 2 (Step 001410): Train loss 5.022, Val loss 5.261
# Ep 2 (Step 001415): Train loss 4.799, Val loss 5.286
# Ep 2 (Step 001420): Train loss 4.650, Val loss 5.306
# Ep 2 (Step 001425): Train loss 4.440, Val loss 5.248
# Ep 2 (Step 001430): Train loss 4.790, Val loss 5.280
# Ep 2 (Step 001435): Train loss 4.668, Val loss 5.325
# Ep 2 (Step 001440): Train loss 4.448, Val loss 5.260
# Ep 2 (Step 001445): Train loss 5.089, Val loss 5.286
# Ep 2 (Step 001450): Train loss 5.220, Val loss 5.311
# Ep 2 (Step 001455): Train loss 4.498, Val loss 5.213
# Ep 2 (Step 001460): Train loss 5.096, Val loss 5.261
# Ep 2 (Step 001465): Train loss 4.783, Val loss 5.273
# Ep 2 (Step 001470): Train loss 4.620, Val loss 5.235
# Ep 2 (Step 001475): Train loss 4.739, Val loss 5.242
# Ep 2 (Step 001480): Train loss 4.233, Val loss 5.279
# Ep 2 (Step 001485): Train loss 4.817, Val loss 5.300
# Ep 2 (Step 001490): Train loss 4.261, Val loss 5.280
# Ep 2 (Step 001495): Train loss 4.974, Val loss 5.288
# Ep 2 (Step 001500): Train loss 5.443, Val loss 5.237
# Ep 2 (Step 001505): Train loss 4.509, Val loss 5.264
# Ep 2 (Step 001510): Train loss 4.368, Val loss 5.277
# Ep 2 (Step 001515): Train loss 4.075, Val loss 5.235
# Ep 2 (Step 001520): Train loss 4.760, Val loss 5.317
# Ep 2 (Step 001525): Train loss 4.297, Val loss 5.274
# Ep 2 (Step 001530): Train loss 4.677, Val loss 5.291
# Ep 2 (Step 001535): Train loss 4.319, Val loss 5.260
# Ep 2 (Step 001540): Train loss 4.954, Val loss 5.246
# Ep 2 (Step 001545): Train loss 4.319, Val loss 5.222
# Ep 2 (Step 001550): Train loss 4.838, Val loss 5.232
# Ep 2 (Step 001555): Train loss 4.836, Val loss 5.243
# Ep 2 (Step 001560): Train loss 4.682, Val loss 5.194
# Ep 2 (Step 001565): Train loss 4.493, Val loss 5.200
# Ep 2 (Step 001570): Train loss 4.777, Val loss 5.231
# Ep 2 (Step 001575): Train loss 3.959, Val loss 5.207
# Ep 2 (Step 001580): Train loss 4.866, Val loss 5.227
# Ep 2 (Step 001585): Train loss 4.763, Val loss 5.159
# Ep 2 (Step 001590): Train loss 5.538, Val loss 5.191
# Ep 2 (Step 001595): Train loss 4.935, Val loss 5.212
# Ep 2 (Step 001600): Train loss 4.301, Val loss 5.229
# Ep 2 (Step 001605): Train loss 4.651, Val loss 5.250
# Ep 2 (Step 001610): Train loss 4.799, Val loss 5.171
# Ep 2 (Step 001615): Train loss 4.025, Val loss 5.210
# Ep 2 (Step 001620): Train loss 4.567, Val loss 5.191
# Ep 2 (Step 001625): Train loss 4.866, Val loss 5.231
# Ep 2 (Step 001630): Train loss 4.508, Val loss 5.219
# Ep 2 (Step 001635): Train loss 4.717, Val loss 5.210
# Ep 2 (Step 001640): Train loss 4.839, Val loss 5.166
# Ep 2 (Step 001645): Train loss 4.931, Val loss 5.206
# Ep 2 (Step 001650): Train loss 4.100, Val loss 5.172
# Ep 2 (Step 001655): Train loss 3.557, Val loss 5.183
# Ep 2 (Step 001660): Train loss 4.627, Val loss 5.144
# Ep 2 (Step 001665): Train loss 3.811, Val loss 5.193
# Ep 2 (Step 001670): Train loss 4.583, Val loss 5.175
# Ep 2 (Step 001675): Train loss 4.795, Val loss 5.201
# Ep 2 (Step 001680): Train loss 5.050, Val loss 5.194
# Ep 2 (Step 001685): Train loss 4.666, Val loss 5.206
# Ep 2 (Step 001690): Train loss 4.804, Val loss 5.235
# Ep 2 (Step 001695): Train loss 4.338, Val loss 5.187
# Ep 2 (Step 001700): Train loss 3.842, Val loss 5.177
# Ep 2 (Step 001705): Train loss 4.500, Val loss 5.206
# Ep 2 (Step 001710): Train loss 4.627, Val loss 5.180
# Ep 2 (Step 001715): Train loss 4.811, Val loss 5.168
# Ep 2 (Step 001720): Train loss 4.647, Val loss 5.167
# Ep 2 (Step 001725): Train loss 4.599, Val loss 5.148
# Ep 2 (Step 001730): Train loss 4.532, Val loss 5.186
# Ep 2 (Step 001735): Train loss 4.598, Val loss 5.183
# Ep 2 (Step 001740): Train loss 4.396, Val loss 5.179
# Ep 2 (Step 001745): Train loss 4.668, Val loss 5.246
# Ep 2 (Step 001750): Train loss 4.376, Val loss 5.143
# Ep 2 (Step 001755): Train loss 4.325, Val loss 5.154
# Ep 2 (Step 001760): Train loss 4.149, Val loss 5.153
# Ep 2 (Step 001765): Train loss 4.658, Val loss 5.117
# Ep 2 (Step 001770): Train loss 4.269, Val loss 5.136
# Ep 2 (Step 001775): Train loss 4.299, Val loss 5.143
# Ep 2 (Step 001780): Train loss 4.591, Val loss 5.135
# Ep 2 (Step 001785): Train loss 4.513, Val loss 5.187
# Ep 2 (Step 001790): Train loss 4.589, Val loss 5.167
# Ep 2 (Step 001795): Train loss 4.416, Val loss 5.126
# Ep 2 (Step 001800): Train loss 4.249, Val loss 5.121
# Ep 2 (Step 001805): Train loss 4.057, Val loss 5.080
# Ep 2 (Step 001810): Train loss 4.446, Val loss 5.158
# Ep 2 (Step 001815): Train loss 4.242, Val loss 5.137
# He said we came here we shall tell me. We shall tell me.”  “I have no one of my own, I have been   ” “But we shall tell you are near,” ”
# Ep 3 (Step 001820): Train loss 4.735, Val loss 5.148
# Ep 3 (Step 001825): Train loss 4.493, Val loss 5.095
# Ep 3 (Step 001830): Train loss 4.441, Val loss 5.115
# Ep 3 (Step 001835): Train loss 4.510, Val loss 5.131
# Ep 3 (Step 001840): Train loss 4.700, Val loss 5.119
# Ep 3 (Step 001845): Train loss 4.231, Val loss 5.232
# Ep 3 (Step 001850): Train loss 4.082, Val loss 5.131
# Ep 3 (Step 001855): Train loss 4.699, Val loss 5.058
# Ep 3 (Step 001860): Train loss 4.141, Val loss 5.065
# Ep 3 (Step 001865): Train loss 4.209, Val loss 5.135
# Ep 3 (Step 001870): Train loss 4.618, Val loss 5.155
# Ep 3 (Step 001875): Train loss 5.170, Val loss 5.153
# Ep 3 (Step 001880): Train loss 4.792, Val loss 5.079
# Ep 3 (Step 001885): Train loss 4.689, Val loss 5.121
# Ep 3 (Step 001890): Train loss 4.934, Val loss 5.181
# Ep 3 (Step 001895): Train loss 4.396, Val loss 5.136
# Ep 3 (Step 001900): Train loss 4.026, Val loss 5.120
# Ep 3 (Step 001905): Train loss 4.732, Val loss 5.139
# Ep 3 (Step 001910): Train loss 4.856, Val loss 5.167
# Ep 3 (Step 001915): Train loss 4.566, Val loss 5.081
# Ep 3 (Step 001920): Train loss 4.086, Val loss 5.106
# Ep 3 (Step 001925): Train loss 4.697, Val loss 5.149
# Ep 3 (Step 001930): Train loss 4.552, Val loss 5.150
# Ep 3 (Step 001935): Train loss 5.161, Val loss 5.105
# Ep 3 (Step 001940): Train loss 4.173, Val loss 5.157
# Ep 3 (Step 001945): Train loss 4.745, Val loss 5.180
# Ep 3 (Step 001950): Train loss 4.645, Val loss 5.154
# Ep 3 (Step 001955): Train loss 4.485, Val loss 5.126
# Ep 3 (Step 001960): Train loss 4.582, Val loss 5.186
# Ep 3 (Step 001965): Train loss 4.472, Val loss 5.121
# Ep 3 (Step 001970): Train loss 4.747, Val loss 5.066
# Ep 3 (Step 001975): Train loss 4.634, Val loss 5.114
# Ep 3 (Step 001980): Train loss 4.184, Val loss 5.114
# Ep 3 (Step 001985): Train loss 4.529, Val loss 5.094
# Ep 3 (Step 001990): Train loss 4.900, Val loss 5.173
# Ep 3 (Step 001995): Train loss 4.394, Val loss 5.139
# Ep 3 (Step 002000): Train loss 4.553, Val loss 5.192
# Ep 3 (Step 002005): Train loss 4.535, Val loss 5.160
# Ep 3 (Step 002010): Train loss 4.751, Val loss 5.145
# Ep 3 (Step 002015): Train loss 3.775, Val loss 5.116
# Ep 3 (Step 002020): Train loss 4.505, Val loss 5.098
# Ep 3 (Step 002025): Train loss 4.592, Val loss 5.112
# Ep 3 (Step 002030): Train loss 4.037, Val loss 5.096
# Ep 3 (Step 002035): Train loss 4.249, Val loss 5.124
# Ep 3 (Step 002040): Train loss 4.268, Val loss 5.123
# Ep 3 (Step 002045): Train loss 4.300, Val loss 5.132
# Ep 3 (Step 002050): Train loss 4.044, Val loss 5.098
# Ep 3 (Step 002055): Train loss 3.876, Val loss 5.096
# Ep 3 (Step 002060): Train loss 4.336, Val loss 5.129
# Ep 3 (Step 002065): Train loss 4.655, Val loss 5.135
# Ep 3 (Step 002070): Train loss 4.045, Val loss 5.164
# Ep 3 (Step 002075): Train loss 4.461, Val loss 5.179
# Ep 3 (Step 002080): Train loss 4.153, Val loss 5.115
# Ep 3 (Step 002085): Train loss 4.146, Val loss 5.182
# Ep 3 (Step 002090): Train loss 5.052, Val loss 5.110
# Ep 3 (Step 002095): Train loss 4.648, Val loss 5.126
# Ep 3 (Step 002100): Train loss 3.613, Val loss 5.103
# Ep 3 (Step 002105): Train loss 4.349, Val loss 5.081
# Ep 3 (Step 002110): Train loss 4.778, Val loss 5.103
# Ep 3 (Step 002115): Train loss 4.874, Val loss 5.066
# Ep 3 (Step 002120): Train loss 4.768, Val loss 5.110
# Ep 3 (Step 002125): Train loss 3.963, Val loss 5.107
# Ep 3 (Step 002130): Train loss 4.327, Val loss 5.056
# Ep 3 (Step 002135): Train loss 4.415, Val loss 5.104
# Ep 3 (Step 002140): Train loss 4.347, Val loss 5.046
# Ep 3 (Step 002145): Train loss 4.423, Val loss 5.026
# Ep 3 (Step 002150): Train loss 3.810, Val loss 5.104
# Ep 3 (Step 002155): Train loss 4.915, Val loss 5.026
# Ep 3 (Step 002160): Train loss 3.893, Val loss 5.037
# Ep 3 (Step 002165): Train loss 4.315, Val loss 5.061
# Ep 3 (Step 002170): Train loss 4.505, Val loss 4.975
# Ep 3 (Step 002175): Train loss 4.425, Val loss 5.042
# Ep 3 (Step 002180): Train loss 3.916, Val loss 5.036
# Ep 3 (Step 002185): Train loss 3.788, Val loss 5.010
# Ep 3 (Step 002190): Train loss 4.961, Val loss 5.076
# Ep 3 (Step 002195): Train loss 4.253, Val loss 5.060
# Ep 3 (Step 002200): Train loss 4.876, Val loss 5.057
# Ep 3 (Step 002205): Train loss 4.542, Val loss 5.083
# Ep 3 (Step 002210): Train loss 4.675, Val loss 5.025
# Ep 3 (Step 002215): Train loss 3.711, Val loss 4.995
# Ep 3 (Step 002220): Train loss 3.929, Val loss 5.056
# Ep 3 (Step 002225): Train loss 4.970, Val loss 5.014
# Ep 3 (Step 002230): Train loss 4.362, Val loss 4.986
# Ep 3 (Step 002235): Train loss 3.886, Val loss 5.029
# Ep 3 (Step 002240): Train loss 3.721, Val loss 5.033
# Ep 3 (Step 002245): Train loss 3.882, Val loss 5.025
# Ep 3 (Step 002250): Train loss 4.797, Val loss 5.070
# Ep 3 (Step 002255): Train loss 4.237, Val loss 5.042
# Ep 3 (Step 002260): Train loss 4.595, Val loss 5.015
# Ep 3 (Step 002265): Train loss 3.965, Val loss 5.081
# Ep 3 (Step 002270): Train loss 3.910, Val loss 5.061
# Ep 3 (Step 002275): Train loss 5.045, Val loss 5.020
# Ep 3 (Step 002280): Train loss 4.413, Val loss 4.997
# Ep 3 (Step 002285): Train loss 4.677, Val loss 5.089
# Ep 3 (Step 002290): Train loss 4.455, Val loss 5.006
# Ep 3 (Step 002295): Train loss 4.929, Val loss 5.091
# Ep 3 (Step 002300): Train loss 4.710, Val loss 5.116
# Ep 3 (Step 002305): Train loss 5.060, Val loss 5.092
# Ep 3 (Step 002310): Train loss 4.585, Val loss 5.105
# Ep 3 (Step 002315): Train loss 3.698, Val loss 5.025
# Ep 3 (Step 002320): Train loss 4.468, Val loss 5.062
# Ep 3 (Step 002325): Train loss 4.444, Val loss 5.042
# Ep 3 (Step 002330): Train loss 4.603, Val loss 5.018
# Ep 3 (Step 002335): Train loss 3.882, Val loss 5.012
# Ep 3 (Step 002340): Train loss 4.055, Val loss 5.033
# Ep 3 (Step 002345): Train loss 4.175, Val loss 5.016
# Ep 3 (Step 002350): Train loss 4.547, Val loss 4.986
# Ep 3 (Step 002355): Train loss 4.397, Val loss 4.972
# Ep 3 (Step 002360): Train loss 4.180, Val loss 4.986
# Ep 3 (Step 002365): Train loss 3.939, Val loss 5.026
# Ep 3 (Step 002370): Train loss 3.740, Val loss 5.038
# Ep 3 (Step 002375): Train loss 4.909, Val loss 4.976
# Ep 3 (Step 002380): Train loss 4.289, Val loss 5.005
# Ep 3 (Step 002385): Train loss 3.768, Val loss 4.937
# Ep 3 (Step 002390): Train loss 3.908, Val loss 4.954
# Ep 3 (Step 002395): Train loss 4.415, Val loss 4.983
# Ep 3 (Step 002400): Train loss 4.434, Val loss 5.040
# Ep 3 (Step 002405): Train loss 4.316, Val loss 4.981
# Ep 3 (Step 002410): Train loss 4.663, Val loss 5.021
# Ep 3 (Step 002415): Train loss 3.678, Val loss 5.025
# Ep 3 (Step 002420): Train loss 4.358, Val loss 5.028
# Ep 3 (Step 002425): Train loss 3.870, Val loss 5.062
# Ep 3 (Step 002430): Train loss 4.269, Val loss 5.122
# Ep 3 (Step 002435): Train loss 4.369, Val loss 5.095
# Ep 3 (Step 002440): Train loss 4.201, Val loss 4.992
# Ep 3 (Step 002445): Train loss 4.345, Val loss 4.979
# Ep 3 (Step 002450): Train loss 4.522, Val loss 5.034
# Ep 3 (Step 002455): Train loss 4.255, Val loss 5.117
# Ep 3 (Step 002460): Train loss 4.249, Val loss 4.995
# Ep 3 (Step 002465): Train loss 3.878, Val loss 5.020
# Ep 3 (Step 002470): Train loss 4.374, Val loss 5.071
# Ep 3 (Step 002475): Train loss 4.287, Val loss 5.070
# Ep 3 (Step 002480): Train loss 3.890, Val loss 5.034
# Ep 3 (Step 002485): Train loss 4.363, Val loss 4.980
# Ep 3 (Step 002490): Train loss 4.332, Val loss 5.001
# Ep 3 (Step 002495): Train loss 3.293, Val loss 5.025
# Ep 3 (Step 002500): Train loss 3.951, Val loss 5.029
# Ep 3 (Step 002505): Train loss 4.041, Val loss 5.004
# Ep 3 (Step 002510): Train loss 4.047, Val loss 4.995
# Ep 3 (Step 002515): Train loss 3.929, Val loss 5.021
# Ep 3 (Step 002520): Train loss 3.680, Val loss 5.011
# Ep 3 (Step 002525): Train loss 3.694, Val loss 5.013
# Ep 3 (Step 002530): Train loss 4.341, Val loss 5.096
# Ep 3 (Step 002535): Train loss 3.614, Val loss 4.990
# Ep 3 (Step 002540): Train loss 4.099, Val loss 4.990
# Ep 3 (Step 002545): Train loss 4.141, Val loss 4.998
# Ep 3 (Step 002550): Train loss 4.370, Val loss 4.996
# Ep 3 (Step 002555): Train loss 3.971, Val loss 4.977
# Ep 3 (Step 002560): Train loss 4.662, Val loss 4.952
# Ep 3 (Step 002565): Train loss 4.033, Val loss 5.004
# Ep 3 (Step 002570): Train loss 4.088, Val loss 4.975
# Ep 3 (Step 002575): Train loss 3.809, Val loss 4.947
# Ep 3 (Step 002580): Train loss 4.148, Val loss 4.948
# Ep 3 (Step 002585): Train loss 4.245, Val loss 4.920
# Ep 3 (Step 002590): Train loss 4.179, Val loss 4.949
# Ep 3 (Step 002595): Train loss 3.883, Val loss 4.965
# Ep 3 (Step 002600): Train loss 3.987, Val loss 4.999
# Ep 3 (Step 002605): Train loss 4.385, Val loss 4.953
# Ep 3 (Step 002610): Train loss 3.808, Val loss 4.957
# Ep 3 (Step 002615): Train loss 4.293, Val loss 4.935
# Ep 3 (Step 002620): Train loss 4.282, Val loss 4.962
# Ep 3 (Step 002625): Train loss 3.777, Val loss 5.007
# Ep 3 (Step 002630): Train loss 4.590, Val loss 4.957
# Ep 3 (Step 002635): Train loss 4.129, Val loss 4.940
# Ep 3 (Step 002640): Train loss 3.906, Val loss 4.919
# Ep 3 (Step 002645): Train loss 3.555, Val loss 4.941
# Ep 3 (Step 002650): Train loss 4.710, Val loss 4.966
# Ep 3 (Step 002655): Train loss 3.965, Val loss 4.957
# Ep 3 (Step 002660): Train loss 4.468, Val loss 4.981
# Ep 3 (Step 002665): Train loss 3.834, Val loss 4.952
# Ep 3 (Step 002670): Train loss 3.935, Val loss 4.982
# Ep 3 (Step 002675): Train loss 3.749, Val loss 4.950
# Ep 3 (Step 002680): Train loss 4.071, Val loss 4.926
# Ep 3 (Step 002685): Train loss 4.172, Val loss 4.955
# Ep 3 (Step 002690): Train loss 3.846, Val loss 4.963
# Ep 3 (Step 002695): Train loss 4.428, Val loss 4.957
# Ep 3 (Step 002700): Train loss 4.113, Val loss 5.003
# Ep 3 (Step 002705): Train loss 4.005, Val loss 5.008
# Ep 3 (Step 002710): Train loss 3.755, Val loss 4.995
# Ep 3 (Step 002715): Train loss 3.960, Val loss 4.955
# Ep 3 (Step 002720): Train loss 3.760, Val loss 4.953
# He said we came here to me. I know whether I know whether I know. I know that I know that I know that I know whether I know not know that I know. I know to me, and I know that I know. I know. I
# Ep 4 (Step 002725): Train loss 3.853, Val loss 4.919
# Ep 4 (Step 002730): Train loss 3.452, Val loss 4.966
# Ep 4 (Step 002735): Train loss 4.049, Val loss 4.966
# Ep 4 (Step 002740): Train loss 3.543, Val loss 4.943
# Ep 4 (Step 002745): Train loss 4.007, Val loss 5.027
# Ep 4 (Step 002750): Train loss 3.413, Val loss 4.951
# Ep 4 (Step 002755): Train loss 4.220, Val loss 4.969
# Ep 4 (Step 002760): Train loss 4.192, Val loss 4.986
# Ep 4 (Step 002765): Train loss 4.105, Val loss 4.988
# Ep 4 (Step 002770): Train loss 3.611, Val loss 5.001
# Ep 4 (Step 002775): Train loss 3.973, Val loss 4.970
# Ep 4 (Step 002780): Train loss 3.383, Val loss 4.987
# Ep 4 (Step 002785): Train loss 4.191, Val loss 5.008
# Ep 4 (Step 002790): Train loss 3.771, Val loss 5.052
# Ep 4 (Step 002795): Train loss 3.899, Val loss 5.032
# Ep 4 (Step 002800): Train loss 4.202, Val loss 5.031
# Ep 4 (Step 002805): Train loss 4.316, Val loss 5.004
# Ep 4 (Step 002810): Train loss 4.387, Val loss 4.967
# Ep 4 (Step 002815): Train loss 3.775, Val loss 4.993
# Ep 4 (Step 002820): Train loss 4.194, Val loss 4.977
# Ep 4 (Step 002825): Train loss 4.275, Val loss 4.950
# Ep 4 (Step 002830): Train loss 3.987, Val loss 4.952
# Ep 4 (Step 002835): Train loss 3.220, Val loss 4.976
# Ep 4 (Step 002840): Train loss 4.129, Val loss 4.996
# Ep 4 (Step 002845): Train loss 4.241, Val loss 5.023
# Ep 4 (Step 002850): Train loss 3.190, Val loss 5.018
# Ep 4 (Step 002855): Train loss 4.018, Val loss 4.996
# Ep 4 (Step 002860): Train loss 4.129, Val loss 5.018
# Ep 4 (Step 002865): Train loss 3.846, Val loss 5.027
# Ep 4 (Step 002870): Train loss 4.606, Val loss 5.066
# Ep 4 (Step 002875): Train loss 4.046, Val loss 4.995
# Ep 4 (Step 002880): Train loss 3.821, Val loss 4.946
# Ep 4 (Step 002885): Train loss 4.338, Val loss 4.981
# Ep 4 (Step 002890): Train loss 4.236, Val loss 4.919
# Ep 4 (Step 002895): Train loss 4.104, Val loss 4.940
# Ep 4 (Step 002900): Train loss 4.192, Val loss 4.912
# Ep 4 (Step 002905): Train loss 4.482, Val loss 4.951
# Ep 4 (Step 002910): Train loss 3.685, Val loss 4.971
# Ep 4 (Step 002915): Train loss 3.710, Val loss 5.028
# Ep 4 (Step 002920): Train loss 3.476, Val loss 5.031
# Ep 4 (Step 002925): Train loss 3.727, Val loss 5.025
# Ep 4 (Step 002930): Train loss 3.728, Val loss 4.979
# Ep 4 (Step 002935): Train loss 4.530, Val loss 4.992
# Ep 4 (Step 002940): Train loss 3.095, Val loss 5.012
# Ep 4 (Step 002945): Train loss 3.532, Val loss 5.038
# Ep 4 (Step 002950): Train loss 4.627, Val loss 4.974
# Ep 4 (Step 002955): Train loss 3.472, Val loss 4.998
# Ep 4 (Step 002960): Train loss 4.052, Val loss 5.009
# Ep 4 (Step 002965): Train loss 3.774, Val loss 4.998
# Ep 4 (Step 002970): Train loss 4.282, Val loss 4.976
# Ep 4 (Step 002975): Train loss 3.959, Val loss 5.022
# Ep 4 (Step 002980): Train loss 3.248, Val loss 4.957
# Ep 4 (Step 002985): Train loss 3.762, Val loss 4.958
# Ep 4 (Step 002990): Train loss 3.545, Val loss 4.924
# Ep 4 (Step 002995): Train loss 3.721, Val loss 4.953
# Ep 4 (Step 003000): Train loss 3.661, Val loss 4.961
# Ep 4 (Step 003005): Train loss 4.540, Val loss 4.963
# Ep 4 (Step 003010): Train loss 4.205, Val loss 4.989
# Ep 4 (Step 003015): Train loss 3.791, Val loss 4.984
# Ep 4 (Step 003020): Train loss 3.357, Val loss 4.973
# Ep 4 (Step 003025): Train loss 4.072, Val loss 4.983
# Ep 4 (Step 003030): Train loss 4.374, Val loss 5.000
# Ep 4 (Step 003035): Train loss 4.392, Val loss 4.933
# Ep 4 (Step 003040): Train loss 4.428, Val loss 5.008
# Ep 4 (Step 003045): Train loss 3.252, Val loss 5.097
# Ep 4 (Step 003050): Train loss 3.852, Val loss 5.033
# Ep 4 (Step 003055): Train loss 4.150, Val loss 5.060
# Ep 4 (Step 003060): Train loss 4.004, Val loss 5.042
# Ep 4 (Step 003065): Train loss 4.087, Val loss 5.011
# Ep 4 (Step 003070): Train loss 3.809, Val loss 4.980
# Ep 4 (Step 003075): Train loss 3.560, Val loss 5.001
# Ep 4 (Step 003080): Train loss 3.929, Val loss 4.932
# Ep 4 (Step 003085): Train loss 4.105, Val loss 4.966
# Ep 4 (Step 003090): Train loss 3.803, Val loss 4.975
# Ep 4 (Step 003095): Train loss 4.335, Val loss 5.010
# Ep 4 (Step 003100): Train loss 3.063, Val loss 4.978
# Ep 4 (Step 003105): Train loss 3.641, Val loss 4.986
# Ep 4 (Step 003110): Train loss 4.783, Val loss 4.986
# Ep 4 (Step 003115): Train loss 3.863, Val loss 5.016
# Ep 4 (Step 003120): Train loss 4.712, Val loss 5.010
# Ep 4 (Step 003125): Train loss 3.824, Val loss 4.959
# Ep 4 (Step 003130): Train loss 3.081, Val loss 4.963
# Ep 4 (Step 003135): Train loss 3.243, Val loss 5.023
# Ep 4 (Step 003140): Train loss 4.037, Val loss 5.029
# Ep 4 (Step 003145): Train loss 3.432, Val loss 5.000
# Ep 4 (Step 003150): Train loss 3.458, Val loss 4.968
# Ep 4 (Step 003155): Train loss 4.631, Val loss 5.007
# Ep 4 (Step 003160): Train loss 3.744, Val loss 4.981
# Ep 4 (Step 003165): Train loss 3.151, Val loss 5.022
# Ep 4 (Step 003170): Train loss 4.001, Val loss 4.997
# Ep 4 (Step 003175): Train loss 3.445, Val loss 4.985
# Ep 4 (Step 003180): Train loss 3.727, Val loss 5.018
# Ep 4 (Step 003185): Train loss 3.357, Val loss 4.987
# Ep 4 (Step 003190): Train loss 3.895, Val loss 4.939
# Ep 4 (Step 003195): Train loss 3.966, Val loss 4.967
# Ep 4 (Step 003200): Train loss 3.658, Val loss 5.006
# Ep 4 (Step 003205): Train loss 3.645, Val loss 4.957
# Ep 4 (Step 003210): Train loss 3.770, Val loss 4.955
# Ep 4 (Step 003215): Train loss 3.804, Val loss 4.978
# Ep 4 (Step 003220): Train loss 4.051, Val loss 4.942
# Ep 4 (Step 003225): Train loss 3.913, Val loss 4.933
# Ep 4 (Step 003230): Train loss 3.519, Val loss 4.930
# Ep 4 (Step 003235): Train loss 4.239, Val loss 4.978
# Ep 4 (Step 003240): Train loss 3.767, Val loss 4.940
# Ep 4 (Step 003245): Train loss 3.821, Val loss 4.899
# Ep 4 (Step 003250): Train loss 3.961, Val loss 4.984
# Ep 4 (Step 003255): Train loss 4.364, Val loss 4.973
# Ep 4 (Step 003260): Train loss 3.674, Val loss 4.937
# Ep 4 (Step 003265): Train loss 3.601, Val loss 4.980
# Ep 4 (Step 003270): Train loss 3.846, Val loss 4.976
# Ep 4 (Step 003275): Train loss 3.669, Val loss 4.955
# Ep 4 (Step 003280): Train loss 3.868, Val loss 4.940
# Ep 4 (Step 003285): Train loss 3.992, Val loss 4.940
# Ep 4 (Step 003290): Train loss 4.312, Val loss 4.948
# Ep 4 (Step 003295): Train loss 3.417, Val loss 4.946
# Ep 4 (Step 003300): Train loss 3.848, Val loss 4.941
# Ep 4 (Step 003305): Train loss 3.667, Val loss 4.926
# Ep 4 (Step 003310): Train loss 3.388, Val loss 4.916
# Ep 4 (Step 003315): Train loss 4.384, Val loss 4.875
# Ep 4 (Step 003320): Train loss 3.757, Val loss 4.907
# Ep 4 (Step 003325): Train loss 3.463, Val loss 4.936
# Ep 4 (Step 003330): Train loss 3.593, Val loss 4.932
# Ep 4 (Step 003335): Train loss 3.593, Val loss 4.958
# Ep 4 (Step 003340): Train loss 3.184, Val loss 4.938
# Ep 4 (Step 003345): Train loss 4.244, Val loss 4.877
# Ep 4 (Step 003350): Train loss 4.423, Val loss 4.870
# Ep 4 (Step 003355): Train loss 3.832, Val loss 4.870
# Ep 4 (Step 003360): Train loss 3.911, Val loss 4.840
# Ep 4 (Step 003365): Train loss 3.445, Val loss 4.867
# Ep 4 (Step 003370): Train loss 3.487, Val loss 4.971
# Ep 4 (Step 003375): Train loss 4.170, Val loss 4.920
# Ep 4 (Step 003380): Train loss 4.235, Val loss 4.895
# Ep 4 (Step 003385): Train loss 3.364, Val loss 4.887
# Ep 4 (Step 003390): Train loss 3.507, Val loss 4.867
# Ep 4 (Step 003395): Train loss 3.545, Val loss 4.878
# Ep 4 (Step 003400): Train loss 3.822, Val loss 4.852
# Ep 4 (Step 003405): Train loss 3.704, Val loss 4.848
# Ep 4 (Step 003410): Train loss 3.947, Val loss 4.895
# Ep 4 (Step 003415): Train loss 4.443, Val loss 4.888
# Ep 4 (Step 003420): Train loss 3.783, Val loss 4.909
# Ep 4 (Step 003425): Train loss 3.510, Val loss 4.911
# Ep 4 (Step 003430): Train loss 3.598, Val loss 4.915
# Ep 4 (Step 003435): Train loss 2.983, Val loss 4.942
# Ep 4 (Step 003440): Train loss 3.657, Val loss 4.959
# Ep 4 (Step 003445): Train loss 3.937, Val loss 4.947
# Ep 4 (Step 003450): Train loss 3.655, Val loss 4.880
# Ep 4 (Step 003455): Train loss 3.052, Val loss 4.860
# Ep 4 (Step 003460): Train loss 3.349, Val loss 4.837
# Ep 4 (Step 003465): Train loss 3.765, Val loss 4.817
# Ep 4 (Step 003470): Train loss 3.940, Val loss 4.825
# Ep 4 (Step 003475): Train loss 3.479, Val loss 4.806
# Ep 4 (Step 003480): Train loss 3.490, Val loss 4.870
# Ep 4 (Step 003485): Train loss 4.046, Val loss 4.838
# Ep 4 (Step 003490): Train loss 3.667, Val loss 4.859
# Ep 4 (Step 003495): Train loss 3.331, Val loss 4.851
# Ep 4 (Step 003500): Train loss 3.767, Val loss 4.849
# Ep 4 (Step 003505): Train loss 3.224, Val loss 4.833
# Ep 4 (Step 003510): Train loss 4.070, Val loss 4.856
# Ep 4 (Step 003515): Train loss 3.782, Val loss 4.865
# Ep 4 (Step 003520): Train loss 3.670, Val loss 4.896
# Ep 4 (Step 003525): Train loss 3.195, Val loss 4.886
# Ep 4 (Step 003530): Train loss 3.781, Val loss 4.901
# Ep 4 (Step 003535): Train loss 3.598, Val loss 4.842
# Ep 4 (Step 003540): Train loss 4.040, Val loss 4.865
# Ep 4 (Step 003545): Train loss 3.806, Val loss 4.863
# Ep 4 (Step 003550): Train loss 3.697, Val loss 4.816
# Ep 4 (Step 003555): Train loss 4.070, Val loss 4.828
# Ep 4 (Step 003560): Train loss 3.585, Val loss 4.823
# Ep 4 (Step 003565): Train loss 3.552, Val loss 4.843
# Ep 4 (Step 003570): Train loss 3.631, Val loss 4.814
# Ep 4 (Step 003575): Train loss 3.793, Val loss 4.847
# Ep 4 (Step 003580): Train loss 3.473, Val loss 4.866
# Ep 4 (Step 003585): Train loss 3.924, Val loss 4.902
# Ep 4 (Step 003590): Train loss 3.390, Val loss 4.913
# Ep 4 (Step 003595): Train loss 3.895, Val loss 4.848
# Ep 4 (Step 003600): Train loss 3.915, Val loss 4.759
# Ep 4 (Step 003605): Train loss 3.702, Val loss 4.767
# Ep 4 (Step 003610): Train loss 3.808, Val loss 4.796
# Ep 4 (Step 003615): Train loss 3.493, Val loss 4.820
# Ep 4 (Step 003620): Train loss 3.455, Val loss 4.815
# Ep 4 (Step 003625): Train loss 3.075, Val loss 4.846
# Ep 4 (Step 003630): Train loss 3.649, Val loss 4.818
# He said we came here, and he has given him. He has been a few minutes, and could see how far off. He came back, and then I am afraid, and then, and I am not to me. I am afraid, and could see
# Ep 5 (Step 003635): Train loss 3.539, Val loss 4.778
# Ep 5 (Step 003640): Train loss 2.750, Val loss 4.804
# Ep 5 (Step 003645): Train loss 3.620, Val loss 4.824
# Ep 5 (Step 003650): Train loss 3.730, Val loss 4.867
# Ep 5 (Step 003655): Train loss 3.986, Val loss 4.911
# Ep 5 (Step 003660): Train loss 2.973, Val loss 4.878
# Ep 5 (Step 003665): Train loss 3.255, Val loss 4.920
# Ep 5 (Step 003670): Train loss 3.939, Val loss 4.894
# Ep 5 (Step 003675): Train loss 3.431, Val loss 4.949
# Ep 5 (Step 003680): Train loss 3.729, Val loss 4.940
# Ep 5 (Step 003685): Train loss 3.749, Val loss 4.958
# Ep 5 (Step 003690): Train loss 3.938, Val loss 4.991
# Ep 5 (Step 003695): Train loss 3.525, Val loss 4.986
# Ep 5 (Step 003700): Train loss 2.970, Val loss 4.956
# Ep 5 (Step 003705): Train loss 2.762, Val loss 4.957
# Ep 5 (Step 003710): Train loss 3.679, Val loss 4.972
# Ep 5 (Step 003715): Train loss 3.125, Val loss 4.968
# Ep 5 (Step 003720): Train loss 4.105, Val loss 4.987
# Ep 5 (Step 003725): Train loss 3.761, Val loss 4.970
# Ep 5 (Step 003730): Train loss 2.944, Val loss 4.979
# Ep 5 (Step 003735): Train loss 3.878, Val loss 4.968
# Ep 5 (Step 003740): Train loss 3.593, Val loss 4.975
# Ep 5 (Step 003745): Train loss 3.394, Val loss 4.949
# Ep 5 (Step 003750): Train loss 4.016, Val loss 4.972
# Ep 5 (Step 003755): Train loss 3.413, Val loss 5.029
# Ep 5 (Step 003760): Train loss 3.489, Val loss 4.954
# Ep 5 (Step 003765): Train loss 3.512, Val loss 4.952
# Ep 5 (Step 003770): Train loss 3.519, Val loss 4.952
# Ep 5 (Step 003775): Train loss 2.792, Val loss 4.902
# Ep 5 (Step 003780): Train loss 3.471, Val loss 4.984
# Ep 5 (Step 003785): Train loss 3.290, Val loss 4.978
# Ep 5 (Step 003790): Train loss 3.130, Val loss 4.969
# Ep 5 (Step 003795): Train loss 3.106, Val loss 4.953
# Ep 5 (Step 003800): Train loss 3.699, Val loss 4.984
# Ep 5 (Step 003805): Train loss 3.274, Val loss 4.930
# Ep 5 (Step 003810): Train loss 3.750, Val loss 4.958
# Ep 5 (Step 003815): Train loss 3.366, Val loss 4.900
# Ep 5 (Step 003820): Train loss 3.513, Val loss 4.947
# Ep 5 (Step 003825): Train loss 3.881, Val loss 4.962
# Ep 5 (Step 003830): Train loss 3.479, Val loss 4.919
# Ep 5 (Step 003835): Train loss 3.575, Val loss 4.924
# Ep 5 (Step 003840): Train loss 3.574, Val loss 4.938
# Ep 5 (Step 003845): Train loss 3.697, Val loss 4.890
# Ep 5 (Step 003850): Train loss 3.594, Val loss 4.932
# Ep 5 (Step 003855): Train loss 3.635, Val loss 4.979
# Ep 5 (Step 003860): Train loss 3.514, Val loss 4.960
# Ep 5 (Step 003865): Train loss 3.696, Val loss 4.945
# Ep 5 (Step 003870): Train loss 3.032, Val loss 4.978
# Ep 5 (Step 003875): Train loss 3.823, Val loss 4.961
# Ep 5 (Step 003880): Train loss 3.883, Val loss 4.933
# Ep 5 (Step 003885): Train loss 3.299, Val loss 4.971
# Ep 5 (Step 003890): Train loss 3.030, Val loss 4.970
# Ep 5 (Step 003895): Train loss 3.379, Val loss 4.961
# Ep 5 (Step 003900): Train loss 3.388, Val loss 4.967
# Ep 5 (Step 003905): Train loss 2.589, Val loss 4.937
# Ep 5 (Step 003910): Train loss 3.348, Val loss 4.932
# Ep 5 (Step 003915): Train loss 3.266, Val loss 4.897
# Ep 5 (Step 003920): Train loss 2.929, Val loss 4.855
# Ep 5 (Step 003925): Train loss 3.576, Val loss 4.898
# Ep 5 (Step 003930): Train loss 3.513, Val loss 4.918
# Ep 5 (Step 003935): Train loss 2.768, Val loss 4.961
# Ep 5 (Step 003940): Train loss 3.153, Val loss 4.957
# Ep 5 (Step 003945): Train loss 3.172, Val loss 4.921
# Ep 5 (Step 003950): Train loss 3.234, Val loss 4.936
# Ep 5 (Step 003955): Train loss 3.484, Val loss 4.898
# Ep 5 (Step 003960): Train loss 3.204, Val loss 4.884
# Ep 5 (Step 003965): Train loss 3.015, Val loss 4.888
# Ep 5 (Step 003970): Train loss 3.684, Val loss 4.951
# Ep 5 (Step 003975): Train loss 3.478, Val loss 4.895
# Ep 5 (Step 003980): Train loss 3.164, Val loss 4.898
# Ep 5 (Step 003985): Train loss 3.093, Val loss 4.881
# Ep 5 (Step 003990): Train loss 2.827, Val loss 4.853
# Ep 5 (Step 003995): Train loss 3.853, Val loss 4.913
# Ep 5 (Step 004000): Train loss 2.876, Val loss 4.946
# Ep 5 (Step 004005): Train loss 3.027, Val loss 4.914
# Ep 5 (Step 004010): Train loss 2.938, Val loss 4.879
# Ep 5 (Step 004015): Train loss 3.897, Val loss 4.923
# Ep 5 (Step 004020): Train loss 3.619, Val loss 4.909
# Ep 5 (Step 004025): Train loss 3.048, Val loss 4.927
# Ep 5 (Step 004030): Train loss 3.007, Val loss 4.993
# Ep 5 (Step 004035): Train loss 4.125, Val loss 4.945
# Ep 5 (Step 004040): Train loss 2.757, Val loss 4.910
# Ep 5 (Step 004045): Train loss 3.476, Val loss 4.891
# Ep 5 (Step 004050): Train loss 3.620, Val loss 4.887
# Ep 5 (Step 004055): Train loss 4.024, Val loss 4.913
# Ep 5 (Step 004060): Train loss 3.409, Val loss 4.888
# Ep 5 (Step 004065): Train loss 3.200, Val loss 4.916
# Ep 5 (Step 004070): Train loss 3.834, Val loss 4.910
# Ep 5 (Step 004075): Train loss 3.081, Val loss 4.903
# Ep 5 (Step 004080): Train loss 3.232, Val loss 4.927
# Ep 5 (Step 004085): Train loss 3.609, Val loss 4.913
# Ep 5 (Step 004090): Train loss 3.433, Val loss 4.868
# Ep 5 (Step 004095): Train loss 3.212, Val loss 4.901
# Ep 5 (Step 004100): Train loss 3.625, Val loss 4.893
# Ep 5 (Step 004105): Train loss 3.479, Val loss 4.935
# Ep 5 (Step 004110): Train loss 3.019, Val loss 4.953
# Ep 5 (Step 004115): Train loss 3.432, Val loss 4.902
# Ep 5 (Step 004120): Train loss 3.356, Val loss 4.927
# Ep 5 (Step 004125): Train loss 3.399, Val loss 4.882
# Ep 5 (Step 004130): Train loss 3.374, Val loss 4.880
# Ep 5 (Step 004135): Train loss 2.960, Val loss 4.884
# Ep 5 (Step 004140): Train loss 2.326, Val loss 4.848
# Ep 5 (Step 004145): Train loss 2.988, Val loss 4.878
# Ep 5 (Step 004150): Train loss 3.018, Val loss 4.914
# Ep 5 (Step 004155): Train loss 3.436, Val loss 4.915
# Ep 5 (Step 004160): Train loss 3.772, Val loss 4.911
# Ep 5 (Step 004165): Train loss 3.316, Val loss 4.910
# Ep 5 (Step 004170): Train loss 2.844, Val loss 4.898
# Ep 5 (Step 004175): Train loss 3.068, Val loss 4.964
# Ep 5 (Step 004180): Train loss 3.229, Val loss 4.989
# Ep 5 (Step 004185): Train loss 2.962, Val loss 4.926
# Ep 5 (Step 004190): Train loss 3.470, Val loss 4.910
# Ep 5 (Step 004195): Train loss 3.007, Val loss 4.884
# Ep 5 (Step 004200): Train loss 3.462, Val loss 4.907
# Ep 5 (Step 004205): Train loss 3.143, Val loss 4.937
# Ep 5 (Step 004210): Train loss 2.638, Val loss 4.890
# Ep 5 (Step 004215): Train loss 3.133, Val loss 4.878
# Ep 5 (Step 004220): Train loss 2.478, Val loss 4.904
# Ep 5 (Step 004225): Train loss 2.285, Val loss 4.899
# Ep 5 (Step 004230): Train loss 3.670, Val loss 4.939
# Ep 5 (Step 004235): Train loss 4.077, Val loss 4.868
# Ep 5 (Step 004240): Train loss 2.932, Val loss 4.928
# Ep 5 (Step 004245): Train loss 3.194, Val loss 4.867
# Ep 5 (Step 004250): Train loss 3.593, Val loss 4.863
# Ep 5 (Step 004255): Train loss 3.378, Val loss 4.934
# Ep 5 (Step 004260): Train loss 2.923, Val loss 4.856
# Ep 5 (Step 004265): Train loss 3.247, Val loss 4.886
# Ep 5 (Step 004270): Train loss 3.113, Val loss 4.897
# Ep 5 (Step 004275): Train loss 3.078, Val loss 4.930
# Ep 5 (Step 004280): Train loss 3.328, Val loss 4.962
# Ep 5 (Step 004285): Train loss 3.247, Val loss 4.963
# Ep 5 (Step 004290): Train loss 2.275, Val loss 4.903
# Ep 5 (Step 004295): Train loss 3.372, Val loss 4.968
# Ep 5 (Step 004300): Train loss 3.097, Val loss 4.993
# Ep 5 (Step 004305): Train loss 3.282, Val loss 4.952
# Ep 5 (Step 004310): Train loss 2.567, Val loss 4.984
# Ep 5 (Step 004315): Train loss 3.312, Val loss 4.915
# Ep 5 (Step 004320): Train loss 3.075, Val loss 4.933
# Ep 5 (Step 004325): Train loss 4.126, Val loss 4.941
# Ep 5 (Step 004330): Train loss 3.672, Val loss 4.935
# Ep 5 (Step 004335): Train loss 3.229, Val loss 4.913
# Ep 5 (Step 004340): Train loss 4.014, Val loss 4.910
# Ep 5 (Step 004345): Train loss 3.669, Val loss 4.901
# Ep 5 (Step 004350): Train loss 3.481, Val loss 4.929
# Ep 5 (Step 004355): Train loss 3.185, Val loss 4.924
# Ep 5 (Step 004360): Train loss 2.939, Val loss 4.882
# Ep 5 (Step 004365): Train loss 3.126, Val loss 4.924
# Ep 5 (Step 004370): Train loss 2.981, Val loss 4.922
# Ep 5 (Step 004375): Train loss 2.686, Val loss 4.895
# Ep 5 (Step 004380): Train loss 3.418, Val loss 4.928
# Ep 5 (Step 004385): Train loss 3.103, Val loss 4.917
# Ep 5 (Step 004390): Train loss 3.425, Val loss 4.909
# Ep 5 (Step 004395): Train loss 3.470, Val loss 4.962
# Ep 5 (Step 004400): Train loss 3.063, Val loss 4.948
# Ep 5 (Step 004405): Train loss 3.058, Val loss 4.922
# Ep 5 (Step 004410): Train loss 2.791, Val loss 4.961
# Ep 5 (Step 004415): Train loss 3.087, Val loss 4.910
# Ep 5 (Step 004420): Train loss 3.729, Val loss 4.940
# Ep 5 (Step 004425): Train loss 3.259, Val loss 4.922
# Ep 5 (Step 004430): Train loss 3.030, Val loss 4.882
# Ep 5 (Step 004435): Train loss 3.908, Val loss 4.903
# Ep 5 (Step 004440): Train loss 3.643, Val loss 4.923
# Ep 5 (Step 004445): Train loss 2.782, Val loss 4.896
# ...
# Ep 9 (Step 007645): Train loss 1.665, Val loss 5.734
# Ep 9 (Step 007650): Train loss 1.345, Val loss 5.744
# Ep 9 (Step 007655): Train loss 1.761, Val loss 5.799
# Ep 9 (Step 007660): Train loss 1.697, Val loss 5.790
# Ep 9 (Step 007665): Train loss 1.371, Val loss 5.759
# Ep 9 (Step 007670): Train loss 1.319, Val loss 5.881
# Ep 9 (Step 007675): Train loss 0.726, Val loss 5.862
# Ep 9 (Step 007680): Train loss 1.662, Val loss 5.770
# Ep 9 (Step 007685): Train loss 1.115, Val loss 5.821
# Ep 9 (Step 007690): Train loss 1.994, Val loss 5.810
# Ep 9 (Step 007695): Train loss 0.828, Val loss 5.768
# Ep 9 (Step 007700): Train loss 1.886, Val loss 5.772
# Ep 9 (Step 007705): Train loss 1.598, Val loss 5.775
# Ep 9 (Step 007710): Train loss 0.793, Val loss 5.773
# Ep 9 (Step 007715): Train loss 1.130, Val loss 5.743
# Ep 9 (Step 007720): Train loss 1.643, Val loss 5.740
# Ep 9 (Step 007725): Train loss 1.541, Val loss 5.712
# Ep 9 (Step 007730): Train loss 1.445, Val loss 5.786
# Ep 9 (Step 007735): Train loss 1.223, Val loss 5.776
# Ep 9 (Step 007740): Train loss 1.122, Val loss 5.730
# Ep 9 (Step 007745): Train loss 1.694, Val loss 5.756
# Ep 9 (Step 007750): Train loss 0.861, Val loss 5.740
# Ep 9 (Step 007755): Train loss 1.247, Val loss 5.741
# Ep 9 (Step 007760): Train loss 1.270, Val loss 5.751
# Ep 9 (Step 007765): Train loss 1.167, Val loss 5.709
# Ep 9 (Step 007770): Train loss 0.756, Val loss 5.713
# Ep 9 (Step 007775): Train loss 1.114, Val loss 5.742
# Ep 9 (Step 007780): Train loss 1.266, Val loss 5.667
# Ep 9 (Step 007785): Train loss 1.427, Val loss 5.619
# Ep 9 (Step 007790): Train loss 1.356, Val loss 5.691
# Ep 9 (Step 007795): Train loss 0.687, Val loss 5.728
# Ep 9 (Step 007800): Train loss 1.021, Val loss 5.766
# Ep 9 (Step 007805): Train loss 1.371, Val loss 5.805
# Ep 9 (Step 007810): Train loss 0.894, Val loss 5.746
# Ep 9 (Step 007815): Train loss 1.352, Val loss 5.695
# Ep 9 (Step 007820): Train loss 1.048, Val loss 5.717
# Ep 9 (Step 007825): Train loss 1.543, Val loss 5.745
# Ep 9 (Step 007830): Train loss 0.797, Val loss 5.705
# Ep 9 (Step 007835): Train loss 1.316, Val loss 5.682
# Ep 9 (Step 007840): Train loss 1.886, Val loss 5.667
# Ep 9 (Step 007845): Train loss 0.916, Val loss 5.702
# Ep 9 (Step 007850): Train loss 1.356, Val loss 5.752
# Ep 9 (Step 007855): Train loss 1.040, Val loss 5.743
# Ep 9 (Step 007860): Train loss 1.096, Val loss 5.677
# Ep 9 (Step 007865): Train loss 0.961, Val loss 5.680
# Ep 9 (Step 007870): Train loss 0.766, Val loss 5.669
# Ep 9 (Step 007875): Train loss 1.116, Val loss 5.717
# Ep 9 (Step 007880): Train loss 1.909, Val loss 5.706
# Ep 9 (Step 007885): Train loss 1.904, Val loss 5.642
# Ep 9 (Step 007890): Train loss 1.348, Val loss 5.586
# Ep 9 (Step 007895): Train loss 1.373, Val loss 5.682
# Ep 9 (Step 007900): Train loss 1.430, Val loss 5.654
# Ep 9 (Step 007905): Train loss 1.592, Val loss 5.674
# Ep 9 (Step 007910): Train loss 2.079, Val loss 5.717
# Ep 9 (Step 007915): Train loss 1.394, Val loss 5.683
# Ep 9 (Step 007920): Train loss 1.520, Val loss 5.713
# Ep 9 (Step 007925): Train loss 1.554, Val loss 5.745
# Ep 9 (Step 007930): Train loss 1.577, Val loss 5.757
# Ep 9 (Step 007935): Train loss 1.219, Val loss 5.681
# Ep 9 (Step 007940): Train loss 1.138, Val loss 5.596
# Ep 9 (Step 007945): Train loss 0.902, Val loss 5.781
# Ep 9 (Step 007950): Train loss 1.525, Val loss 5.779
# Ep 9 (Step 007955): Train loss 0.702, Val loss 5.706
# Ep 9 (Step 007960): Train loss 1.226, Val loss 5.745
# Ep 9 (Step 007965): Train loss 1.315, Val loss 5.758
# Ep 9 (Step 007970): Train loss 0.908, Val loss 5.778
# Ep 9 (Step 007975): Train loss 0.834, Val loss 5.745
# Ep 9 (Step 007980): Train loss 0.506, Val loss 5.746
# Ep 9 (Step 007985): Train loss 1.042, Val loss 5.756
# Ep 9 (Step 007990): Train loss 1.575, Val loss 5.786
# Ep 9 (Step 007995): Train loss 0.961, Val loss 5.859
# Ep 9 (Step 008000): Train loss 0.918, Val loss 5.840
# Ep 9 (Step 008005): Train loss 1.444, Val loss 5.800
# Ep 9 (Step 008010): Train loss 1.290, Val loss 5.782
# Ep 9 (Step 008015): Train loss 1.039, Val loss 5.809
# Ep 9 (Step 008020): Train loss 1.435, Val loss 5.824
# Ep 9 (Step 008025): Train loss 1.080, Val loss 5.847
# Ep 9 (Step 008030): Train loss 1.614, Val loss 5.838
# Ep 9 (Step 008035): Train loss 1.472, Val loss 5.812
# Ep 9 (Step 008040): Train loss 1.808, Val loss 5.827
# Ep 9 (Step 008045): Train loss 1.393, Val loss 5.795
# Ep 9 (Step 008050): Train loss 1.378, Val loss 5.757
# Ep 9 (Step 008055): Train loss 0.904, Val loss 5.744
# Ep 9 (Step 008060): Train loss 1.325, Val loss 5.709
# Ep 9 (Step 008065): Train loss 1.501, Val loss 5.784
# Ep 9 (Step 008070): Train loss 0.974, Val loss 5.764
# Ep 9 (Step 008075): Train loss 1.395, Val loss 5.785
# Ep 9 (Step 008080): Train loss 1.177, Val loss 5.760
# Ep 9 (Step 008085): Train loss 1.298, Val loss 5.763
# Ep 9 (Step 008090): Train loss 0.753, Val loss 5.805
# Ep 9 (Step 008095): Train loss 1.631, Val loss 5.709
# Ep 9 (Step 008100): Train loss 0.945, Val loss 5.689
# Ep 9 (Step 008105): Train loss 1.033, Val loss 5.750
# Ep 9 (Step 008110): Train loss 1.131, Val loss 5.738
# Ep 9 (Step 008115): Train loss 1.321, Val loss 5.723
# Ep 9 (Step 008120): Train loss 1.019, Val loss 5.693
# Ep 9 (Step 008125): Train loss 1.200, Val loss 5.721
# Ep 9 (Step 008130): Train loss 0.696, Val loss 5.743
# Ep 9 (Step 008135): Train loss 1.040, Val loss 5.827
# Ep 9 (Step 008140): Train loss 1.161, Val loss 5.801
# Ep 9 (Step 008145): Train loss 1.718, Val loss 5.733
# Ep 9 (Step 008150): Train loss 1.141, Val loss 5.700
# Ep 9 (Step 008155): Train loss 0.646, Val loss 5.718
# Ep 9 (Step 008160): Train loss 1.613, Val loss 5.761
# Ep 9 (Step 008165): Train loss 1.253, Val loss 5.678
# Ep 9 (Step 008170): Train loss 1.237, Val loss 5.697
# He said we came here and rest of the world. Knowing of the Count’s seeming, and the earth and tender and there was a film of the floor, and the floating mot which we letters, and a black line of roof, and the driver
# Ep 10 (Step 008175): Train loss 1.181, Val loss 5.877
# Ep 10 (Step 008180): Train loss 1.092, Val loss 6.075
# Ep 10 (Step 008185): Train loss 0.866, Val loss 6.115
# Ep 10 (Step 008190): Train loss 1.056, Val loss 6.062
# Ep 10 (Step 008195): Train loss 1.406, Val loss 5.983
# Ep 10 (Step 008200): Train loss 1.157, Val loss 6.003
# Ep 10 (Step 008205): Train loss 1.130, Val loss 6.020
# Ep 10 (Step 008210): Train loss 0.953, Val loss 6.094
# Ep 10 (Step 008215): Train loss 0.661, Val loss 6.013
# Ep 10 (Step 008220): Train loss 0.967, Val loss 5.986
# Ep 10 (Step 008225): Train loss 1.131, Val loss 5.987
# Ep 10 (Step 008230): Train loss 0.975, Val loss 5.998
# Ep 10 (Step 008235): Train loss 0.746, Val loss 6.129
# Ep 10 (Step 008240): Train loss 0.911, Val loss 6.119
# Ep 10 (Step 008245): Train loss 0.956, Val loss 6.087
# Ep 10 (Step 008250): Train loss 1.093, Val loss 6.138
# Ep 10 (Step 008255): Train loss 0.694, Val loss 6.128
# Ep 10 (Step 008260): Train loss 1.156, Val loss 6.070
# Ep 10 (Step 008265): Train loss 1.156, Val loss 6.064
# Ep 10 (Step 008270): Train loss 0.773, Val loss 6.123
# Ep 10 (Step 008275): Train loss 1.180, Val loss 6.151
# Ep 10 (Step 008280): Train loss 1.235, Val loss 6.190
# Ep 10 (Step 008285): Train loss 0.929, Val loss 6.166
# Ep 10 (Step 008290): Train loss 1.036, Val loss 6.104
# Ep 10 (Step 008295): Train loss 1.313, Val loss 6.209
# Ep 10 (Step 008300): Train loss 1.167, Val loss 6.131
# Ep 10 (Step 008305): Train loss 1.286, Val loss 6.075
# Ep 10 (Step 008310): Train loss 1.083, Val loss 6.135
# Ep 10 (Step 008315): Train loss 1.258, Val loss 6.245
# Ep 10 (Step 008320): Train loss 1.214, Val loss 6.154
# Ep 10 (Step 008325): Train loss 0.643, Val loss 6.121
# Ep 10 (Step 008330): Train loss 0.449, Val loss 6.136
# Ep 10 (Step 008335): Train loss 1.220, Val loss 6.155
# Ep 10 (Step 008340): Train loss 0.640, Val loss 6.149
# Ep 10 (Step 008345): Train loss 0.770, Val loss 6.126
# Ep 10 (Step 008350): Train loss 0.879, Val loss 6.140
# Ep 10 (Step 008355): Train loss 1.245, Val loss 6.153
# Ep 10 (Step 008360): Train loss 1.129, Val loss 6.163
# Ep 10 (Step 008365): Train loss 0.344, Val loss 6.215
# Ep 10 (Step 008370): Train loss 1.125, Val loss 6.234
# Ep 10 (Step 008375): Train loss 0.772, Val loss 6.214
# Ep 10 (Step 008380): Train loss 0.783, Val loss 6.174
# Ep 10 (Step 008385): Train loss 1.100, Val loss 6.261
# Ep 10 (Step 008390): Train loss 1.393, Val loss 6.257
# Ep 10 (Step 008395): Train loss 0.841, Val loss 6.188
# Ep 10 (Step 008400): Train loss 0.922, Val loss 6.149
# Ep 10 (Step 008405): Train loss 1.178, Val loss 6.158
# Ep 10 (Step 008410): Train loss 0.692, Val loss 6.219
# Ep 10 (Step 008415): Train loss 1.316, Val loss 6.222
# Ep 10 (Step 008420): Train loss 1.321, Val loss 6.246
# Ep 10 (Step 008425): Train loss 1.254, Val loss 6.198
# Ep 10 (Step 008430): Train loss 0.800, Val loss 6.175
# Ep 10 (Step 008435): Train loss 1.183, Val loss 6.122
# Ep 10 (Step 008440): Train loss 0.732, Val loss 6.122
# Ep 10 (Step 008445): Train loss 0.483, Val loss 6.152
# Ep 10 (Step 008450): Train loss 1.057, Val loss 6.116
# Ep 10 (Step 008455): Train loss 1.198, Val loss 6.142
# Ep 10 (Step 008460): Train loss 1.281, Val loss 6.185
# Ep 10 (Step 008465): Train loss 1.304, Val loss 6.168
# Ep 10 (Step 008470): Train loss 1.126, Val loss 6.234
# Ep 10 (Step 008475): Train loss 0.769, Val loss 6.275
# Ep 10 (Step 008480): Train loss 1.232, Val loss 6.232
# Ep 10 (Step 008485): Train loss 1.823, Val loss 6.115
# Ep 10 (Step 008490): Train loss 1.272, Val loss 6.094
# Ep 10 (Step 008495): Train loss 0.523, Val loss 6.107
# Ep 10 (Step 008500): Train loss 0.781, Val loss 6.043
# Ep 10 (Step 008505): Train loss 1.189, Val loss 6.158
# Ep 10 (Step 008510): Train loss 0.903, Val loss 6.184
# Ep 10 (Step 008515): Train loss 0.790, Val loss 6.057
# Ep 10 (Step 008520): Train loss 0.994, Val loss 6.088
# Ep 10 (Step 008525): Train loss 0.777, Val loss 6.110
# Ep 10 (Step 008530): Train loss 1.490, Val loss 6.148
# Ep 10 (Step 008535): Train loss 1.247, Val loss 6.112
# Ep 10 (Step 008540): Train loss 0.306, Val loss 6.102
# Ep 10 (Step 008545): Train loss 0.556, Val loss 6.176
# Ep 10 (Step 008550): Train loss 1.252, Val loss 6.113
# Ep 10 (Step 008555): Train loss 0.567, Val loss 6.010
# Ep 10 (Step 008560): Train loss 0.662, Val loss 6.107
# Ep 10 (Step 008565): Train loss 0.807, Val loss 6.143
# Ep 10 (Step 008570): Train loss 1.409, Val loss 6.167
# Ep 10 (Step 008575): Train loss 0.830, Val loss 6.200
# Ep 10 (Step 008580): Train loss 0.469, Val loss 6.171
# Ep 10 (Step 008585): Train loss 0.863, Val loss 6.075
# Ep 10 (Step 008590): Train loss 1.484, Val loss 6.124
# Ep 10 (Step 008595): Train loss 0.791, Val loss 6.148
# Ep 10 (Step 008600): Train loss 0.589, Val loss 6.184
# Ep 10 (Step 008605): Train loss 1.278, Val loss 6.180
# Ep 10 (Step 008610): Train loss 1.117, Val loss 6.124
# Ep 10 (Step 008615): Train loss 1.319, Val loss 6.122
# Ep 10 (Step 008620): Train loss 1.114, Val loss 6.079
# Ep 10 (Step 008625): Train loss 0.870, Val loss 6.097
# Ep 10 (Step 008630): Train loss 1.047, Val loss 6.134
# Ep 10 (Step 008635): Train loss 1.178, Val loss 6.102
# Ep 10 (Step 008640): Train loss 1.028, Val loss 6.079
# Ep 10 (Step 008645): Train loss 0.776, Val loss 6.114
# Ep 10 (Step 008650): Train loss 1.393, Val loss 6.184
# Ep 10 (Step 008655): Train loss 0.794, Val loss 6.170
# Ep 10 (Step 008660): Train loss 0.840, Val loss 6.147
# Ep 10 (Step 008665): Train loss 0.547, Val loss 6.219
# Ep 10 (Step 008670): Train loss 0.972, Val loss 6.233
# Ep 10 (Step 008675): Train loss 0.425, Val loss 6.111
# Ep 10 (Step 008680): Train loss 0.792, Val loss 6.247
# Ep 10 (Step 008685): Train loss 1.018, Val loss 6.155
# Ep 10 (Step 008690): Train loss 1.419, Val loss 6.078
# Ep 10 (Step 008695): Train loss 0.552, Val loss 6.083
# Ep 10 (Step 008700): Train loss 1.331, Val loss 6.040
# Ep 10 (Step 008705): Train loss 1.441, Val loss 6.004
# Ep 10 (Step 008710): Train loss 0.460, Val loss 6.110
# Ep 10 (Step 008715): Train loss 0.683, Val loss 6.161
# Ep 10 (Step 008720): Train loss 1.163, Val loss 6.065
# Ep 10 (Step 008725): Train loss 1.260, Val loss 6.081
# Ep 10 (Step 008730): Train loss 1.443, Val loss 6.067
# Ep 10 (Step 008735): Train loss 0.970, Val loss 6.095
# Ep 10 (Step 008740): Train loss 1.172, Val loss 6.080
# Ep 10 (Step 008745): Train loss 0.982, Val loss 6.025
# Ep 10 (Step 008750): Train loss 0.665, Val loss 6.074
# Ep 10 (Step 008755): Train loss 1.044, Val loss 6.182
# Ep 10 (Step 008760): Train loss 0.646, Val loss 6.162
# Ep 10 (Step 008765): Train loss 0.410, Val loss 6.112
# Ep 10 (Step 008770): Train loss 1.175, Val loss 6.125
# Ep 10 (Step 008775): Train loss 0.688, Val loss 6.094
# Ep 10 (Step 008780): Train loss 0.520, Val loss 6.099
# Ep 10 (Step 008785): Train loss 0.739, Val loss 6.116
# Ep 10 (Step 008790): Train loss 0.686, Val loss 6.119
# Ep 10 (Step 008795): Train loss 0.979, Val loss 6.048
# Ep 10 (Step 008800): Train loss 0.977, Val loss 6.021
# Ep 10 (Step 008805): Train loss 0.790, Val loss 6.060
# Ep 10 (Step 008810): Train loss 1.176, Val loss 6.116
# Ep 10 (Step 008815): Train loss 0.919, Val loss 6.153
# Ep 10 (Step 008820): Train loss 1.423, Val loss 6.000
# Ep 10 (Step 008825): Train loss 1.372, Val loss 6.010
# Ep 10 (Step 008830): Train loss 0.544, Val loss 6.097
# Ep 10 (Step 008835): Train loss 0.986, Val loss 6.057
# Ep 10 (Step 008840): Train loss 0.714, Val loss 6.119
# Ep 10 (Step 008845): Train loss 0.751, Val loss 6.150
# Ep 10 (Step 008850): Train loss 1.096, Val loss 6.091
# Ep 10 (Step 008855): Train loss 0.621, Val loss 6.109
# Ep 10 (Step 008860): Train loss 1.052, Val loss 6.094
# Ep 10 (Step 008865): Train loss 0.919, Val loss 6.066
# Ep 10 (Step 008870): Train loss 1.252, Val loss 6.069
# Ep 10 (Step 008875): Train loss 0.864, Val loss 6.063
# Ep 10 (Step 008880): Train loss 1.481, Val loss 6.005
# Ep 10 (Step 008885): Train loss 0.949, Val loss 6.055
# Ep 10 (Step 008890): Train loss 0.727, Val loss 6.068
# Ep 10 (Step 008895): Train loss 0.946, Val loss 6.011
# Ep 10 (Step 008900): Train loss 0.619, Val loss 6.025
# Ep 10 (Step 008905): Train loss 0.644, Val loss 6.047
# Ep 10 (Step 008910): Train loss 0.991, Val loss 6.058
# Ep 10 (Step 008915): Train loss 0.422, Val loss 6.049
# Ep 10 (Step 008920): Train loss 0.535, Val loss 6.055
# Ep 10 (Step 008925): Train loss 0.937, Val loss 5.985
# Ep 10 (Step 008930): Train loss 0.680, Val loss 5.956
# Ep 10 (Step 008935): Train loss 0.429, Val loss 5.961
# Ep 10 (Step 008940): Train loss 0.665, Val loss 5.978
# Ep 10 (Step 008945): Train loss 0.660, Val loss 5.997
# Ep 10 (Step 008950): Train loss 0.998, Val loss 5.961
# Ep 10 (Step 008955): Train loss 0.659, Val loss 5.949
# Ep 10 (Step 008960): Train loss 0.531, Val loss 5.991
# Ep 10 (Step 008965): Train loss 0.738, Val loss 5.940
# Ep 10 (Step 008970): Train loss 0.657, Val loss 5.967
# Ep 10 (Step 008975): Train loss 0.754, Val loss 5.965
# Ep 10 (Step 008980): Train loss 0.659, Val loss 5.920
# Ep 10 (Step 008985): Train loss 0.971, Val loss 5.827
# Ep 10 (Step 008990): Train loss 0.682, Val loss 5.881
# Ep 10 (Step 008995): Train loss 0.845, Val loss 6.002
# Ep 10 (Step 009000): Train loss 0.838, Val loss 6.083
# Ep 10 (Step 009005): Train loss 0.579, Val loss 6.044
# Ep 10 (Step 009010): Train loss 0.592, Val loss 6.011
# Ep 10 (Step 009015): Train loss 0.700, Val loss 5.994
# Ep 10 (Step 009020): Train loss 0.915, Val loss 6.052
# Ep 10 (Step 009025): Train loss 0.723, Val loss 6.023
# Ep 10 (Step 009030): Train loss 0.752, Val loss 6.012
# Ep 10 (Step 009035): Train loss 0.750, Val loss 5.977
# Ep 10 (Step 009040): Train loss 0.745, Val loss 5.970
# Ep 10 (Step 009045): Train loss 0.615, Val loss 6.029
# Ep 10 (Step 009050): Train loss 0.520, Val loss 6.038
# Ep 10 (Step 009055): Train loss 0.867, Val loss 5.960
# Ep 10 (Step 009060): Train loss 1.070, Val loss 5.997
# Ep 10 (Step 009065): Train loss 0.635, Val loss 6.041
# Ep 10 (Step 009070): Train loss 0.835, Val loss 5.979
# Ep 10 (Step 009075): Train loss 0.724, Val loss 5.847
# He said we came here and rest. I must go out on the time of the strain that amongst it.”  Miss Bartlett, “When you must go to-day?” I got at the summer?”
# Sample output:
#  The tree was evidently torturing his; but he was as his fingers towards the
# deserve of a tower, whose inquiries after a great
#
# All training runs completed in 45.29 minutes.

# %%
import os
os._exit(0)

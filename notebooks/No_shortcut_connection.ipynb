# %%
import os

file_path = "data.txt"

# Check if the file exists in the current directory (i.e., Colab session)
if os.path.exists(file_path):
    with open(file_path, "r", encoding="utf-8") as file:
        text_data = file.read()
    print(f"File '{file_path}' loaded with {len(text_data)} characters.")
else:
    print(f"File '{file_path}' not found. Please upload it to the Colab environment first.")
# Out:
# File 'data.txt' loaded with 1935114 characters.

# %%
# !pip3 install tiktoken > /dev/null 2>&1

# %%
import importlib
import tiktoken

print("tiktoken version:", importlib.metadata.version("tiktoken"))
# Out:
# tiktoken version: 0.9.0

# %%
tokenizer = tiktoken.get_encoding("gpt2")

# %%
text = (
    "Hello, do you like tea? <|endoftext|> In the sunlit terraces"
     "of someunknownPlace."
)

integers = tokenizer.encode(text, allowed_special={"<|endoftext|>"})

print(integers)
# Out:
# [15496, 11, 466, 345, 588, 8887, 30, 220, 50256, 554, 262, 4252, 18250, 8812, 2114, 1659, 617, 34680, 27271, 13]

# %%
integers = tokenizer.encode("Akwirw ier")
print(integers)

strings = tokenizer.decode(integers)
print(strings)
# Out:
# [33901, 86, 343, 86, 220, 959]
# Akwirw ier

# %%
total_characters = len(text_data)
total_tokens = len(tokenizer.encode(text_data))

print("Characters:", total_characters)
print("Tokens:", total_tokens)
# Out:
# Characters: 1935114
# Tokens: 522304

# %%
with open("data.txt", "r", encoding="utf-8") as f:
    raw_text = f.read()

enc_text = tokenizer.encode(raw_text)
print(len(enc_text))
# Out:
# 522304

# %%
from torch.utils.data import Dataset, DataLoader


class GPTDatasetV1(Dataset):
    def __init__(self, txt, tokenizer, max_length, stride):
        self.input_ids = []
        self.target_ids = []

        # Tokenize the entire text
        token_ids = tokenizer.encode(txt, allowed_special={"<|endoftext|>"})

        # Use a sliding window to chunk the book into overlapping sequences of max_length
        for i in range(0, len(token_ids) - max_length, stride):
            input_chunk = token_ids[i:i + max_length]
            target_chunk = token_ids[i + 1: i + max_length + 1]
            self.input_ids.append(torch.tensor(input_chunk))
            self.target_ids.append(torch.tensor(target_chunk))

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return self.input_ids[idx], self.target_ids[idx]

# %%
def create_dataloader_v1(txt, batch_size=4, max_length=256,
                         stride=128, shuffle=True, drop_last=True,
                         num_workers=0):

    # Initialize the tokenizer
    tokenizer = tiktoken.get_encoding("gpt2")

    # Create dataset
    dataset = GPTDatasetV1(txt, tokenizer, max_length, stride)

    # Create dataloader
    dataloader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=shuffle,
        drop_last=drop_last,
        num_workers=num_workers
    )

    return dataloader

# %%
import torch
print("PyTorch version:", torch.__version__)
dataloader = create_dataloader_v1(
    raw_text, batch_size=1, max_length=4, stride=1, shuffle=False
)

data_iter = iter(dataloader)
first_batch = next(data_iter)
print(first_batch)
# Out:
# PyTorch version: 2.6.0+cu124
# [tensor([[   62,    54,  2501, 47958]]), tensor([[   54,  2501, 47958,   468]])]

# %%
vocab_size = 50257
output_dim = 256

token_embedding_layer = torch.nn.Embedding(vocab_size, output_dim)

# %%
max_length = 4
dataloader = create_dataloader_v1(
    raw_text, batch_size=8, max_length=max_length,
    stride=max_length, shuffle=False
)
data_iter = iter(dataloader)
inputs, targets = next(data_iter)

# %%
print("Token IDs:\n", inputs)
print("\nInputs shape:\n", inputs.shape)
# Out:
# Token IDs:
#  tensor([[   62,    54,  2501, 47958],
#         [  468,  7382,   257,  3734],
#         [  290,   655, 12941,  1022],
#         [  564,   250, 33983,   198],
#         [ 1525, 24930,   447,   251],
#         [  290,   564,   250, 33983],
#         [  351,  2614,  1842,    13],
#         [  447,   251,   770, 12941]])
#
# Inputs shape:
#  torch.Size([8, 4])

# %%
token_embeddings = token_embedding_layer(inputs)
print(token_embeddings.shape)
# Out:
# torch.Size([8, 4, 256])

# %%
context_length = max_length
pos_embedding_layer = torch.nn.Embedding(context_length, output_dim)

# %%
pos_embeddings = pos_embedding_layer(torch.arange(max_length))
print(pos_embeddings.shape)
# Out:
# torch.Size([4, 256])

# %%
input_embeddings = token_embeddings + pos_embeddings
print(input_embeddings.shape)
# Out:
# torch.Size([8, 4, 256])

# %%
import torch.nn as nn

class MultiHeadAttention(nn.Module):
    def __init__(self, d_in, d_out, context_length, dropout, num_heads, qkv_bias=False):
        super().__init__()
        assert (d_out % num_heads == 0), \
            "d_out must be divisible by num_heads"

        self.d_out = d_out
        self.num_heads = num_heads
        self.head_dim = d_out // num_heads # Reduce the projection dim to match desired output dim

        self.W_query = nn.Linear(d_in, d_out, bias=qkv_bias)
        self.W_key = nn.Linear(d_in, d_out, bias=qkv_bias)
        self.W_value = nn.Linear(d_in, d_out, bias=qkv_bias)
        self.out_proj = nn.Linear(d_out, d_out)  # Linear layer to combine head outputs
        self.dropout = nn.Dropout(dropout)
        self.register_buffer(
            "mask",
            torch.triu(torch.ones(context_length, context_length),
                       diagonal=1)
        )

    def forward(self, x):
        b, num_tokens, d_in = x.shape

        keys = self.W_key(x) # Shape: (b, num_tokens, d_out)
        queries = self.W_query(x)
        values = self.W_value(x)

        # We implicitly split the matrix by adding a `num_heads` dimension
        # Unroll last dim: (b, num_tokens, d_out) -> (b, num_tokens, num_heads, head_dim)
        keys = keys.view(b, num_tokens, self.num_heads, self.head_dim)
        values = values.view(b, num_tokens, self.num_heads, self.head_dim)
        queries = queries.view(b, num_tokens, self.num_heads, self.head_dim)

        # Transpose: (b, num_tokens, num_heads, head_dim) -> (b, num_heads, num_tokens, head_dim)
        keys = keys.transpose(1, 2)
        queries = queries.transpose(1, 2)
        values = values.transpose(1, 2)

        # Compute scaled dot-product attention (aka self-attention) with a causal mask
        attn_scores = queries @ keys.transpose(2, 3)  # Dot product for each head

        # Original mask truncated to the number of tokens and converted to boolean
        mask_bool = self.mask.bool()[:num_tokens, :num_tokens]

        # Use the mask to fill attention scores
        attn_scores.masked_fill_(mask_bool, -torch.inf)

        attn_weights = torch.softmax(attn_scores / keys.shape[-1]**0.5, dim=-1)
        attn_weights = self.dropout(attn_weights)

        # Shape: (b, num_tokens, num_heads, head_dim)
        context_vec = (attn_weights @ values).transpose(1, 2)

        # Combine heads, where self.d_out = self.num_heads * self.head_dim
        context_vec = context_vec.contiguous().view(b, num_tokens, self.d_out)
        context_vec = self.out_proj(context_vec) # optional projection

        return context_vec

# %%
torch.manual_seed(123)

# Define the tensor with 3 rows and 6 columns
inputs = torch.tensor(
    [[0.43, 0.15, 0.89, 0.55, 0.87, 0.66],  # Row 1
     [0.57, 0.85, 0.64, 0.22, 0.58, 0.33],  # Row 2
     [0.77, 0.25, 0.10, 0.05, 0.80, 0.55]]  # Row 3
)

batch = torch.stack((inputs, inputs), dim=0)
print(batch.shape)

batch_size, context_length, d_in = batch.shape
d_out = 6
mha = MultiHeadAttention(d_in, d_out, context_length, 0.0, num_heads=2)
context_vecs = mha(batch)
print(context_vecs)
print("context_vecs.shape:", context_vecs.shape)
# Out:
# torch.Size([2, 3, 6])
# tensor([[[ 0.1569, -0.0873,  0.0210,  0.0215, -0.3243, -0.2518],
#          [ 0.1117, -0.0547,  0.0406, -0.0213, -0.3251, -0.2993],
#          [ 0.1196, -0.0491,  0.0318, -0.0635, -0.2788, -0.2578]],
#
#         [[ 0.1569, -0.0873,  0.0210,  0.0215, -0.3243, -0.2518],
#          [ 0.1117, -0.0547,  0.0406, -0.0213, -0.3251, -0.2993],
#          [ 0.1196, -0.0491,  0.0318, -0.0635, -0.2788, -0.2578]]],
#        grad_fn=<ViewBackward0>)
# context_vecs.shape: torch.Size([2, 3, 6])

# %%
GPT_CONFIG_124M = {
    "vocab_size": 50257,    # Vocabulary size
    "context_length": 256, # Context length
    "emb_dim": 768,         # Embedding dimension
    "n_heads": 12,          # Number of attention heads
    "n_layers": 12,         # Number of layers
    "drop_rate": 0.1,       # Dropout rate
    "qkv_bias": False       # Query-Key-Value bias
}

# %%
class LayerNorm(nn.Module):
    def __init__(self, emb_dim):
        super().__init__()
        self.eps = 1e-5
        self.scale = nn.Parameter(torch.ones(emb_dim))
        self.shift = nn.Parameter(torch.zeros(emb_dim))

    def forward(self, x):
        mean = x.mean(dim=-1, keepdim=True)
        var = x.var(dim=-1, keepdim=True, unbiased=False)
        norm_x = (x - mean) / torch.sqrt(var + self.eps)
        return self.scale * norm_x + self.shift

class GELU(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, x):
        return 0.5 * x * (1 + torch.tanh(
            torch.sqrt(torch.tensor(2.0 / torch.pi)) *
            (x + 0.044715 * torch.pow(x, 3))
        ))


class FeedForward(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(cfg["emb_dim"], 4 * cfg["emb_dim"]), ## Expansion
            GELU(), ## Activation
            nn.Linear(4 * cfg["emb_dim"], cfg["emb_dim"]), ## Contraction
        )

    def forward(self, x):
        return self.layers(x)

# %%
class TransformerBlock(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.att = MultiHeadAttention(
            d_in=cfg["emb_dim"],
            d_out=cfg["emb_dim"],
            context_length=cfg["context_length"],
            num_heads=cfg["n_heads"],
            dropout=cfg["drop_rate"],
            qkv_bias=cfg["qkv_bias"])
        self.ff = FeedForward(cfg)
        self.norm1 = LayerNorm(cfg["emb_dim"])
        self.norm2 = LayerNorm(cfg["emb_dim"])
        self.drop_shortcut = nn.Dropout(cfg["drop_rate"])

    def forward(self, x):
        # Attention block without residual connection
        x = self.norm1(x)
        x = self.att(x)  # [batch_size, num_tokens, emb_dim]
        x = self.drop_shortcut(x)

        # Feed forward block without residual connection
        x = self.norm2(x)
        x = self.ff(x)
        x = self.drop_shortcut(x)

        return x  # [batch_size, num_tokens, emb_dim]

# %%
class GPTModel(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.tok_emb = nn.Embedding(cfg["vocab_size"], cfg["emb_dim"])
        self.pos_emb = nn.Embedding(cfg["context_length"], cfg["emb_dim"])
        self.drop_emb = nn.Dropout(cfg["drop_rate"])

        self.trf_blocks = nn.Sequential(
            *[TransformerBlock(cfg) for _ in range(cfg["n_layers"])])

        self.final_norm = LayerNorm(cfg["emb_dim"])
        self.out_head = nn.Linear(
            cfg["emb_dim"], cfg["vocab_size"], bias=False
        )

    def forward(self, in_idx):
        batch_size, seq_len = in_idx.shape
        tok_embeds = self.tok_emb(in_idx)
        pos_embeds = self.pos_emb(torch.arange(seq_len, device=in_idx.device))
        x = tok_embeds + pos_embeds  # Shape [batch_size, num_tokens, emb_size]
        x = self.drop_emb(x)
        x = self.trf_blocks(x)
        x = self.final_norm(x)
        logits = self.out_head(x)
        return logits

# %%
torch.manual_seed(123)

batch = []
txt1 = "Every effort moves you"
txt2 = "Every day holds a"
batch.append(torch.tensor(tokenizer.encode(txt1)))
batch.append(torch.tensor(tokenizer.encode(txt2)))
batch = torch.stack(batch, dim=0)

model = GPTModel(GPT_CONFIG_124M)
out = model(batch)
print("Input batch:\n", batch)
print("\nOutput shape:", out.shape)
print(out)
# Out:
# Input batch:
#  tensor([[6109, 3626, 6100,  345],
#         [6109, 1110, 6622,  257]])
#
# Output shape: torch.Size([2, 4, 50257])
# tensor([[[ 0.3348,  0.8508, -0.3247,  ..., -0.0282,  0.3920, -0.9251],
#          [ 0.5963,  0.9122,  0.2411,  ..., -0.1180,  0.0159, -0.5346],
#          [ 0.7441,  1.1711, -0.4037,  ...,  0.4604,  0.0650, -0.2290],
#          [ 0.3736,  0.5875, -0.5062,  ...,  0.4843,  0.6456, -0.5545]],
#
#         [[ 0.2952, -0.7104,  0.0215,  ..., -0.3177,  0.0022, -0.7588],
#          [ 0.3557, -0.2341,  0.4119,  ...,  0.0548,  0.1343, -0.6384],
#          [ 0.6435,  1.0740, -0.1917,  ...,  0.0217, -0.2293, -0.3875],
#          [ 0.0966,  0.2566,  0.3248,  ...,  0.8128, -0.1834, -0.2130]]],
#        grad_fn=<UnsafeViewBackward0>)

# %%
total_params = sum(p.numel() for p in model.parameters())
print(f"Total number of parameters: {total_params:,}")
# Out:
# Total number of parameters: 162,419,712

# %%
print("Token embedding layer shape:", model.tok_emb.weight.shape)
print("Output layer shape:", model.out_head.weight.shape)
# Out:
# Token embedding layer shape: torch.Size([50257, 768])
# Output layer shape: torch.Size([50257, 768])

# %%
total_size_bytes = total_params * 4 #A
total_size_mb = total_size_bytes / (1024 * 1024) #B
print(f"Total size of the model: {total_size_mb:.2f} MB")
# Out:
# Total size of the model: 619.58 MB

# %%
def generate_text_simple(model, idx, max_new_tokens, context_size):
    # idx is (batch, n_tokens) array of indices in the current context

    ###Input batch:
 ###tensor([[6109, 3626, 6100,  345],
        ##[6109, 1110, 6622,  257]])

    for _ in range(max_new_tokens):

        # Crop current context if it exceeds the supported context size
        # E.g., if LLM supports only 5 tokens, and the context size is 10
        # then only the last 5 tokens are used as context
        idx_cond = idx[:, -context_size:]

        # Get the predictions
        with torch.no_grad():
            logits = model(idx_cond) ### batch, n_tokens, vocab_size

        # Focus only on the last time step
        # (batch, n_tokens, vocab_size) becomes (batch, vocab_size)
        logits = logits[:, -1, :]

        # Apply softmax to get probabilities
        probas = torch.softmax(logits, dim=-1)  # (batch, vocab_size)

        # Get the idx of the vocab entry with the highest probability value
        idx_next = torch.argmax(probas, dim=-1, keepdim=True)  # (batch, 1)

        # Append sampled index to the running sequence
        idx = torch.cat((idx, idx_next), dim=1)  # (batch, n_tokens+1)

    return idx

# %%
import tiktoken

def text_to_token_ids(text, tokenizer):
    encoded = tokenizer.encode(text, allowed_special={'<|endoftext|>'})
    encoded_tensor = torch.tensor(encoded).unsqueeze(0) # add batch dimension
    return encoded_tensor

def token_ids_to_text(token_ids, tokenizer):
    flat = token_ids.squeeze(0) # remove batch dimension
    return tokenizer.decode(flat.tolist())

start_context = "He said we came here"



token_ids = generate_text_simple(
    model=model,
    idx=text_to_token_ids(start_context, tokenizer),
    max_new_tokens=10,
    context_size=GPT_CONFIG_124M["context_length"]
)

print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# Output text:
#  He said we came here tul dining excehak scorn mesmer squatsChristmas materially stiffness

# %%
# Train/validation ratio
train_ratio = 0.90
split_idx = int(train_ratio * len(text_data))
train_data = text_data[:split_idx]
val_data = text_data[split_idx:]


torch.manual_seed(123)

train_loader = create_dataloader_v1(
    train_data,
    batch_size=2,
    max_length=GPT_CONFIG_124M["context_length"],
    stride=GPT_CONFIG_124M["context_length"],
    drop_last=True,
    shuffle=True,
    num_workers=0
)

val_loader = create_dataloader_v1(
    val_data,
    batch_size=2,
    max_length=GPT_CONFIG_124M["context_length"],
    stride=GPT_CONFIG_124M["context_length"],
    drop_last=False,
    shuffle=False,
    num_workers=0
)

# %%
def calc_loss_batch(input_batch, target_batch, model, device):
    input_batch, target_batch = input_batch.to(device), target_batch.to(device)
    logits = model(input_batch)
    loss = torch.nn.functional.cross_entropy(logits.flatten(0, 1), target_batch.flatten())
    return loss


def calc_loss_loader(data_loader, model, device, num_batches=None):
    total_loss = 0.
    if len(data_loader) == 0:
        return float("nan")
    elif num_batches is None:
        num_batches = len(data_loader)
    else:
        # Reduce the number of batches to match the total number of batches in the data loader
        # if num_batches exceeds the number of batches in the data loader
        num_batches = min(num_batches, len(data_loader))
    for i, (input_batch, target_batch) in enumerate(data_loader):
        if i < num_batches:
            loss = calc_loss_batch(input_batch, target_batch, model, device)
            total_loss += loss.item()
        else:
            break
    return total_loss / num_batches

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Note:
# Uncommenting the following lines will allow the code to run on Apple Silicon chips, if applicable,
# which is approximately 2x faster than on an Apple CPU (as measured on an M3 MacBook Air).
# However, the resulting loss values may be slightly different.

#if torch.cuda.is_available():
#    device = torch.device("cuda")
#elif torch.backends.mps.is_available():
#    device = torch.device("mps")
#else:
#    device = torch.device("cpu")
#
# print(f"Using {device} device.")


model.to(device) # no assignment model = model.to(device) necessary for nn.Module classes


torch.manual_seed(123) # For reproducibility due to the shuffling in the data loader

with torch.no_grad(): # Disable gradient tracking for efficiency because we are not training, yet
    train_loss = calc_loss_loader(train_loader, model, device)
    val_loss = calc_loss_loader(val_loader, model, device)

print("Training loss:", train_loss)
print("Validation loss:", val_loss)
# Out:
# Training loss: 10.994448243783959
# Validation loss: 11.02231926101822

# %%
print(device)
# Out:
# cuda

# %%
import json

def train_model_simple(model, train_loader, val_loader, optimizer, device, num_epochs,
                       eval_freq, eval_iter, start_context, tokenizer,
                       store_epochs={5, 10, 20, 50, 100, 200, 500},
                       save_path="intermediate_results.json"):

    # Initialize lists to track losses and tokens seen
    train_losses, val_losses, track_tokens_seen = [], [], []
    intermediate_results = {"epoch": [], "train_loss": [], "val_loss": [], "tokens_seen": []}

    tokens_seen, global_step = 0, -1

    def save_results_to_disk(results, path):
        with open(path, "w") as f:
            json.dump(results, f, indent=2)

    # Main training loop
    for epoch in range(1, num_epochs + 1):  # Epoch starts at 1
        model.train()  # Set model to training mode

        for input_batch, target_batch in train_loader:
            optimizer.zero_grad()  # Reset loss gradients from previous batch iteration
            loss = calc_loss_batch(input_batch, target_batch, model, device)
            loss.backward()  # Calculate loss gradients
            optimizer.step()  # Update model weights using loss gradients
            tokens_seen += input_batch.numel()
            global_step += 1

            # Optional evaluation step
            if global_step % eval_freq == 0:
                train_loss, val_loss = evaluate_model(
                    model, train_loader, val_loader, device, eval_iter)
                train_losses.append(train_loss)
                val_losses.append(val_loss)
                track_tokens_seen.append(tokens_seen)
                print(f"Ep {epoch} (Step {global_step:06d}): "
                      f"Train loss {train_loss:.3f}, Val loss {val_loss:.3f}")

        # Store intermediate results if this epoch is in store_epochs
        if epoch in store_epochs:
            # Perform evaluation if not already done in last step of epoch
            if not (global_step % eval_freq == 0):
                train_loss, val_loss = evaluate_model(
                    model, train_loader, val_loader, device, eval_iter)
                train_losses.append(train_loss)
                val_losses.append(val_loss)
                track_tokens_seen.append(tokens_seen)

            intermediate_results["epoch"].append(epoch)
            intermediate_results["train_loss"].append(train_loss)
            intermediate_results["val_loss"].append(val_loss)
            intermediate_results["tokens_seen"].append(tokens_seen)
            save_results_to_disk(intermediate_results, save_path)

        # Print a sample text after each epoch
        generate_and_print_sample(model, tokenizer, device, start_context)

    return train_losses, val_losses, track_tokens_seen

# %%
def evaluate_model(model, train_loader, val_loader, device, eval_iter):
    model.eval()
    with torch.no_grad():
        train_loss = calc_loss_loader(train_loader, model, device, num_batches=eval_iter)
        val_loss = calc_loss_loader(val_loader, model, device, num_batches=eval_iter)
    model.train()
    return train_loss, val_loss

# %%
def generate_and_print_sample(model, tokenizer, device, start_context):
    model.eval()
    context_size = model.pos_emb.weight.shape[0]
    encoded = text_to_token_ids(start_context, tokenizer).to(device)
    with torch.no_grad():
        token_ids = generate_text_simple(
            model=model, idx=encoded,
            max_new_tokens=50, context_size=context_size
        )
    decoded_text = token_ids_to_text(token_ids, tokenizer)
    print(decoded_text.replace("\n", " "))  # Compact print format
    model.train()

# %%
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')
RESULT_DIR = "/content/drive/MyDrive/grid_search_results"
os.makedirs(RESULT_DIR, exist_ok=True)
# Out:
# Mounted at /content/drive

# %%
import os
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import torch
import time
import seaborn as sns
import numpy as np

# Dark background settings
plt.style.use('dark_background')
sns.set_style("darkgrid")

# ---- Smoothing Function ----
def smooth(values, window_size=20):
    if len(values) < window_size:
        return values
    return np.convolve(values, np.ones(window_size)/window_size, mode='valid')

# ---- Dark Themed Plotting Function ----
def plot_losses(epochs_seen, tokens_seen, train_losses, val_losses, lr_label, epoch_count, smooth_window=20):
    smoothed_train = smooth(train_losses, smooth_window)
    smoothed_val = smooth(val_losses, smooth_window)

    offset = (len(train_losses) - len(smoothed_train)) // 2
    epochs_smoothed = epochs_seen[offset : offset + len(smoothed_train)]
    tokens_smoothed = tokens_seen[offset : offset + len(smoothed_train)]

    fig, ax1 = plt.subplots(figsize=(7, 4))
    fig.patch.set_facecolor('black')
    ax1.set_facecolor('black')

    ax1.plot(epochs_smoothed, smoothed_train, label="Training Loss", color="cyan", linewidth=2)
    ax1.plot(epochs_smoothed, smoothed_val, label="Validation Loss", color="yellow", linewidth=2, linestyle="--")

    ax1.set_xlabel("Epochs", fontsize=12, color='white')
    ax1.set_ylabel("Loss", fontsize=12, color='white')
    ax1.tick_params(colors='white')
    ax1.grid(True, linestyle="--", alpha=0.3)
    ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

    ax2 = ax1.twiny()
    ax2.plot(tokens_smoothed, smoothed_train, alpha=0)
    ax2.set_xlabel("Tokens Seen", fontsize=12, color='white')
    ax2.tick_params(colors='white')

    fig.suptitle(f"Loss Curve (LR={lr_label}, Epochs={epoch_count})", fontsize=14, color='white', weight='bold')
    legend = ax1.legend(loc="upper right", fontsize=10)
    for text in legend.get_texts():
        text.set_color("white")

    fig.tight_layout(rect=[0, 0, 1, 0.95])
    plot_filename = os.path.join(RESULT_DIR, f"no_shortcuts.pdf")
    plt.savefig(plot_filename, dpi=300)
    plt.close()

# ---- Training Wrapper Function ----
def run_training_for_epochs(lr, epoch_count):
    print(f"\nTraining with learning rate: {lr} for {epoch_count} epochs")
    torch.manual_seed(123)

    model = GPTModel(GPT_CONFIG_124M)
    model.to(device)
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=0.1)

    train_losses, val_losses, tokens_seen = train_model_simple(
        model, train_loader, val_loader, optimizer, device,
        num_epochs=epoch_count, eval_freq=5, eval_iter=1,
        start_context="He said we came here", tokenizer=tokenizer
    )

    epochs_tensor = torch.linspace(0, epoch_count, len(train_losses))
    lr_label = str(lr).replace(".", "_")
    plot_losses(epochs_tensor, tokens_seen, train_losses, val_losses, lr_label, epoch_count)

    token_ids = text_to_token_ids("The tree was", tokenizer).to(device)
    token_ids = generate_text_simple(
        model=model,
        idx=token_ids,
        max_new_tokens=25,
        context_size=GPT_CONFIG_124M["context_length"]
    )
    output_text = token_ids_to_text(token_ids, tokenizer)

    output_file = os.path.join(RESULT_DIR, f"output_text_no_shortcuts.txt")
    with open(output_file, "w") as f:
        f.write(output_text)

    print("Sample output:\n", output_text)

    loss_file = os.path.join(RESULT_DIR, f"final_losses_no_shortcuts.txt")
    with open(loss_file, "w") as f:
        f.write(f"Final Training Loss: {train_losses[-1]:.4f}\n")
        f.write(f"Final Validation Loss: {val_losses[-1]:.4f}\n")

# ---- Run Training ----
learning_rate = 0.0001
epoch_variations = [10]
start_time = time.time()

for epoch_count in epoch_variations:
    run_training_for_epochs(learning_rate, epoch_count)

end_time = time.time()
print(f"\nAll training runs completed in {(end_time - start_time)/60:.2f} minutes.")
# Out:
# Training with learning rate: 0.0001 for 10 epochs
# Ep 1 (Step 000000): Train loss 10.274, Val loss 10.321
# Ep 1 (Step 000005): Train loss 9.196, Val loss 9.188
# Ep 1 (Step 000010): Train loss 8.759, Val loss 8.837
# Ep 1 (Step 000015): Train loss 8.718, Val loss 8.514
# Ep 1 (Step 000020): Train loss 8.152, Val loss 8.191
# Ep 1 (Step 000025): Train loss 7.701, Val loss 7.881
# Ep 1 (Step 000030): Train loss 7.880, Val loss 7.656
# Ep 1 (Step 000035): Train loss 7.146, Val loss 7.453
# Ep 1 (Step 000040): Train loss 7.259, Val loss 7.282
# Ep 1 (Step 000045): Train loss 7.287, Val loss 7.125
# Ep 1 (Step 000050): Train loss 6.687, Val loss 7.024
# Ep 1 (Step 000055): Train loss 6.659, Val loss 7.000
# Ep 1 (Step 000060): Train loss 6.851, Val loss 6.935
# Ep 1 (Step 000065): Train loss 6.577, Val loss 6.909
# Ep 1 (Step 000070): Train loss 6.618, Val loss 6.900
# Ep 1 (Step 000075): Train loss 6.758, Val loss 6.887
# Ep 1 (Step 000080): Train loss 6.792, Val loss 6.840
# Ep 1 (Step 000085): Train loss 6.642, Val loss 6.825
# Ep 1 (Step 000090): Train loss 6.520, Val loss 6.867
# Ep 1 (Step 000095): Train loss 6.718, Val loss 6.960
# Ep 1 (Step 000100): Train loss 6.520, Val loss 6.982
# Ep 1 (Step 000105): Train loss 6.269, Val loss 6.950
# Ep 1 (Step 000110): Train loss 6.497, Val loss 6.909
# Ep 1 (Step 000115): Train loss 6.971, Val loss 6.886
# Ep 1 (Step 000120): Train loss 7.050, Val loss 6.891
# Ep 1 (Step 000125): Train loss 6.836, Val loss 6.891
# Ep 1 (Step 000130): Train loss 6.349, Val loss 6.904
# Ep 1 (Step 000135): Train loss 6.603, Val loss 6.916
# Ep 1 (Step 000140): Train loss 6.416, Val loss 6.918
# Ep 1 (Step 000145): Train loss 6.707, Val loss 6.878
# Ep 1 (Step 000150): Train loss 6.603, Val loss 6.894
# Ep 1 (Step 000155): Train loss 6.580, Val loss 6.918
# Ep 1 (Step 000160): Train loss 6.507, Val loss 6.882
# Ep 1 (Step 000165): Train loss 6.643, Val loss 6.861
# Ep 1 (Step 000170): Train loss 6.700, Val loss 6.869
# Ep 1 (Step 000175): Train loss 6.969, Val loss 6.887
# Ep 1 (Step 000180): Train loss 6.584, Val loss 6.887
# Ep 1 (Step 000185): Train loss 6.506, Val loss 6.878
# Ep 1 (Step 000190): Train loss 6.727, Val loss 6.866
# Ep 1 (Step 000195): Train loss 6.711, Val loss 6.872
# Ep 1 (Step 000200): Train loss 7.192, Val loss 6.886
# Ep 1 (Step 000205): Train loss 6.671, Val loss 6.868
# Ep 1 (Step 000210): Train loss 6.475, Val loss 6.850
# Ep 1 (Step 000215): Train loss 6.252, Val loss 6.830
# Ep 1 (Step 000220): Train loss 6.488, Val loss 6.826
# Ep 1 (Step 000225): Train loss 6.549, Val loss 6.828
# Ep 1 (Step 000230): Train loss 6.441, Val loss 6.846
# Ep 1 (Step 000235): Train loss 6.778, Val loss 6.864
# Ep 1 (Step 000240): Train loss 6.438, Val loss 6.851
# Ep 1 (Step 000245): Train loss 6.103, Val loss 6.840
# Ep 1 (Step 000250): Train loss 6.483, Val loss 6.829
# Ep 1 (Step 000255): Train loss 6.381, Val loss 6.787
# Ep 1 (Step 000260): Train loss 6.711, Val loss 6.776
# Ep 1 (Step 000265): Train loss 6.940, Val loss 6.792
# Ep 1 (Step 000270): Train loss 6.275, Val loss 6.845
# Ep 1 (Step 000275): Train loss 6.296, Val loss 6.868
# Ep 1 (Step 000280): Train loss 6.893, Val loss 6.851
# Ep 1 (Step 000285): Train loss 6.406, Val loss 6.810
# Ep 1 (Step 000290): Train loss 6.492, Val loss 6.773
# Ep 1 (Step 000295): Train loss 6.444, Val loss 6.776
# Ep 1 (Step 000300): Train loss 6.317, Val loss 6.800
# Ep 1 (Step 000305): Train loss 6.346, Val loss 6.816
# Ep 1 (Step 000310): Train loss 6.764, Val loss 6.824
# Ep 1 (Step 000315): Train loss 6.037, Val loss 6.811
# Ep 1 (Step 000320): Train loss 6.264, Val loss 6.799
# Ep 1 (Step 000325): Train loss 6.631, Val loss 6.793
# Ep 1 (Step 000330): Train loss 6.717, Val loss 6.788
# Ep 1 (Step 000335): Train loss 6.127, Val loss 6.773
# Ep 1 (Step 000340): Train loss 6.519, Val loss 6.763
# Ep 1 (Step 000345): Train loss 6.943, Val loss 6.763
# Ep 1 (Step 000350): Train loss 6.536, Val loss 6.766
# Ep 1 (Step 000355): Train loss 6.580, Val loss 6.767
# Ep 1 (Step 000360): Train loss 6.942, Val loss 6.770
# Ep 1 (Step 000365): Train loss 6.248, Val loss 6.776
# Ep 1 (Step 000370): Train loss 6.329, Val loss 6.781
# Ep 1 (Step 000375): Train loss 6.388, Val loss 6.798
# Ep 1 (Step 000380): Train loss 6.532, Val loss 6.793
# Ep 1 (Step 000385): Train loss 6.628, Val loss 6.790
# Ep 1 (Step 000390): Train loss 6.495, Val loss 6.802
# Ep 1 (Step 000395): Train loss 6.645, Val loss 6.808
# Ep 1 (Step 000400): Train loss 6.326, Val loss 6.793
# Ep 1 (Step 000405): Train loss 6.620, Val loss 6.792
# Ep 1 (Step 000410): Train loss 6.586, Val loss 6.791
# Ep 1 (Step 000415): Train loss 6.445, Val loss 6.783
# Ep 1 (Step 000420): Train loss 6.575, Val loss 6.780
# Ep 1 (Step 000425): Train loss 6.576, Val loss 6.776
# Ep 1 (Step 000430): Train loss 6.318, Val loss 6.774
# Ep 1 (Step 000435): Train loss 6.086, Val loss 6.778
# Ep 1 (Step 000440): Train loss 6.778, Val loss 6.788
# Ep 1 (Step 000445): Train loss 6.326, Val loss 6.802
# Ep 1 (Step 000450): Train loss 6.362, Val loss 6.787
# Ep 1 (Step 000455): Train loss 6.717, Val loss 6.770
# Ep 1 (Step 000460): Train loss 6.636, Val loss 6.763
# Ep 1 (Step 000465): Train loss 6.576, Val loss 6.776
# Ep 1 (Step 000470): Train loss 6.738, Val loss 6.777
# Ep 1 (Step 000475): Train loss 6.718, Val loss 6.757
# Ep 1 (Step 000480): Train loss 6.520, Val loss 6.752
# Ep 1 (Step 000485): Train loss 6.924, Val loss 6.772
# Ep 1 (Step 000490): Train loss 6.324, Val loss 6.794
# Ep 1 (Step 000495): Train loss 6.478, Val loss 6.785
# Ep 1 (Step 000500): Train loss 6.517, Val loss 6.767
# Ep 1 (Step 000505): Train loss 6.634, Val loss 6.774
# Ep 1 (Step 000510): Train loss 6.608, Val loss 6.782
# Ep 1 (Step 000515): Train loss 6.600, Val loss 6.775
# Ep 1 (Step 000520): Train loss 6.311, Val loss 6.787
# Ep 1 (Step 000525): Train loss 6.824, Val loss 6.812
# Ep 1 (Step 000530): Train loss 6.493, Val loss 6.805
# Ep 1 (Step 000535): Train loss 6.653, Val loss 6.834
# Ep 1 (Step 000540): Train loss 6.465, Val loss 6.830
# Ep 1 (Step 000545): Train loss 6.284, Val loss 6.799
# Ep 1 (Step 000550): Train loss 6.700, Val loss 6.775
# Ep 1 (Step 000555): Train loss 6.820, Val loss 6.752
# Ep 1 (Step 000560): Train loss 6.713, Val loss 6.740
# Ep 1 (Step 000565): Train loss 6.563, Val loss 6.754
# Ep 1 (Step 000570): Train loss 6.531, Val loss 6.755
# Ep 1 (Step 000575): Train loss 6.528, Val loss 6.761
# Ep 1 (Step 000580): Train loss 6.604, Val loss 6.781
# Ep 1 (Step 000585): Train loss 6.518, Val loss 6.773
# Ep 1 (Step 000590): Train loss 6.733, Val loss 6.777
# Ep 1 (Step 000595): Train loss 6.818, Val loss 6.785
# Ep 1 (Step 000600): Train loss 6.438, Val loss 6.801
# Ep 1 (Step 000605): Train loss 6.234, Val loss 6.785
# Ep 1 (Step 000610): Train loss 6.690, Val loss 6.754
# Ep 1 (Step 000615): Train loss 6.231, Val loss 6.733
# Ep 1 (Step 000620): Train loss 6.400, Val loss 6.726
# Ep 1 (Step 000625): Train loss 6.431, Val loss 6.749
# Ep 1 (Step 000630): Train loss 6.467, Val loss 6.753
# Ep 1 (Step 000635): Train loss 6.787, Val loss 6.753
# Ep 1 (Step 000640): Train loss 6.344, Val loss 6.761
# Ep 1 (Step 000645): Train loss 6.875, Val loss 6.759
# Ep 1 (Step 000650): Train loss 6.711, Val loss 6.768
# Ep 1 (Step 000655): Train loss 6.464, Val loss 6.783
# Ep 1 (Step 000660): Train loss 6.466, Val loss 6.769
# Ep 1 (Step 000665): Train loss 6.518, Val loss 6.754
# Ep 1 (Step 000670): Train loss 6.362, Val loss 6.742
# Ep 1 (Step 000675): Train loss 6.205, Val loss 6.735
# Ep 1 (Step 000680): Train loss 6.408, Val loss 6.742
# Ep 1 (Step 000685): Train loss 6.478, Val loss 6.743
# Ep 1 (Step 000690): Train loss 6.389, Val loss 6.731
# Ep 1 (Step 000695): Train loss 6.452, Val loss 6.731
# Ep 1 (Step 000700): Train loss 6.391, Val loss 6.751
# Ep 1 (Step 000705): Train loss 6.643, Val loss 6.769
# Ep 1 (Step 000710): Train loss 6.131, Val loss 6.771
# Ep 1 (Step 000715): Train loss 6.201, Val loss 6.772
# Ep 1 (Step 000720): Train loss 6.546, Val loss 6.757
# Ep 1 (Step 000725): Train loss 6.243, Val loss 6.725
# Ep 1 (Step 000730): Train loss 6.431, Val loss 6.723
# Ep 1 (Step 000735): Train loss 6.506, Val loss 6.727
# Ep 1 (Step 000740): Train loss 6.398, Val loss 6.739
# Ep 1 (Step 000745): Train loss 6.461, Val loss 6.732
# Ep 1 (Step 000750): Train loss 6.683, Val loss 6.731
# Ep 1 (Step 000755): Train loss 6.474, Val loss 6.759
# Ep 1 (Step 000760): Train loss 6.457, Val loss 6.775
# Ep 1 (Step 000765): Train loss 6.461, Val loss 6.762
# Ep 1 (Step 000770): Train loss 6.330, Val loss 6.741
# Ep 1 (Step 000775): Train loss 6.705, Val loss 6.716
# Ep 1 (Step 000780): Train loss 6.252, Val loss 6.698
# Ep 1 (Step 000785): Train loss 6.670, Val loss 6.683
# Ep 1 (Step 000790): Train loss 6.479, Val loss 6.695
# Ep 1 (Step 000795): Train loss 6.280, Val loss 6.708
# Ep 1 (Step 000800): Train loss 6.427, Val loss 6.722
# Ep 1 (Step 000805): Train loss 6.475, Val loss 6.750
# Ep 1 (Step 000810): Train loss 6.436, Val loss 6.748
# Ep 1 (Step 000815): Train loss 6.273, Val loss 6.746
# Ep 1 (Step 000820): Train loss 6.672, Val loss 6.757
# Ep 1 (Step 000825): Train loss 6.760, Val loss 6.760
# Ep 1 (Step 000830): Train loss 6.420, Val loss 6.763
# Ep 1 (Step 000835): Train loss 6.485, Val loss 6.782
# Ep 1 (Step 000840): Train loss 6.687, Val loss 6.784
# Ep 1 (Step 000845): Train loss 6.586, Val loss 6.778
# Ep 1 (Step 000850): Train loss 6.713, Val loss 6.769
# Ep 1 (Step 000855): Train loss 6.605, Val loss 6.743
# Ep 1 (Step 000860): Train loss 6.647, Val loss 6.725
# Ep 1 (Step 000865): Train loss 6.368, Val loss 6.731
# Ep 1 (Step 000870): Train loss 6.402, Val loss 6.743
# Ep 1 (Step 000875): Train loss 6.769, Val loss 6.757
# Ep 1 (Step 000880): Train loss 6.041, Val loss 6.783
# Ep 1 (Step 000885): Train loss 6.178, Val loss 6.808
# Ep 1 (Step 000890): Train loss 6.315, Val loss 6.811
# Ep 1 (Step 000895): Train loss 6.745, Val loss 6.796
# Ep 1 (Step 000900): Train loss 6.547, Val loss 6.768
# Ep 1 (Step 000905): Train loss 6.537, Val loss 6.729
# He said we came here
# Ep 2 (Step 000910): Train loss 5.860, Val loss 6.713
# Ep 2 (Step 000915): Train loss 6.123, Val loss 6.706
# Ep 2 (Step 000920): Train loss 6.351, Val loss 6.723
# Ep 2 (Step 000925): Train loss 6.613, Val loss 6.731
# Ep 2 (Step 000930): Train loss 6.240, Val loss 6.737
# Ep 2 (Step 000935): Train loss 6.816, Val loss 6.744
# Ep 2 (Step 000940): Train loss 6.391, Val loss 6.766
# Ep 2 (Step 000945): Train loss 6.325, Val loss 6.787
# Ep 2 (Step 000950): Train loss 6.469, Val loss 6.792
# Ep 2 (Step 000955): Train loss 6.379, Val loss 6.806
# Ep 2 (Step 000960): Train loss 6.604, Val loss 6.814
# Ep 2 (Step 000965): Train loss 6.748, Val loss 6.801
# Ep 2 (Step 000970): Train loss 6.601, Val loss 6.783
# Ep 2 (Step 000975): Train loss 6.476, Val loss 6.786
# Ep 2 (Step 000980): Train loss 6.414, Val loss 6.794
# Ep 2 (Step 000985): Train loss 6.507, Val loss 6.785
# Ep 2 (Step 000990): Train loss 6.643, Val loss 6.782
# Ep 2 (Step 000995): Train loss 6.456, Val loss 6.786
# Ep 2 (Step 001000): Train loss 6.520, Val loss 6.778
# Ep 2 (Step 001005): Train loss 6.544, Val loss 6.761
# Ep 2 (Step 001010): Train loss 6.403, Val loss 6.754
# Ep 2 (Step 001015): Train loss 6.158, Val loss 6.753
# Ep 2 (Step 001020): Train loss 6.535, Val loss 6.764
# Ep 2 (Step 001025): Train loss 6.409, Val loss 6.773
# Ep 2 (Step 001030): Train loss 6.737, Val loss 6.774
# Ep 2 (Step 001035): Train loss 6.456, Val loss 6.772
# Ep 2 (Step 001040): Train loss 6.364, Val loss 6.771
# Ep 2 (Step 001045): Train loss 6.675, Val loss 6.778
# Ep 2 (Step 001050): Train loss 6.273, Val loss 6.786
# Ep 2 (Step 001055): Train loss 6.407, Val loss 6.790
# Ep 2 (Step 001060): Train loss 6.668, Val loss 6.787
# Ep 2 (Step 001065): Train loss 6.517, Val loss 6.783
# Ep 2 (Step 001070): Train loss 6.532, Val loss 6.762
# Ep 2 (Step 001075): Train loss 6.459, Val loss 6.742
# Ep 2 (Step 001080): Train loss 6.410, Val loss 6.729
# Ep 2 (Step 001085): Train loss 6.627, Val loss 6.735
# Ep 2 (Step 001090): Train loss 6.526, Val loss 6.757
# Ep 2 (Step 001095): Train loss 6.612, Val loss 6.764
# Ep 2 (Step 001100): Train loss 6.533, Val loss 6.766
# Ep 2 (Step 001105): Train loss 6.918, Val loss 6.773
# Ep 2 (Step 001110): Train loss 6.256, Val loss 6.758
# Ep 2 (Step 001115): Train loss 6.278, Val loss 6.747
# Ep 2 (Step 001120): Train loss 6.513, Val loss 6.737
# Ep 2 (Step 001125): Train loss 6.558, Val loss 6.746
# Ep 2 (Step 001130): Train loss 6.264, Val loss 6.757
# Ep 2 (Step 001135): Train loss 6.469, Val loss 6.770
# Ep 2 (Step 001140): Train loss 6.451, Val loss 6.769
# Ep 2 (Step 001145): Train loss 6.340, Val loss 6.757
# Ep 2 (Step 001150): Train loss 6.161, Val loss 6.742
# Ep 2 (Step 001155): Train loss 6.482, Val loss 6.729
# Ep 2 (Step 001160): Train loss 6.473, Val loss 6.717
# Ep 2 (Step 001165): Train loss 6.342, Val loss 6.710
# Ep 2 (Step 001170): Train loss 6.385, Val loss 6.711
# Ep 2 (Step 001175): Train loss 6.874, Val loss 6.727
# Ep 2 (Step 001180): Train loss 6.503, Val loss 6.728
# Ep 2 (Step 001185): Train loss 6.526, Val loss 6.723
# Ep 2 (Step 001190): Train loss 6.857, Val loss 6.728
# Ep 2 (Step 001195): Train loss 6.424, Val loss 6.731
# Ep 2 (Step 001200): Train loss 6.331, Val loss 6.740
# Ep 2 (Step 001205): Train loss 6.013, Val loss 6.754
# Ep 2 (Step 001210): Train loss 6.770, Val loss 6.737
# Ep 2 (Step 001215): Train loss 6.498, Val loss 6.725
# Ep 2 (Step 001220): Train loss 6.344, Val loss 6.707
# Ep 2 (Step 001225): Train loss 6.444, Val loss 6.713
# Ep 2 (Step 001230): Train loss 6.727, Val loss 6.740
# Ep 2 (Step 001235): Train loss 6.290, Val loss 6.754
# Ep 2 (Step 001240): Train loss 6.144, Val loss 6.759
# Ep 2 (Step 001245): Train loss 6.519, Val loss 6.762
# Ep 2 (Step 001250): Train loss 6.603, Val loss 6.751
# Ep 2 (Step 001255): Train loss 6.356, Val loss 6.735
# Ep 2 (Step 001260): Train loss 6.320, Val loss 6.735
# Ep 2 (Step 001265): Train loss 6.775, Val loss 6.731
# Ep 2 (Step 001270): Train loss 6.406, Val loss 6.736
# Ep 2 (Step 001275): Train loss 6.847, Val loss 6.746
# Ep 2 (Step 001280): Train loss 6.497, Val loss 6.744
# Ep 2 (Step 001285): Train loss 6.665, Val loss 6.735
# Ep 2 (Step 001290): Train loss 6.560, Val loss 6.732
# Ep 2 (Step 001295): Train loss 6.294, Val loss 6.733
# Ep 2 (Step 001300): Train loss 6.277, Val loss 6.742
# Ep 2 (Step 001305): Train loss 6.845, Val loss 6.750
# Ep 2 (Step 001310): Train loss 6.324, Val loss 6.740
# Ep 2 (Step 001315): Train loss 6.371, Val loss 6.722
# Ep 2 (Step 001320): Train loss 6.775, Val loss 6.713
# Ep 2 (Step 001325): Train loss 6.556, Val loss 6.722
# Ep 2 (Step 001330): Train loss 6.585, Val loss 6.731
# Ep 2 (Step 001335): Train loss 6.466, Val loss 6.737
# Ep 2 (Step 001340): Train loss 6.401, Val loss 6.743
# Ep 2 (Step 001345): Train loss 6.876, Val loss 6.740
# Ep 2 (Step 001350): Train loss 6.564, Val loss 6.741
# Ep 2 (Step 001355): Train loss 6.448, Val loss 6.740
# Ep 2 (Step 001360): Train loss 6.360, Val loss 6.742
# Ep 2 (Step 001365): Train loss 6.800, Val loss 6.750
# Ep 2 (Step 001370): Train loss 6.100, Val loss 6.761
# Ep 2 (Step 001375): Train loss 6.924, Val loss 6.770
# Ep 2 (Step 001380): Train loss 6.439, Val loss 6.773
# Ep 2 (Step 001385): Train loss 6.323, Val loss 6.773
# Ep 2 (Step 001390): Train loss 6.168, Val loss 6.760
# Ep 2 (Step 001395): Train loss 6.592, Val loss 6.745
# Ep 2 (Step 001400): Train loss 6.152, Val loss 6.722
# Ep 2 (Step 001405): Train loss 6.197, Val loss 6.713
# Ep 2 (Step 001410): Train loss 6.453, Val loss 6.734
# Ep 2 (Step 001415): Train loss 6.711, Val loss 6.751
# Ep 2 (Step 001420): Train loss 6.358, Val loss 6.767
# Ep 2 (Step 001425): Train loss 6.330, Val loss 6.787
# Ep 2 (Step 001430): Train loss 6.267, Val loss 6.795
# Ep 2 (Step 001435): Train loss 6.726, Val loss 6.795
# Ep 2 (Step 001440): Train loss 6.689, Val loss 6.773
# Ep 2 (Step 001445): Train loss 6.467, Val loss 6.744
# Ep 2 (Step 001450): Train loss 6.422, Val loss 6.733
# Ep 2 (Step 001455): Train loss 6.686, Val loss 6.732
# Ep 2 (Step 001460): Train loss 6.370, Val loss 6.731
# Ep 2 (Step 001465): Train loss 6.439, Val loss 6.741
# Ep 2 (Step 001470): Train loss 6.297, Val loss 6.762
# Ep 2 (Step 001475): Train loss 6.441, Val loss 6.781
# Ep 2 (Step 001480): Train loss 6.454, Val loss 6.777
# Ep 2 (Step 001485): Train loss 6.523, Val loss 6.761
# Ep 2 (Step 001490): Train loss 6.174, Val loss 6.752
# Ep 2 (Step 001495): Train loss 6.068, Val loss 6.771
# Ep 2 (Step 001500): Train loss 6.596, Val loss 6.794
# Ep 2 (Step 001505): Train loss 6.795, Val loss 6.797
# Ep 2 (Step 001510): Train loss 6.813, Val loss 6.803
# Ep 2 (Step 001515): Train loss 6.243, Val loss 6.791
# Ep 2 (Step 001520): Train loss 6.357, Val loss 6.777
# Ep 2 (Step 001525): Train loss 6.428, Val loss 6.761
# Ep 2 (Step 001530): Train loss 6.748, Val loss 6.751
# Ep 2 (Step 001535): Train loss 6.601, Val loss 6.747
# Ep 2 (Step 001540): Train loss 6.778, Val loss 6.756
# Ep 2 (Step 001545): Train loss 6.757, Val loss 6.764
# Ep 2 (Step 001550): Train loss 7.210, Val loss 6.780
# Ep 2 (Step 001555): Train loss 6.273, Val loss 6.786
# Ep 2 (Step 001560): Train loss 6.468, Val loss 6.784
# Ep 2 (Step 001565): Train loss 6.241, Val loss 6.766
# Ep 2 (Step 001570): Train loss 6.488, Val loss 6.749
# Ep 2 (Step 001575): Train loss 6.588, Val loss 6.738
# Ep 2 (Step 001580): Train loss 6.577, Val loss 6.724
# Ep 2 (Step 001585): Train loss 6.157, Val loss 6.719
# Ep 2 (Step 001590): Train loss 6.523, Val loss 6.729
# Ep 2 (Step 001595): Train loss 6.202, Val loss 6.736
# Ep 2 (Step 001600): Train loss 6.529, Val loss 6.744
# Ep 2 (Step 001605): Train loss 6.268, Val loss 6.751
# Ep 2 (Step 001610): Train loss 6.772, Val loss 6.763
# Ep 2 (Step 001615): Train loss 6.599, Val loss 6.768
# Ep 2 (Step 001620): Train loss 6.393, Val loss 6.763
# Ep 2 (Step 001625): Train loss 6.238, Val loss 6.771
# Ep 2 (Step 001630): Train loss 6.481, Val loss 6.761
# Ep 2 (Step 001635): Train loss 6.317, Val loss 6.746
# Ep 2 (Step 001640): Train loss 6.334, Val loss 6.741
# Ep 2 (Step 001645): Train loss 6.364, Val loss 6.739
# Ep 2 (Step 001650): Train loss 6.550, Val loss 6.738
# Ep 2 (Step 001655): Train loss 6.267, Val loss 6.733
# Ep 2 (Step 001660): Train loss 6.570, Val loss 6.741
# Ep 2 (Step 001665): Train loss 6.575, Val loss 6.753
# Ep 2 (Step 001670): Train loss 6.306, Val loss 6.766
# Ep 2 (Step 001675): Train loss 6.714, Val loss 6.765
# Ep 2 (Step 001680): Train loss 6.328, Val loss 6.762
# Ep 2 (Step 001685): Train loss 6.409, Val loss 6.756
# Ep 2 (Step 001690): Train loss 6.557, Val loss 6.744
# Ep 2 (Step 001695): Train loss 6.370, Val loss 6.753
# Ep 2 (Step 001700): Train loss 6.180, Val loss 6.780
# Ep 2 (Step 001705): Train loss 6.241, Val loss 6.788
# Ep 2 (Step 001710): Train loss 6.694, Val loss 6.783
# Ep 2 (Step 001715): Train loss 6.331, Val loss 6.774
# Ep 2 (Step 001720): Train loss 6.296, Val loss 6.763
# Ep 2 (Step 001725): Train loss 6.430, Val loss 6.755
# Ep 2 (Step 001730): Train loss 6.252, Val loss 6.754
# Ep 2 (Step 001735): Train loss 6.464, Val loss 6.755
# Ep 2 (Step 001740): Train loss 6.616, Val loss 6.743
# Ep 2 (Step 001745): Train loss 6.835, Val loss 6.730
# Ep 2 (Step 001750): Train loss 6.039, Val loss 6.720
# Ep 2 (Step 001755): Train loss 6.318, Val loss 6.723
# Ep 2 (Step 001760): Train loss 6.345, Val loss 6.744
# Ep 2 (Step 001765): Train loss 6.412, Val loss 6.778
# Ep 2 (Step 001770): Train loss 6.533, Val loss 6.782
# Ep 2 (Step 001775): Train loss 6.490, Val loss 6.777
# Ep 2 (Step 001780): Train loss 6.582, Val loss 6.772
# Ep 2 (Step 001785): Train loss 6.243, Val loss 6.781
# Ep 2 (Step 001790): Train loss 6.027, Val loss 6.784
# Ep 2 (Step 001795): Train loss 6.598, Val loss 6.790
# Ep 2 (Step 001800): Train loss 7.004, Val loss 6.797
# Ep 2 (Step 001805): Train loss 6.337, Val loss 6.807
# Ep 2 (Step 001810): Train loss 6.414, Val loss 6.799
# Ep 2 (Step 001815): Train loss 6.603, Val loss 6.773
# He said we came here
# Ep 3 (Step 001820): Train loss 6.262, Val loss 6.757
# Ep 3 (Step 001825): Train loss 6.298, Val loss 6.748
# Ep 3 (Step 001830): Train loss 6.503, Val loss 6.746
# Ep 3 (Step 001835): Train loss 6.514, Val loss 6.759
# Ep 3 (Step 001840): Train loss 6.641, Val loss 6.761
# Ep 3 (Step 001845): Train loss 6.509, Val loss 6.744
# Ep 3 (Step 001850): Train loss 6.694, Val loss 6.730
# Ep 3 (Step 001855): Train loss 6.246, Val loss 6.729
# Ep 3 (Step 001860): Train loss 6.648, Val loss 6.740
# Ep 3 (Step 001865): Train loss 6.467, Val loss 6.769
# Ep 3 (Step 001870): Train loss 6.331, Val loss 6.781
# Ep 3 (Step 001875): Train loss 6.300, Val loss 6.774
# Ep 3 (Step 001880): Train loss 6.580, Val loss 6.759
# Ep 3 (Step 001885): Train loss 6.249, Val loss 6.747
# Ep 3 (Step 001890): Train loss 6.231, Val loss 6.741
# Ep 3 (Step 001895): Train loss 6.476, Val loss 6.747
# Ep 3 (Step 001900): Train loss 6.406, Val loss 6.762
# Ep 3 (Step 001905): Train loss 6.691, Val loss 6.779
# Ep 3 (Step 001910): Train loss 7.000, Val loss 6.791
# Ep 3 (Step 001915): Train loss 6.409, Val loss 6.796
# Ep 3 (Step 001920): Train loss 6.668, Val loss 6.781
# Ep 3 (Step 001925): Train loss 6.486, Val loss 6.768
# Ep 3 (Step 001930): Train loss 6.225, Val loss 6.764
# Ep 3 (Step 001935): Train loss 6.217, Val loss 6.762
# Ep 3 (Step 001940): Train loss 6.220, Val loss 6.764
# Ep 3 (Step 001945): Train loss 6.861, Val loss 6.766
# Ep 3 (Step 001950): Train loss 6.231, Val loss 6.774
# Ep 3 (Step 001955): Train loss 7.199, Val loss 6.791
# Ep 3 (Step 001960): Train loss 6.907, Val loss 6.802
# Ep 3 (Step 001965): Train loss 6.586, Val loss 6.798
# Ep 3 (Step 001970): Train loss 6.430, Val loss 6.783
# Ep 3 (Step 001975): Train loss 7.039, Val loss 6.771
# Ep 3 (Step 001980): Train loss 6.542, Val loss 6.770
# Ep 3 (Step 001985): Train loss 6.293, Val loss 6.776
# Ep 3 (Step 001990): Train loss 6.659, Val loss 6.787
# Ep 3 (Step 001995): Train loss 6.376, Val loss 6.780
# Ep 3 (Step 002000): Train loss 6.274, Val loss 6.776
# Ep 3 (Step 002005): Train loss 6.129, Val loss 6.776
# Ep 3 (Step 002010): Train loss 6.488, Val loss 6.775
# Ep 3 (Step 002015): Train loss 6.479, Val loss 6.775
# Ep 3 (Step 002020): Train loss 6.363, Val loss 6.779
# Ep 3 (Step 002025): Train loss 6.546, Val loss 6.779
# Ep 3 (Step 002030): Train loss 6.196, Val loss 6.773
# Ep 3 (Step 002035): Train loss 6.518, Val loss 6.778
# Ep 3 (Step 002040): Train loss 6.255, Val loss 6.783
# Ep 3 (Step 002045): Train loss 6.587, Val loss 6.782
# Ep 3 (Step 002050): Train loss 6.559, Val loss 6.778
# Ep 3 (Step 002055): Train loss 6.170, Val loss 6.770
# Ep 3 (Step 002060): Train loss 6.269, Val loss 6.766
# Ep 3 (Step 002065): Train loss 6.777, Val loss 6.776
# Ep 3 (Step 002070): Train loss 6.526, Val loss 6.788
# Ep 3 (Step 002075): Train loss 6.205, Val loss 6.796
# Ep 3 (Step 002080): Train loss 6.606, Val loss 6.789
# Ep 3 (Step 002085): Train loss 6.210, Val loss 6.781
# Ep 3 (Step 002090): Train loss 6.131, Val loss 6.760
# Ep 3 (Step 002095): Train loss 6.472, Val loss 6.741
# Ep 3 (Step 002100): Train loss 6.570, Val loss 6.742
# Ep 3 (Step 002105): Train loss 6.231, Val loss 6.749
# Ep 3 (Step 002110): Train loss 6.300, Val loss 6.748
# Ep 3 (Step 002115): Train loss 6.374, Val loss 6.757
# Ep 3 (Step 002120): Train loss 6.542, Val loss 6.755
# Ep 3 (Step 002125): Train loss 6.549, Val loss 6.759
# Ep 3 (Step 002130): Train loss 6.059, Val loss 6.755
# Ep 3 (Step 002135): Train loss 6.399, Val loss 6.761
# Ep 3 (Step 002140): Train loss 6.306, Val loss 6.760
# Ep 3 (Step 002145): Train loss 6.772, Val loss 6.754
# Ep 3 (Step 002150): Train loss 6.529, Val loss 6.757
# Ep 3 (Step 002155): Train loss 6.332, Val loss 6.766
# Ep 3 (Step 002160): Train loss 6.206, Val loss 6.762
# Ep 3 (Step 002165): Train loss 6.711, Val loss 6.755
# Ep 3 (Step 002170): Train loss 6.492, Val loss 6.759
# Ep 3 (Step 002175): Train loss 6.497, Val loss 6.762
# Ep 3 (Step 002180): Train loss 6.232, Val loss 6.752
# Ep 3 (Step 002185): Train loss 6.466, Val loss 6.751
# Ep 3 (Step 002190): Train loss 6.320, Val loss 6.752
# Ep 3 (Step 002195): Train loss 6.206, Val loss 6.747
# Ep 3 (Step 002200): Train loss 6.111, Val loss 6.738
# Ep 3 (Step 002205): Train loss 6.235, Val loss 6.745
# Ep 3 (Step 002210): Train loss 6.529, Val loss 6.751
# Ep 3 (Step 002215): Train loss 6.451, Val loss 6.765
# Ep 3 (Step 002220): Train loss 6.525, Val loss 6.772
# Ep 3 (Step 002225): Train loss 6.426, Val loss 6.770
# Ep 3 (Step 002230): Train loss 6.397, Val loss 6.759
# Ep 3 (Step 002235): Train loss 6.237, Val loss 6.752
# Ep 3 (Step 002240): Train loss 6.399, Val loss 6.744
# Ep 3 (Step 002245): Train loss 6.648, Val loss 6.739
# Ep 3 (Step 002250): Train loss 6.612, Val loss 6.740
# Ep 3 (Step 002255): Train loss 6.169, Val loss 6.735
# Ep 3 (Step 002260): Train loss 6.453, Val loss 6.733
# Ep 3 (Step 002265): Train loss 6.627, Val loss 6.732
# Ep 3 (Step 002270): Train loss 6.498, Val loss 6.723
# Ep 3 (Step 002275): Train loss 6.284, Val loss 6.713
# Ep 3 (Step 002280): Train loss 6.347, Val loss 6.713
# Ep 3 (Step 002285): Train loss 6.158, Val loss 6.726
# Ep 3 (Step 002290): Train loss 6.357, Val loss 6.743
# Ep 3 (Step 002295): Train loss 6.448, Val loss 6.760
# Ep 3 (Step 002300): Train loss 6.464, Val loss 6.765
# Ep 3 (Step 002305): Train loss 6.864, Val loss 6.763
# Ep 3 (Step 002310): Train loss 6.229, Val loss 6.772
# Ep 3 (Step 002315): Train loss 6.530, Val loss 6.768
# Ep 3 (Step 002320): Train loss 6.747, Val loss 6.757
# Ep 3 (Step 002325): Train loss 6.856, Val loss 6.748
# Ep 3 (Step 002330): Train loss 6.468, Val loss 6.738
# Ep 3 (Step 002335): Train loss 6.365, Val loss 6.741
# Ep 3 (Step 002340): Train loss 6.734, Val loss 6.738
# Ep 3 (Step 002345): Train loss 6.679, Val loss 6.728
# Ep 3 (Step 002350): Train loss 6.559, Val loss 6.728
# Ep 3 (Step 002355): Train loss 6.315, Val loss 6.734
# Ep 3 (Step 002360): Train loss 6.153, Val loss 6.738
# Ep 3 (Step 002365): Train loss 6.030, Val loss 6.736
# Ep 3 (Step 002370): Train loss 6.432, Val loss 6.733
# Ep 3 (Step 002375): Train loss 6.360, Val loss 6.736
# Ep 3 (Step 002380): Train loss 6.367, Val loss 6.739
# Ep 3 (Step 002385): Train loss 6.668, Val loss 6.744
# Ep 3 (Step 002390): Train loss 6.397, Val loss 6.750
# Ep 3 (Step 002395): Train loss 6.818, Val loss 6.753
# Ep 3 (Step 002400): Train loss 6.480, Val loss 6.747
# Ep 3 (Step 002405): Train loss 6.894, Val loss 6.743
# Ep 3 (Step 002410): Train loss 6.318, Val loss 6.744
# Ep 3 (Step 002415): Train loss 6.745, Val loss 6.739
# Ep 3 (Step 002420): Train loss 6.313, Val loss 6.737
# Ep 3 (Step 002425): Train loss 6.669, Val loss 6.747
# Ep 3 (Step 002430): Train loss 7.095, Val loss 6.774
# Ep 3 (Step 002435): Train loss 6.318, Val loss 6.798
# Ep 3 (Step 002440): Train loss 6.457, Val loss 6.812
# Ep 3 (Step 002445): Train loss 6.648, Val loss 6.815
# Ep 3 (Step 002450): Train loss 6.646, Val loss 6.811
# Ep 3 (Step 002455): Train loss 6.542, Val loss 6.797
# Ep 3 (Step 002460): Train loss 6.194, Val loss 6.790
# Ep 3 (Step 002465): Train loss 6.665, Val loss 6.791
# Ep 3 (Step 002470): Train loss 6.231, Val loss 6.797
# Ep 3 (Step 002475): Train loss 6.402, Val loss 6.796
# Ep 3 (Step 002480): Train loss 6.299, Val loss 6.781
# Ep 3 (Step 002485): Train loss 6.411, Val loss 6.765
# Ep 3 (Step 002490): Train loss 6.275, Val loss 6.757
# Ep 3 (Step 002495): Train loss 6.651, Val loss 6.746
# Ep 3 (Step 002500): Train loss 6.303, Val loss 6.746
# Ep 3 (Step 002505): Train loss 6.418, Val loss 6.757
# Ep 3 (Step 002510): Train loss 6.570, Val loss 6.770
# Ep 3 (Step 002515): Train loss 6.377, Val loss 6.778
# Ep 3 (Step 002520): Train loss 6.475, Val loss 6.771
# Ep 3 (Step 002525): Train loss 6.689, Val loss 6.762
# Ep 3 (Step 002530): Train loss 6.552, Val loss 6.759
# Ep 3 (Step 002535): Train loss 6.589, Val loss 6.764
# Ep 3 (Step 002540): Train loss 6.273, Val loss 6.773
# Ep 3 (Step 002545): Train loss 6.657, Val loss 6.784
# Ep 3 (Step 002550): Train loss 6.582, Val loss 6.789
# Ep 3 (Step 002555): Train loss 6.528, Val loss 6.789
# Ep 3 (Step 002560): Train loss 6.538, Val loss 6.777
# Ep 3 (Step 002565): Train loss 6.246, Val loss 6.769
# Ep 3 (Step 002570): Train loss 6.792, Val loss 6.768
# Ep 3 (Step 002575): Train loss 6.103, Val loss 6.784
# Ep 3 (Step 002580): Train loss 6.731, Val loss 6.794
# Ep 3 (Step 002585): Train loss 6.612, Val loss 6.782
# Ep 3 (Step 002590): Train loss 6.667, Val loss 6.761
# Ep 3 (Step 002595): Train loss 6.597, Val loss 6.748
# Ep 3 (Step 002600): Train loss 6.620, Val loss 6.741
# Ep 3 (Step 002605): Train loss 6.294, Val loss 6.743
# Ep 3 (Step 002610): Train loss 6.270, Val loss 6.746
# Ep 3 (Step 002615): Train loss 6.435, Val loss 6.756
# Ep 3 (Step 002620): Train loss 6.246, Val loss 6.766
# Ep 3 (Step 002625): Train loss 6.217, Val loss 6.777
# Ep 3 (Step 002630): Train loss 6.380, Val loss 6.779
# Ep 3 (Step 002635): Train loss 6.924, Val loss 6.771
# Ep 3 (Step 002640): Train loss 6.303, Val loss 6.773
# Ep 3 (Step 002645): Train loss 6.379, Val loss 6.768
# Ep 3 (Step 002650): Train loss 6.088, Val loss 6.759
# Ep 3 (Step 002655): Train loss 6.559, Val loss 6.749
# Ep 3 (Step 002660): Train loss 6.318, Val loss 6.744
# Ep 3 (Step 002665): Train loss 6.467, Val loss 6.750
# Ep 3 (Step 002670): Train loss 6.112, Val loss 6.758
# Ep 3 (Step 002675): Train loss 6.654, Val loss 6.765
# Ep 3 (Step 002680): Train loss 6.711, Val loss 6.766
# Ep 3 (Step 002685): Train loss 6.378, Val loss 6.749
# Ep 3 (Step 002690): Train loss 6.433, Val loss 6.734
# Ep 3 (Step 002695): Train loss 6.405, Val loss 6.731
# Ep 3 (Step 002700): Train loss 6.571, Val loss 6.733
# Ep 3 (Step 002705): Train loss 6.290, Val loss 6.745
# Ep 3 (Step 002710): Train loss 6.219, Val loss 6.760
# Ep 3 (Step 002715): Train loss 6.471, Val loss 6.764
# Ep 3 (Step 002720): Train loss 6.881, Val loss 6.762
# He said we came here
# Ep 4 (Step 002725): Train loss 5.969, Val loss 6.744
# Ep 4 (Step 002730): Train loss 6.517, Val loss 6.735
# Ep 4 (Step 002735): Train loss 6.224, Val loss 6.743
# Ep 4 (Step 002740): Train loss 6.330, Val loss 6.753
# Ep 4 (Step 002745): Train loss 6.432, Val loss 6.764
# Ep 4 (Step 002750): Train loss 6.469, Val loss 6.766
# Ep 4 (Step 002755): Train loss 6.285, Val loss 6.764
# Ep 4 (Step 002760): Train loss 6.345, Val loss 6.759
# Ep 4 (Step 002765): Train loss 6.154, Val loss 6.760
# Ep 4 (Step 002770): Train loss 6.523, Val loss 6.760
# Ep 4 (Step 002775): Train loss 6.653, Val loss 6.762
# Ep 4 (Step 002780): Train loss 6.344, Val loss 6.756
# Ep 4 (Step 002785): Train loss 6.705, Val loss 6.750
# Ep 4 (Step 002790): Train loss 6.283, Val loss 6.746
# Ep 4 (Step 002795): Train loss 6.657, Val loss 6.749
# Ep 4 (Step 002800): Train loss 6.199, Val loss 6.758
# Ep 4 (Step 002805): Train loss 6.322, Val loss 6.761
# Ep 4 (Step 002810): Train loss 6.416, Val loss 6.762
# Ep 4 (Step 002815): Train loss 6.573, Val loss 6.762
# Ep 4 (Step 002820): Train loss 6.396, Val loss 6.760
# Ep 4 (Step 002825): Train loss 6.679, Val loss 6.760
# Ep 4 (Step 002830): Train loss 6.213, Val loss 6.743
# Ep 4 (Step 002835): Train loss 6.484, Val loss 6.723
# Ep 4 (Step 002840): Train loss 6.245, Val loss 6.717
# Ep 4 (Step 002845): Train loss 6.322, Val loss 6.720
# Ep 4 (Step 002850): Train loss 6.617, Val loss 6.727
# Ep 4 (Step 002855): Train loss 6.299, Val loss 6.733
# Ep 4 (Step 002860): Train loss 6.339, Val loss 6.736
# Ep 4 (Step 002865): Train loss 6.796, Val loss 6.742
# Ep 4 (Step 002870): Train loss 6.549, Val loss 6.746
# Ep 4 (Step 002875): Train loss 6.493, Val loss 6.750
# Ep 4 (Step 002880): Train loss 6.531, Val loss 6.757
# Ep 4 (Step 002885): Train loss 6.361, Val loss 6.767
# Ep 4 (Step 002890): Train loss 6.369, Val loss 6.768
# Ep 4 (Step 002895): Train loss 6.580, Val loss 6.763
# Ep 4 (Step 002900): Train loss 6.529, Val loss 6.769
# Ep 4 (Step 002905): Train loss 6.229, Val loss 6.784
# Ep 4 (Step 002910): Train loss 6.483, Val loss 6.790
# Ep 4 (Step 002915): Train loss 6.138, Val loss 6.790
# Ep 4 (Step 002920): Train loss 6.462, Val loss 6.790
# Ep 4 (Step 002925): Train loss 6.468, Val loss 6.792
# Ep 4 (Step 002930): Train loss 6.381, Val loss 6.793
# Ep 4 (Step 002935): Train loss 6.557, Val loss 6.783
# Ep 4 (Step 002940): Train loss 6.444, Val loss 6.779
# Ep 4 (Step 002945): Train loss 6.402, Val loss 6.786
# Ep 4 (Step 002950): Train loss 6.613, Val loss 6.791
# Ep 4 (Step 002955): Train loss 6.135, Val loss 6.791
# Ep 4 (Step 002960): Train loss 6.463, Val loss 6.789
# Ep 4 (Step 002965): Train loss 6.687, Val loss 6.798
# Ep 4 (Step 002970): Train loss 6.374, Val loss 6.808
# Ep 4 (Step 002975): Train loss 6.365, Val loss 6.805
# Ep 4 (Step 002980): Train loss 6.438, Val loss 6.790
# Ep 4 (Step 002985): Train loss 6.450, Val loss 6.780
# Ep 4 (Step 002990): Train loss 6.504, Val loss 6.777
# Ep 4 (Step 002995): Train loss 6.435, Val loss 6.770
# Ep 4 (Step 003000): Train loss 6.361, Val loss 6.769
# Ep 4 (Step 003005): Train loss 6.342, Val loss 6.770
# Ep 4 (Step 003010): Train loss 6.374, Val loss 6.775
# Ep 4 (Step 003015): Train loss 6.434, Val loss 6.776
# Ep 4 (Step 003020): Train loss 7.008, Val loss 6.769
# Ep 4 (Step 003025): Train loss 6.281, Val loss 6.757
# Ep 4 (Step 003030): Train loss 6.587, Val loss 6.755
# Ep 4 (Step 003035): Train loss 6.577, Val loss 6.759
# Ep 4 (Step 003040): Train loss 6.893, Val loss 6.762
# Ep 4 (Step 003045): Train loss 6.660, Val loss 6.749
# Ep 4 (Step 003050): Train loss 6.390, Val loss 6.745
# Ep 4 (Step 003055): Train loss 6.491, Val loss 6.751
# Ep 4 (Step 003060): Train loss 6.393, Val loss 6.757
# Ep 4 (Step 003065): Train loss 6.593, Val loss 6.754
# Ep 4 (Step 003070): Train loss 6.818, Val loss 6.759
# Ep 4 (Step 003075): Train loss 6.767, Val loss 6.765
# Ep 4 (Step 003080): Train loss 6.343, Val loss 6.763
# Ep 4 (Step 003085): Train loss 6.326, Val loss 6.765
# Ep 4 (Step 003090): Train loss 6.470, Val loss 6.774
# Ep 4 (Step 003095): Train loss 6.528, Val loss 6.777
# Ep 4 (Step 003100): Train loss 6.461, Val loss 6.778
# Ep 4 (Step 003105): Train loss 6.658, Val loss 6.786
# Ep 4 (Step 003110): Train loss 6.528, Val loss 6.785
# Ep 4 (Step 003115): Train loss 6.895, Val loss 6.779
# Ep 4 (Step 003120): Train loss 6.595, Val loss 6.771
# Ep 4 (Step 003125): Train loss 6.605, Val loss 6.772
# Ep 4 (Step 003130): Train loss 6.524, Val loss 6.778
# Ep 4 (Step 003135): Train loss 6.406, Val loss 6.785
# Ep 4 (Step 003140): Train loss 6.419, Val loss 6.786
# Ep 4 (Step 003145): Train loss 6.135, Val loss 6.787
# Ep 4 (Step 003150): Train loss 6.486, Val loss 6.790
# Ep 4 (Step 003155): Train loss 6.262, Val loss 6.797
# Ep 4 (Step 003160): Train loss 6.505, Val loss 6.796
# Ep 4 (Step 003165): Train loss 6.174, Val loss 6.797
# Ep 4 (Step 003170): Train loss 6.105, Val loss 6.797
# Ep 4 (Step 003175): Train loss 6.548, Val loss 6.793
# Ep 4 (Step 003180): Train loss 6.424, Val loss 6.786
# Ep 4 (Step 003185): Train loss 6.579, Val loss 6.776
# Ep 4 (Step 003190): Train loss 6.217, Val loss 6.774
# Ep 4 (Step 003195): Train loss 6.238, Val loss 6.769
# Ep 4 (Step 003200): Train loss 6.607, Val loss 6.769
# Ep 4 (Step 003205): Train loss 6.311, Val loss 6.773
# Ep 4 (Step 003210): Train loss 6.298, Val loss 6.778
# Ep 4 (Step 003215): Train loss 6.830, Val loss 6.770
# Ep 4 (Step 003220): Train loss 6.309, Val loss 6.769
# Ep 4 (Step 003225): Train loss 6.647, Val loss 6.779
# Ep 4 (Step 003230): Train loss 6.523, Val loss 6.787
# Ep 4 (Step 003235): Train loss 6.273, Val loss 6.785
# Ep 4 (Step 003240): Train loss 6.113, Val loss 6.781
# Ep 4 (Step 003245): Train loss 6.353, Val loss 6.780
# Ep 4 (Step 003250): Train loss 6.312, Val loss 6.781
# Ep 4 (Step 003255): Train loss 6.645, Val loss 6.782
# Ep 4 (Step 003260): Train loss 6.462, Val loss 6.792
# Ep 4 (Step 003265): Train loss 6.503, Val loss 6.791
# Ep 4 (Step 003270): Train loss 6.440, Val loss 6.782
# Ep 4 (Step 003275): Train loss 6.703, Val loss 6.771
# Ep 4 (Step 003280): Train loss 6.479, Val loss 6.768
# Ep 4 (Step 003285): Train loss 6.075, Val loss 6.760
# Ep 4 (Step 003290): Train loss 6.163, Val loss 6.744
# Ep 4 (Step 003295): Train loss 6.439, Val loss 6.739
# Ep 4 (Step 003300): Train loss 6.340, Val loss 6.729
# Ep 4 (Step 003305): Train loss 6.386, Val loss 6.722
# Ep 4 (Step 003310): Train loss 6.564, Val loss 6.720
# Ep 4 (Step 003315): Train loss 6.914, Val loss 6.718
# Ep 4 (Step 003320): Train loss 6.701, Val loss 6.724
# Ep 4 (Step 003325): Train loss 6.238, Val loss 6.723
# Ep 4 (Step 003330): Train loss 6.438, Val loss 6.723
# Ep 4 (Step 003335): Train loss 6.345, Val loss 6.729
# Ep 4 (Step 003340): Train loss 6.405, Val loss 6.740
# Ep 4 (Step 003345): Train loss 6.313, Val loss 6.741
# Ep 4 (Step 003350): Train loss 6.322, Val loss 6.740
# Ep 4 (Step 003355): Train loss 6.613, Val loss 6.734
# Ep 4 (Step 003360): Train loss 6.590, Val loss 6.727
# Ep 4 (Step 003365): Train loss 6.483, Val loss 6.735
# Ep 4 (Step 003370): Train loss 6.560, Val loss 6.749
# Ep 4 (Step 003375): Train loss 6.386, Val loss 6.761
# Ep 4 (Step 003380): Train loss 6.486, Val loss 6.761
# Ep 4 (Step 003385): Train loss 6.535, Val loss 6.759
# Ep 4 (Step 003390): Train loss 6.319, Val loss 6.762
# Ep 4 (Step 003395): Train loss 6.295, Val loss 6.753
# Ep 4 (Step 003400): Train loss 5.971, Val loss 6.739
# Ep 4 (Step 003405): Train loss 6.435, Val loss 6.740
# Ep 4 (Step 003410): Train loss 6.333, Val loss 6.743
# Ep 4 (Step 003415): Train loss 6.362, Val loss 6.746
# Ep 4 (Step 003420): Train loss 6.193, Val loss 6.757
# Ep 4 (Step 003425): Train loss 6.057, Val loss 6.766
# Ep 4 (Step 003430): Train loss 6.475, Val loss 6.771
# Ep 4 (Step 003435): Train loss 6.169, Val loss 6.774
# Ep 4 (Step 003440): Train loss 6.585, Val loss 6.779
# Ep 4 (Step 003445): Train loss 6.588, Val loss 6.788
# Ep 4 (Step 003450): Train loss 6.398, Val loss 6.793
# Ep 4 (Step 003455): Train loss 6.627, Val loss 6.796
# Ep 4 (Step 003460): Train loss 6.306, Val loss 6.795
# Ep 4 (Step 003465): Train loss 6.682, Val loss 6.792
# Ep 4 (Step 003470): Train loss 6.625, Val loss 6.788
# Ep 4 (Step 003475): Train loss 6.618, Val loss 6.789
# Ep 4 (Step 003480): Train loss 6.456, Val loss 6.797
# Ep 4 (Step 003485): Train loss 6.625, Val loss 6.791
# Ep 4 (Step 003490): Train loss 6.059, Val loss 6.787
# Ep 4 (Step 003495): Train loss 6.692, Val loss 6.784
# Ep 4 (Step 003500): Train loss 6.500, Val loss 6.765
# Ep 4 (Step 003505): Train loss 6.311, Val loss 6.744
# Ep 4 (Step 003510): Train loss 6.240, Val loss 6.735
# Ep 4 (Step 003515): Train loss 6.377, Val loss 6.736
# Ep 4 (Step 003520): Train loss 6.657, Val loss 6.740
# Ep 4 (Step 003525): Train loss 6.532, Val loss 6.745
# Ep 4 (Step 003530): Train loss 6.504, Val loss 6.754
# Ep 4 (Step 003535): Train loss 6.534, Val loss 6.760
# Ep 4 (Step 003540): Train loss 6.465, Val loss 6.761
# Ep 4 (Step 003545): Train loss 6.524, Val loss 6.765
# Ep 4 (Step 003550): Train loss 6.350, Val loss 6.760
# Ep 4 (Step 003555): Train loss 6.281, Val loss 6.753
# Ep 4 (Step 003560): Train loss 6.121, Val loss 6.745
# Ep 4 (Step 003565): Train loss 6.742, Val loss 6.739
# Ep 4 (Step 003570): Train loss 5.803, Val loss 6.738
# Ep 4 (Step 003575): Train loss 6.594, Val loss 6.741
# Ep 4 (Step 003580): Train loss 6.502, Val loss 6.749
# Ep 4 (Step 003585): Train loss 6.438, Val loss 6.750
# Ep 4 (Step 003590): Train loss 6.552, Val loss 6.748
# Ep 4 (Step 003595): Train loss 6.294, Val loss 6.755
# Ep 4 (Step 003600): Train loss 6.689, Val loss 6.761
# Ep 4 (Step 003605): Train loss 6.174, Val loss 6.761
# Ep 4 (Step 003610): Train loss 6.569, Val loss 6.765
# Ep 4 (Step 003615): Train loss 6.198, Val loss 6.770
# Ep 4 (Step 003620): Train loss 6.597, Val loss 6.785
# Ep 4 (Step 003625): Train loss 6.220, Val loss 6.789
# Ep 4 (Step 003630): Train loss 6.268, Val loss 6.781
# He said we came here
# Ep 5 (Step 003635): Train loss 6.365, Val loss 6.770
# Ep 5 (Step 003640): Train loss 6.272, Val loss 6.757
# Ep 5 (Step 003645): Train loss 6.118, Val loss 6.741
# Ep 5 (Step 003650): Train loss 6.587, Val loss 6.741
# Ep 5 (Step 003655): Train loss 6.463, Val loss 6.742
# Ep 5 (Step 003660): Train loss 6.462, Val loss 6.738
# Ep 5 (Step 003665): Train loss 6.357, Val loss 6.731
# Ep 5 (Step 003670): Train loss 6.505, Val loss 6.732
# Ep 5 (Step 003675): Train loss 6.639, Val loss 6.740
# Ep 5 (Step 003680): Train loss 6.794, Val loss 6.747
# Ep 5 (Step 003685): Train loss 6.314, Val loss 6.750
# Ep 5 (Step 003690): Train loss 6.007, Val loss 6.755
# Ep 5 (Step 003695): Train loss 6.184, Val loss 6.761
# Ep 5 (Step 003700): Train loss 6.398, Val loss 6.773
# Ep 5 (Step 003705): Train loss 6.910, Val loss 6.772
# Ep 5 (Step 003710): Train loss 6.461, Val loss 6.772
# Ep 5 (Step 003715): Train loss 6.366, Val loss 6.771
# Ep 5 (Step 003720): Train loss 6.119, Val loss 6.758
# Ep 5 (Step 003725): Train loss 6.286, Val loss 6.749
# Ep 5 (Step 003730): Train loss 6.698, Val loss 6.749
# Ep 5 (Step 003735): Train loss 6.347, Val loss 6.748
# Ep 5 (Step 003740): Train loss 6.270, Val loss 6.751
# Ep 5 (Step 003745): Train loss 6.643, Val loss 6.762
# Ep 5 (Step 003750): Train loss 6.271, Val loss 6.773
# Ep 5 (Step 003755): Train loss 6.195, Val loss 6.780
# Ep 5 (Step 003760): Train loss 6.257, Val loss 6.779
# Ep 5 (Step 003765): Train loss 6.444, Val loss 6.776
# Ep 5 (Step 003770): Train loss 6.507, Val loss 6.778
# Ep 5 (Step 003775): Train loss 6.408, Val loss 6.775
# Ep 5 (Step 003780): Train loss 6.431, Val loss 6.764
# Ep 5 (Step 003785): Train loss 6.415, Val loss 6.758
# Ep 5 (Step 003790): Train loss 6.026, Val loss 6.758
# Ep 5 (Step 003795): Train loss 6.588, Val loss 6.758
# Ep 5 (Step 003800): Train loss 6.209, Val loss 6.755
# Ep 5 (Step 003805): Train loss 6.907, Val loss 6.757
# Ep 5 (Step 003810): Train loss 6.288, Val loss 6.763
# Ep 5 (Step 003815): Train loss 6.816, Val loss 6.768
# Ep 5 (Step 003820): Train loss 6.218, Val loss 6.764
# Ep 5 (Step 003825): Train loss 6.623, Val loss 6.760
# Ep 5 (Step 003830): Train loss 6.313, Val loss 6.759
# Ep 5 (Step 003835): Train loss 6.511, Val loss 6.762
# Ep 5 (Step 003840): Train loss 6.454, Val loss 6.772
# Ep 5 (Step 003845): Train loss 6.562, Val loss 6.781
# Ep 5 (Step 003850): Train loss 6.254, Val loss 6.793
# Ep 5 (Step 003855): Train loss 6.118, Val loss 6.785
# Ep 5 (Step 003860): Train loss 6.025, Val loss 6.775
# Ep 5 (Step 003865): Train loss 6.055, Val loss 6.774
# Ep 5 (Step 003870): Train loss 6.710, Val loss 6.767
# Ep 5 (Step 003875): Train loss 6.622, Val loss 6.766
# Ep 5 (Step 003880): Train loss 6.607, Val loss 6.765
# Ep 5 (Step 003885): Train loss 6.433, Val loss 6.765
# Ep 5 (Step 003890): Train loss 6.679, Val loss 6.759
# Ep 5 (Step 003895): Train loss 6.549, Val loss 6.764
# Ep 5 (Step 003900): Train loss 6.457, Val loss 6.768
# Ep 5 (Step 003905): Train loss 6.558, Val loss 6.758
# Ep 5 (Step 003910): Train loss 6.141, Val loss 6.745
# Ep 5 (Step 003915): Train loss 6.796, Val loss 6.745
# Ep 5 (Step 003920): Train loss 6.760, Val loss 6.753
# Ep 5 (Step 003925): Train loss 6.429, Val loss 6.758
# Ep 5 (Step 003930): Train loss 6.467, Val loss 6.758
# Ep 5 (Step 003935): Train loss 6.504, Val loss 6.763
# Ep 5 (Step 003940): Train loss 6.491, Val loss 6.767
# Ep 5 (Step 003945): Train loss 6.888, Val loss 6.758
# Ep 5 (Step 003950): Train loss 6.624, Val loss 6.752
# Ep 5 (Step 003955): Train loss 6.662, Val loss 6.757
# Ep 5 (Step 003960): Train loss 6.819, Val loss 6.757
# Ep 5 (Step 003965): Train loss 6.218, Val loss 6.755
# Ep 5 (Step 003970): Train loss 6.376, Val loss 6.755
# Ep 5 (Step 003975): Train loss 6.662, Val loss 6.758
# Ep 5 (Step 003980): Train loss 6.360, Val loss 6.761
# Ep 5 (Step 003985): Train loss 6.254, Val loss 6.774
# Ep 5 (Step 003990): Train loss 6.352, Val loss 6.789
# Ep 5 (Step 003995): Train loss 6.530, Val loss 6.789
# Ep 5 (Step 004000): Train loss 6.229, Val loss 6.783
# Ep 5 (Step 004005): Train loss 6.453, Val loss 6.770
# Ep 5 (Step 004010): Train loss 6.704, Val loss 6.759
# Ep 5 (Step 004015): Train loss 6.476, Val loss 6.755
# Ep 5 (Step 004020): Train loss 6.232, Val loss 6.754
# Ep 5 (Step 004025): Train loss 6.847, Val loss 6.757
# Ep 5 (Step 004030): Train loss 6.271, Val loss 6.769
# Ep 5 (Step 004035): Train loss 6.513, Val loss 6.777
# Ep 5 (Step 004040): Train loss 6.449, Val loss 6.779
# Ep 5 (Step 004045): Train loss 6.538, Val loss 6.773
# Ep 5 (Step 004050): Train loss 6.463, Val loss 6.766
# Ep 5 (Step 004055): Train loss 6.443, Val loss 6.773
# Ep 5 (Step 004060): Train loss 6.607, Val loss 6.777
# Ep 5 (Step 004065): Train loss 6.529, Val loss 6.778
# Ep 5 (Step 004070): Train loss 6.383, Val loss 6.779
# Ep 5 (Step 004075): Train loss 6.639, Val loss 6.778
# Ep 5 (Step 004080): Train loss 6.521, Val loss 6.780
# Ep 5 (Step 004085): Train loss 6.802, Val loss 6.782
# Ep 5 (Step 004090): Train loss 6.688, Val loss 6.779
# Ep 5 (Step 004095): Train loss 6.383, Val loss 6.780
# Ep 5 (Step 004100): Train loss 6.293, Val loss 6.783
# Ep 5 (Step 004105): Train loss 6.260, Val loss 6.791
# Ep 5 (Step 004110): Train loss 6.541, Val loss 6.803
# Ep 5 (Step 004115): Train loss 6.412, Val loss 6.815
# Ep 5 (Step 004120): Train loss 6.207, Val loss 6.832
# Ep 5 (Step 004125): Train loss 5.966, Val loss 6.834
# Ep 5 (Step 004130): Train loss 6.427, Val loss 6.815
# Ep 5 (Step 004135): Train loss 6.639, Val loss 6.797
# Ep 5 (Step 004140): Train loss 6.617, Val loss 6.774
# Ep 5 (Step 004145): Train loss 6.342, Val loss 6.754
# Ep 5 (Step 004150): Train loss 6.492, Val loss 6.745
# Ep 5 (Step 004155): Train loss 6.299, Val loss 6.739
# Ep 5 (Step 004160): Train loss 6.727, Val loss 6.747
# Ep 5 (Step 004165): Train loss 6.268, Val loss 6.751
# Ep 5 (Step 004170): Train loss 6.272, Val loss 6.743
# Ep 5 (Step 004175): Train loss 6.536, Val loss 6.742
# Ep 5 (Step 004180): Train loss 6.201, Val loss 6.748
# Ep 5 (Step 004185): Train loss 6.622, Val loss 6.753
# Ep 5 (Step 004190): Train loss 6.322, Val loss 6.751
# Ep 5 (Step 004195): Train loss 6.468, Val loss 6.749
# Ep 5 (Step 004200): Train loss 6.313, Val loss 6.751
# Ep 5 (Step 004205): Train loss 6.474, Val loss 6.762
# Ep 5 (Step 004210): Train loss 6.333, Val loss 6.766
# Ep 5 (Step 004215): Train loss 6.683, Val loss 6.760
# Ep 5 (Step 004220): Train loss 7.019, Val loss 6.753
# Ep 5 (Step 004225): Train loss 6.448, Val loss 6.751
# Ep 5 (Step 004230): Train loss 6.697, Val loss 6.751
# Ep 5 (Step 004235): Train loss 6.511, Val loss 6.759
# Ep 5 (Step 004240): Train loss 5.974, Val loss 6.756
# Ep 5 (Step 004245): Train loss 6.281, Val loss 6.758
# Ep 5 (Step 004250): Train loss 6.383, Val loss 6.762
# Ep 5 (Step 004255): Train loss 6.628, Val loss 6.766
# Ep 5 (Step 004260): Train loss 6.475, Val loss 6.769
# Ep 5 (Step 004265): Train loss 6.375, Val loss 6.764
# Ep 5 (Step 004270): Train loss 6.486, Val loss 6.765
# Ep 5 (Step 004275): Train loss 6.345, Val loss 6.759
# Ep 5 (Step 004280): Train loss 6.792, Val loss 6.761
# Ep 5 (Step 004285): Train loss 6.199, Val loss 6.757
# Ep 5 (Step 004290): Train loss 6.453, Val loss 6.758
# Ep 5 (Step 004295): Train loss 6.216, Val loss 6.767
# Ep 5 (Step 004300): Train loss 6.365, Val loss 6.775
# Ep 5 (Step 004305): Train loss 6.009, Val loss 6.775
# Ep 5 (Step 004310): Train loss 6.614, Val loss 6.781
# Ep 5 (Step 004315): Train loss 6.205, Val loss 6.786
# Ep 5 (Step 004320): Train loss 6.709, Val loss 6.783
# Ep 5 (Step 004325): Train loss 6.391, Val loss 6.778
# Ep 5 (Step 004330): Train loss 6.225, Val loss 6.782
# Ep 5 (Step 004335): Train loss 6.403, Val loss 6.785
# Ep 5 (Step 004340): Train loss 6.272, Val loss 6.788
# Ep 5 (Step 004345): Train loss 6.351, Val loss 6.783
# Ep 5 (Step 004350): Train loss 6.319, Val loss 6.778
# Ep 5 (Step 004355): Train loss 6.719, Val loss 6.767
# Ep 5 (Step 004360): Train loss 6.209, Val loss 6.759
# Ep 5 (Step 004365): Train loss 6.263, Val loss 6.761
# Ep 5 (Step 004370): Train loss 6.631, Val loss 6.767
# Ep 5 (Step 004375): Train loss 6.130, Val loss 6.771
# Ep 5 (Step 004380): Train loss 6.558, Val loss 6.773
# Ep 5 (Step 004385): Train loss 6.343, Val loss 6.776
# Ep 5 (Step 004390): Train loss 6.302, Val loss 6.780
# Ep 5 (Step 004395): Train loss 6.099, Val loss 6.783
# Ep 5 (Step 004400): Train loss 6.436, Val loss 6.787
# Ep 5 (Step 004405): Train loss 6.337, Val loss 6.781
# Ep 5 (Step 004410): Train loss 6.492, Val loss 6.771
# Ep 5 (Step 004415): Train loss 6.265, Val loss 6.763
# Ep 5 (Step 004420): Train loss 6.578, Val loss 6.753
# Ep 5 (Step 004425): Train loss 6.582, Val loss 6.755
# Ep 5 (Step 004430): Train loss 6.769, Val loss 6.755
# Ep 5 (Step 004435): Train loss 6.402, Val loss 6.763
# Ep 5 (Step 004440): Train loss 6.265, Val loss 6.775
# Ep 5 (Step 004445): Train loss 6.324, Val loss 6.783
# Ep 5 (Step 004450): Train loss 6.446, Val loss 6.789
# Ep 5 (Step 004455): Train loss 6.512, Val loss 6.791
# Ep 5 (Step 004460): Train loss 6.444, Val loss 6.796
# Ep 5 (Step 004465): Train loss 6.446, Val loss 6.798
# Ep 5 (Step 004470): Train loss 6.613, Val loss 6.802
# Ep 5 (Step 004475): Train loss 6.286, Val loss 6.791
# Ep 5 (Step 004480): Train loss 6.338, Val loss 6.783
# Ep 5 (Step 004485): Train loss 6.473, Val loss 6.781
# Ep 5 (Step 004490): Train loss 6.797, Val loss 6.792
# ...
# Ep 9 (Step 007615): Train loss 6.700, Val loss 6.826
# Ep 9 (Step 007620): Train loss 6.340, Val loss 6.823
# Ep 9 (Step 007625): Train loss 6.578, Val loss 6.814
# Ep 9 (Step 007630): Train loss 6.520, Val loss 6.811
# Ep 9 (Step 007635): Train loss 6.684, Val loss 6.808
# Ep 9 (Step 007640): Train loss 6.385, Val loss 6.810
# Ep 9 (Step 007645): Train loss 6.293, Val loss 6.809
# Ep 9 (Step 007650): Train loss 6.484, Val loss 6.809
# Ep 9 (Step 007655): Train loss 6.440, Val loss 6.806
# Ep 9 (Step 007660): Train loss 6.134, Val loss 6.812
# Ep 9 (Step 007665): Train loss 6.387, Val loss 6.818
# Ep 9 (Step 007670): Train loss 6.633, Val loss 6.814
# Ep 9 (Step 007675): Train loss 6.309, Val loss 6.817
# Ep 9 (Step 007680): Train loss 6.190, Val loss 6.818
# Ep 9 (Step 007685): Train loss 6.321, Val loss 6.820
# Ep 9 (Step 007690): Train loss 6.526, Val loss 6.811
# Ep 9 (Step 007695): Train loss 6.235, Val loss 6.808
# Ep 9 (Step 007700): Train loss 6.693, Val loss 6.810
# Ep 9 (Step 007705): Train loss 6.310, Val loss 6.817
# Ep 9 (Step 007710): Train loss 6.393, Val loss 6.830
# Ep 9 (Step 007715): Train loss 6.403, Val loss 6.826
# Ep 9 (Step 007720): Train loss 6.183, Val loss 6.825
# Ep 9 (Step 007725): Train loss 6.436, Val loss 6.814
# Ep 9 (Step 007730): Train loss 6.508, Val loss 6.812
# Ep 9 (Step 007735): Train loss 6.763, Val loss 6.816
# Ep 9 (Step 007740): Train loss 6.568, Val loss 6.821
# Ep 9 (Step 007745): Train loss 6.339, Val loss 6.824
# Ep 9 (Step 007750): Train loss 6.507, Val loss 6.819
# Ep 9 (Step 007755): Train loss 6.723, Val loss 6.824
# Ep 9 (Step 007760): Train loss 6.326, Val loss 6.828
# Ep 9 (Step 007765): Train loss 6.280, Val loss 6.829
# Ep 9 (Step 007770): Train loss 6.828, Val loss 6.826
# Ep 9 (Step 007775): Train loss 6.945, Val loss 6.825
# Ep 9 (Step 007780): Train loss 6.529, Val loss 6.825
# Ep 9 (Step 007785): Train loss 6.433, Val loss 6.825
# Ep 9 (Step 007790): Train loss 6.238, Val loss 6.829
# Ep 9 (Step 007795): Train loss 6.177, Val loss 6.828
# Ep 9 (Step 007800): Train loss 6.557, Val loss 6.828
# Ep 9 (Step 007805): Train loss 6.805, Val loss 6.820
# Ep 9 (Step 007810): Train loss 6.444, Val loss 6.825
# Ep 9 (Step 007815): Train loss 6.293, Val loss 6.830
# Ep 9 (Step 007820): Train loss 6.391, Val loss 6.837
# Ep 9 (Step 007825): Train loss 6.653, Val loss 6.844
# Ep 9 (Step 007830): Train loss 6.207, Val loss 6.837
# Ep 9 (Step 007835): Train loss 6.401, Val loss 6.826
# Ep 9 (Step 007840): Train loss 6.729, Val loss 6.818
# Ep 9 (Step 007845): Train loss 6.594, Val loss 6.819
# Ep 9 (Step 007850): Train loss 6.330, Val loss 6.821
# Ep 9 (Step 007855): Train loss 6.629, Val loss 6.815
# Ep 9 (Step 007860): Train loss 6.228, Val loss 6.811
# Ep 9 (Step 007865): Train loss 6.721, Val loss 6.813
# Ep 9 (Step 007870): Train loss 6.321, Val loss 6.816
# Ep 9 (Step 007875): Train loss 6.179, Val loss 6.821
# Ep 9 (Step 007880): Train loss 6.106, Val loss 6.821
# Ep 9 (Step 007885): Train loss 6.527, Val loss 6.813
# Ep 9 (Step 007890): Train loss 6.186, Val loss 6.809
# Ep 9 (Step 007895): Train loss 6.278, Val loss 6.811
# Ep 9 (Step 007900): Train loss 6.220, Val loss 6.812
# Ep 9 (Step 007905): Train loss 6.291, Val loss 6.803
# Ep 9 (Step 007910): Train loss 6.585, Val loss 6.790
# Ep 9 (Step 007915): Train loss 6.452, Val loss 6.778
# Ep 9 (Step 007920): Train loss 6.882, Val loss 6.783
# Ep 9 (Step 007925): Train loss 6.241, Val loss 6.788
# Ep 9 (Step 007930): Train loss 6.615, Val loss 6.785
# Ep 9 (Step 007935): Train loss 6.667, Val loss 6.781
# Ep 9 (Step 007940): Train loss 6.491, Val loss 6.785
# Ep 9 (Step 007945): Train loss 6.116, Val loss 6.778
# Ep 9 (Step 007950): Train loss 6.279, Val loss 6.768
# Ep 9 (Step 007955): Train loss 6.193, Val loss 6.766
# Ep 9 (Step 007960): Train loss 6.374, Val loss 6.763
# Ep 9 (Step 007965): Train loss 6.703, Val loss 6.767
# Ep 9 (Step 007970): Train loss 6.615, Val loss 6.771
# Ep 9 (Step 007975): Train loss 6.382, Val loss 6.774
# Ep 9 (Step 007980): Train loss 6.128, Val loss 6.783
# Ep 9 (Step 007985): Train loss 6.244, Val loss 6.780
# Ep 9 (Step 007990): Train loss 6.536, Val loss 6.771
# Ep 9 (Step 007995): Train loss 6.567, Val loss 6.773
# Ep 9 (Step 008000): Train loss 6.498, Val loss 6.784
# Ep 9 (Step 008005): Train loss 6.573, Val loss 6.796
# Ep 9 (Step 008010): Train loss 6.241, Val loss 6.809
# Ep 9 (Step 008015): Train loss 6.621, Val loss 6.816
# Ep 9 (Step 008020): Train loss 6.257, Val loss 6.805
# Ep 9 (Step 008025): Train loss 6.165, Val loss 6.802
# Ep 9 (Step 008030): Train loss 6.100, Val loss 6.800
# Ep 9 (Step 008035): Train loss 6.443, Val loss 6.798
# Ep 9 (Step 008040): Train loss 6.333, Val loss 6.802
# Ep 9 (Step 008045): Train loss 6.322, Val loss 6.812
# Ep 9 (Step 008050): Train loss 6.658, Val loss 6.817
# Ep 9 (Step 008055): Train loss 6.258, Val loss 6.813
# Ep 9 (Step 008060): Train loss 6.366, Val loss 6.809
# Ep 9 (Step 008065): Train loss 6.556, Val loss 6.806
# Ep 9 (Step 008070): Train loss 6.065, Val loss 6.812
# Ep 9 (Step 008075): Train loss 6.354, Val loss 6.818
# Ep 9 (Step 008080): Train loss 6.288, Val loss 6.820
# Ep 9 (Step 008085): Train loss 6.635, Val loss 6.812
# Ep 9 (Step 008090): Train loss 6.314, Val loss 6.802
# Ep 9 (Step 008095): Train loss 6.340, Val loss 6.792
# Ep 9 (Step 008100): Train loss 6.484, Val loss 6.794
# Ep 9 (Step 008105): Train loss 6.348, Val loss 6.798
# Ep 9 (Step 008110): Train loss 6.454, Val loss 6.802
# Ep 9 (Step 008115): Train loss 6.419, Val loss 6.802
# Ep 9 (Step 008120): Train loss 6.342, Val loss 6.796
# Ep 9 (Step 008125): Train loss 6.507, Val loss 6.793
# Ep 9 (Step 008130): Train loss 6.398, Val loss 6.794
# Ep 9 (Step 008135): Train loss 6.576, Val loss 6.803
# Ep 9 (Step 008140): Train loss 6.575, Val loss 6.805
# Ep 9 (Step 008145): Train loss 6.274, Val loss 6.806
# Ep 9 (Step 008150): Train loss 6.547, Val loss 6.815
# Ep 9 (Step 008155): Train loss 6.290, Val loss 6.822
# Ep 9 (Step 008160): Train loss 6.986, Val loss 6.823
# Ep 9 (Step 008165): Train loss 6.934, Val loss 6.822
# Ep 9 (Step 008170): Train loss 6.545, Val loss 6.809
# He said we came here
# Ep 10 (Step 008175): Train loss 6.550, Val loss 6.796
# Ep 10 (Step 008180): Train loss 6.432, Val loss 6.797
# Ep 10 (Step 008185): Train loss 6.299, Val loss 6.807
# Ep 10 (Step 008190): Train loss 6.264, Val loss 6.808
# Ep 10 (Step 008195): Train loss 6.285, Val loss 6.804
# Ep 10 (Step 008200): Train loss 6.445, Val loss 6.798
# Ep 10 (Step 008205): Train loss 6.485, Val loss 6.794
# Ep 10 (Step 008210): Train loss 6.635, Val loss 6.794
# Ep 10 (Step 008215): Train loss 6.761, Val loss 6.799
# Ep 10 (Step 008220): Train loss 6.571, Val loss 6.804
# Ep 10 (Step 008225): Train loss 6.450, Val loss 6.807
# Ep 10 (Step 008230): Train loss 6.771, Val loss 6.813
# Ep 10 (Step 008235): Train loss 6.519, Val loss 6.817
# Ep 10 (Step 008240): Train loss 6.444, Val loss 6.820
# Ep 10 (Step 008245): Train loss 6.674, Val loss 6.826
# Ep 10 (Step 008250): Train loss 6.209, Val loss 6.828
# Ep 10 (Step 008255): Train loss 6.360, Val loss 6.822
# Ep 10 (Step 008260): Train loss 6.528, Val loss 6.811
# Ep 10 (Step 008265): Train loss 6.541, Val loss 6.805
# Ep 10 (Step 008270): Train loss 6.639, Val loss 6.812
# Ep 10 (Step 008275): Train loss 6.760, Val loss 6.817
# Ep 10 (Step 008280): Train loss 6.184, Val loss 6.804
# Ep 10 (Step 008285): Train loss 6.163, Val loss 6.797
# Ep 10 (Step 008290): Train loss 6.437, Val loss 6.801
# Ep 10 (Step 008295): Train loss 6.590, Val loss 6.816
# Ep 10 (Step 008300): Train loss 6.282, Val loss 6.833
# Ep 10 (Step 008305): Train loss 6.627, Val loss 6.838
# Ep 10 (Step 008310): Train loss 6.582, Val loss 6.835
# Ep 10 (Step 008315): Train loss 6.782, Val loss 6.829
# Ep 10 (Step 008320): Train loss 6.825, Val loss 6.820
# Ep 10 (Step 008325): Train loss 6.488, Val loss 6.819
# Ep 10 (Step 008330): Train loss 6.330, Val loss 6.823
# Ep 10 (Step 008335): Train loss 6.472, Val loss 6.822
# Ep 10 (Step 008340): Train loss 6.265, Val loss 6.814
# Ep 10 (Step 008345): Train loss 6.581, Val loss 6.806
# Ep 10 (Step 008350): Train loss 6.272, Val loss 6.805
# Ep 10 (Step 008355): Train loss 6.566, Val loss 6.818
# Ep 10 (Step 008360): Train loss 6.112, Val loss 6.834
# Ep 10 (Step 008365): Train loss 6.532, Val loss 6.831
# Ep 10 (Step 008370): Train loss 6.988, Val loss 6.820
# Ep 10 (Step 008375): Train loss 6.441, Val loss 6.812
# Ep 10 (Step 008380): Train loss 6.564, Val loss 6.811
# Ep 10 (Step 008385): Train loss 6.167, Val loss 6.813
# Ep 10 (Step 008390): Train loss 6.452, Val loss 6.820
# Ep 10 (Step 008395): Train loss 6.519, Val loss 6.819
# Ep 10 (Step 008400): Train loss 6.580, Val loss 6.820
# Ep 10 (Step 008405): Train loss 6.435, Val loss 6.821
# Ep 10 (Step 008410): Train loss 6.496, Val loss 6.809
# Ep 10 (Step 008415): Train loss 6.372, Val loss 6.810
# Ep 10 (Step 008420): Train loss 6.897, Val loss 6.821
# Ep 10 (Step 008425): Train loss 6.562, Val loss 6.827
# Ep 10 (Step 008430): Train loss 6.503, Val loss 6.830
# Ep 10 (Step 008435): Train loss 6.603, Val loss 6.837
# Ep 10 (Step 008440): Train loss 6.330, Val loss 6.831
# Ep 10 (Step 008445): Train loss 6.224, Val loss 6.830
# Ep 10 (Step 008450): Train loss 6.472, Val loss 6.836
# Ep 10 (Step 008455): Train loss 6.272, Val loss 6.834
# Ep 10 (Step 008460): Train loss 6.313, Val loss 6.834
# Ep 10 (Step 008465): Train loss 6.232, Val loss 6.832
# Ep 10 (Step 008470): Train loss 6.543, Val loss 6.835
# Ep 10 (Step 008475): Train loss 6.255, Val loss 6.843
# Ep 10 (Step 008480): Train loss 6.511, Val loss 6.852
# Ep 10 (Step 008485): Train loss 6.537, Val loss 6.853
# Ep 10 (Step 008490): Train loss 6.617, Val loss 6.856
# Ep 10 (Step 008495): Train loss 6.542, Val loss 6.859
# Ep 10 (Step 008500): Train loss 6.489, Val loss 6.855
# Ep 10 (Step 008505): Train loss 6.579, Val loss 6.846
# Ep 10 (Step 008510): Train loss 6.299, Val loss 6.835
# Ep 10 (Step 008515): Train loss 6.522, Val loss 6.826
# Ep 10 (Step 008520): Train loss 6.286, Val loss 6.830
# Ep 10 (Step 008525): Train loss 6.405, Val loss 6.832
# Ep 10 (Step 008530): Train loss 6.642, Val loss 6.834
# Ep 10 (Step 008535): Train loss 6.365, Val loss 6.836
# Ep 10 (Step 008540): Train loss 6.370, Val loss 6.826
# Ep 10 (Step 008545): Train loss 6.232, Val loss 6.822
# Ep 10 (Step 008550): Train loss 5.979, Val loss 6.826
# Ep 10 (Step 008555): Train loss 6.280, Val loss 6.830
# Ep 10 (Step 008560): Train loss 6.694, Val loss 6.832
# Ep 10 (Step 008565): Train loss 6.905, Val loss 6.843
# Ep 10 (Step 008570): Train loss 6.504, Val loss 6.844
# Ep 10 (Step 008575): Train loss 6.433, Val loss 6.840
# Ep 10 (Step 008580): Train loss 6.613, Val loss 6.834
# Ep 10 (Step 008585): Train loss 6.904, Val loss 6.836
# Ep 10 (Step 008590): Train loss 6.104, Val loss 6.847
# Ep 10 (Step 008595): Train loss 6.210, Val loss 6.852
# Ep 10 (Step 008600): Train loss 6.500, Val loss 6.842
# Ep 10 (Step 008605): Train loss 6.756, Val loss 6.826
# Ep 10 (Step 008610): Train loss 6.325, Val loss 6.819
# Ep 10 (Step 008615): Train loss 6.195, Val loss 6.816
# Ep 10 (Step 008620): Train loss 6.313, Val loss 6.813
# Ep 10 (Step 008625): Train loss 6.499, Val loss 6.813
# Ep 10 (Step 008630): Train loss 6.247, Val loss 6.812
# Ep 10 (Step 008635): Train loss 6.441, Val loss 6.810
# Ep 10 (Step 008640): Train loss 6.279, Val loss 6.813
# Ep 10 (Step 008645): Train loss 6.417, Val loss 6.819
# Ep 10 (Step 008650): Train loss 6.196, Val loss 6.837
# Ep 10 (Step 008655): Train loss 6.683, Val loss 6.843
# Ep 10 (Step 008660): Train loss 6.454, Val loss 6.839
# Ep 10 (Step 008665): Train loss 6.141, Val loss 6.832
# Ep 10 (Step 008670): Train loss 6.380, Val loss 6.834
# Ep 10 (Step 008675): Train loss 6.480, Val loss 6.843
# Ep 10 (Step 008680): Train loss 6.296, Val loss 6.856
# Ep 10 (Step 008685): Train loss 6.323, Val loss 6.853
# Ep 10 (Step 008690): Train loss 6.182, Val loss 6.851
# Ep 10 (Step 008695): Train loss 6.372, Val loss 6.839
# Ep 10 (Step 008700): Train loss 6.397, Val loss 6.824
# Ep 10 (Step 008705): Train loss 6.484, Val loss 6.825
# Ep 10 (Step 008710): Train loss 6.461, Val loss 6.829
# Ep 10 (Step 008715): Train loss 6.674, Val loss 6.832
# Ep 10 (Step 008720): Train loss 6.372, Val loss 6.826
# Ep 10 (Step 008725): Train loss 6.387, Val loss 6.816
# Ep 10 (Step 008730): Train loss 6.157, Val loss 6.818
# Ep 10 (Step 008735): Train loss 6.543, Val loss 6.830
# Ep 10 (Step 008740): Train loss 6.791, Val loss 6.849
# Ep 10 (Step 008745): Train loss 6.411, Val loss 6.843
# Ep 10 (Step 008750): Train loss 6.826, Val loss 6.831
# Ep 10 (Step 008755): Train loss 6.502, Val loss 6.820
# Ep 10 (Step 008760): Train loss 6.425, Val loss 6.816
# Ep 10 (Step 008765): Train loss 6.439, Val loss 6.814
# Ep 10 (Step 008770): Train loss 6.376, Val loss 6.816
# Ep 10 (Step 008775): Train loss 6.316, Val loss 6.821
# Ep 10 (Step 008780): Train loss 6.502, Val loss 6.816
# Ep 10 (Step 008785): Train loss 5.975, Val loss 6.807
# Ep 10 (Step 008790): Train loss 6.621, Val loss 6.803
# Ep 10 (Step 008795): Train loss 6.356, Val loss 6.799
# Ep 10 (Step 008800): Train loss 6.506, Val loss 6.798
# Ep 10 (Step 008805): Train loss 6.600, Val loss 6.796
# Ep 10 (Step 008810): Train loss 6.161, Val loss 6.786
# Ep 10 (Step 008815): Train loss 6.341, Val loss 6.779
# Ep 10 (Step 008820): Train loss 6.143, Val loss 6.777
# Ep 10 (Step 008825): Train loss 6.359, Val loss 6.790
# Ep 10 (Step 008830): Train loss 6.498, Val loss 6.799
# Ep 10 (Step 008835): Train loss 6.395, Val loss 6.813
# Ep 10 (Step 008840): Train loss 6.581, Val loss 6.822
# Ep 10 (Step 008845): Train loss 6.355, Val loss 6.821
# Ep 10 (Step 008850): Train loss 6.616, Val loss 6.820
# Ep 10 (Step 008855): Train loss 6.476, Val loss 6.817
# Ep 10 (Step 008860): Train loss 6.484, Val loss 6.816
# Ep 10 (Step 008865): Train loss 6.223, Val loss 6.816
# Ep 10 (Step 008870): Train loss 6.355, Val loss 6.820
# Ep 10 (Step 008875): Train loss 6.386, Val loss 6.813
# Ep 10 (Step 008880): Train loss 6.480, Val loss 6.799
# Ep 10 (Step 008885): Train loss 6.251, Val loss 6.796
# Ep 10 (Step 008890): Train loss 6.518, Val loss 6.800
# Ep 10 (Step 008895): Train loss 6.121, Val loss 6.804
# Ep 10 (Step 008900): Train loss 6.480, Val loss 6.805
# Ep 10 (Step 008905): Train loss 6.173, Val loss 6.805
# Ep 10 (Step 008910): Train loss 6.740, Val loss 6.806
# Ep 10 (Step 008915): Train loss 6.338, Val loss 6.809
# Ep 10 (Step 008920): Train loss 6.558, Val loss 6.809
# Ep 10 (Step 008925): Train loss 6.253, Val loss 6.807
# Ep 10 (Step 008930): Train loss 6.306, Val loss 6.814
# Ep 10 (Step 008935): Train loss 6.423, Val loss 6.823
# Ep 10 (Step 008940): Train loss 5.957, Val loss 6.830
# Ep 10 (Step 008945): Train loss 6.612, Val loss 6.827
# Ep 10 (Step 008950): Train loss 6.770, Val loss 6.829
# Ep 10 (Step 008955): Train loss 6.282, Val loss 6.830
# Ep 10 (Step 008960): Train loss 6.259, Val loss 6.823
# Ep 10 (Step 008965): Train loss 6.396, Val loss 6.809
# Ep 10 (Step 008970): Train loss 6.802, Val loss 6.809
# Ep 10 (Step 008975): Train loss 6.354, Val loss 6.809
# Ep 10 (Step 008980): Train loss 6.482, Val loss 6.816
# Ep 10 (Step 008985): Train loss 6.381, Val loss 6.824
# Ep 10 (Step 008990): Train loss 6.390, Val loss 6.827
# Ep 10 (Step 008995): Train loss 6.218, Val loss 6.816
# Ep 10 (Step 009000): Train loss 6.438, Val loss 6.805
# Ep 10 (Step 009005): Train loss 6.025, Val loss 6.795
# Ep 10 (Step 009010): Train loss 6.814, Val loss 6.786
# Ep 10 (Step 009015): Train loss 6.246, Val loss 6.787
# Ep 10 (Step 009020): Train loss 6.291, Val loss 6.785
# Ep 10 (Step 009025): Train loss 6.829, Val loss 6.789
# Ep 10 (Step 009030): Train loss 6.355, Val loss 6.798
# Ep 10 (Step 009035): Train loss 6.268, Val loss 6.805
# Ep 10 (Step 009040): Train loss 6.531, Val loss 6.818
# Ep 10 (Step 009045): Train loss 6.760, Val loss 6.819
# Ep 10 (Step 009050): Train loss 6.559, Val loss 6.806
# Ep 10 (Step 009055): Train loss 6.789, Val loss 6.802
# Ep 10 (Step 009060): Train loss 6.575, Val loss 6.800
# Ep 10 (Step 009065): Train loss 6.420, Val loss 6.804
# Ep 10 (Step 009070): Train loss 6.727, Val loss 6.808
# Ep 10 (Step 009075): Train loss 6.106, Val loss 6.809
# He said we came here
# Sample output:
#  The tree was
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# All training runs completed in 32.72 minutes.
